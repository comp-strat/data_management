# %%
import pandas as pd
folder_prefix = '/home/jovyan/work/'

# %%
pwd
# Out:
# '/home/jovyan/work/data_management/data/cleandata'

# %%
x = pd.read_csv('../../../nowdata/parsing/overlaps_removed_df.csv', encoding= 'latin-1')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-11-b073a87654d8> in <module>()
# ----> 1 x = pd.read_csv('../../../nowdata/parsing/overlaps_removed_df.csv', encoding= 'latin-1')
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
the_parsed = pd.read_csv(folder_prefix + "nowdata/parsing/overlaps_removed_df.csv", sep="\t", low_memory=False, encoding="utf-8")

# %%
the_parsed.sort_index(axis=1) #how to get alphabetically
# Out:
#        % Civilian Population 16 to 19 Years: High School Graduate, or Enrolled (in School)  \
# 0                                                    NaN
# 1                                                  88.03
# 2                                                  89.50
# 3                                                  89.50
# 4                                                  96.88
# 5                                                  96.88
# 6                                                    NaN
# 7                                                    NaN
# 8                                                  96.88
# 9                                                  96.88
# 10                                                 96.88
# 11                                                 96.88
# 12                                                 96.88
# 13                                                 96.88
# 14                                                 96.88
# ...

# %%
the_parsed =the_parsed[['SCH_NAME','NCESSCH','YEAR_OPENED','MEMBER','ADDRESS16','PCTFRL', 'PCTETH']]
the_parsed
# Out:
#       SCH_NAME       NCESSCH  YEAR_OPENED  MEMBER  \
# 0          NaN  1.001970e+10       2016.0     0.0
# 1          NaN  2.000010e+10       1999.0   177.0
# 2          NaN  2.001500e+10       1998.0   163.0
# 3          NaN  2.001500e+10       2003.0   183.0
# 4          NaN  2.001800e+10       1998.0   379.0
# 5          NaN  2.001800e+10       1998.0   541.0
# 6          NaN  2.001800e+10       1998.0     0.0
# 7          NaN  2.001800e+10       1998.0     0.0
# 8          NaN  2.001800e+10       2005.0   267.0
# 9          NaN  2.001800e+10       2005.0   177.0
# 10         NaN  2.001800e+10       2003.0   267.0
# 11         NaN  2.001800e+10       2003.0   193.0
# 12         NaN  2.001800e+10       2007.0   443.0
# 13         NaN  2.001800e+10       2008.0   334.0
# 14         NaN  2.001800e+10       2015.0     0.0
# 15         NaN  2.002100e+10       1998.0   100.0
# 16         NaN  2.003900e+10       1998.0   188.0
# 17         NaN  2.003900e+10       1998.0   103.0
# ...

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
the_parsed
# Out:
#       SCH_NAME             NCESSCH  YEAR_OPENED  MEMBER  \
# 0          NaN  10,019,702,432.000    2,016.000   0.000
# 1          NaN  20,000,100,329.000    1,999.000 177.000
# 2          NaN  20,015,000,306.000    1,998.000 163.000
# 3          NaN  20,015,000,523.000    2,003.000 183.000
# 4          NaN  20,018,000,172.000    1,998.000 379.000
# 5          NaN  20,018,000,178.000    1,998.000 541.000
# 6          NaN  20,018,000,228.000    1,998.000   0.000
# 7          NaN  20,018,000,315.000    1,998.000   0.000
# 8          NaN  20,018,000,459.000    2,005.000 267.000
# 9          NaN  20,018,000,460.000    2,005.000 177.000
# 10         NaN  20,018,000,530.000    2,003.000 267.000
# 11         NaN  20,018,000,555.000    2,003.000 193.000
# 12         NaN  20,018,000,732.000    2,007.000 443.000
# 13         NaN  20,018,000,736.000    2,008.000 334.000
# 14         NaN  20,018,000,756.000    2,015.000   0.000
# 15         NaN  20,021,000,268.000    1,998.000 100.000
# ...

# %% [markdown]
# # Merging scraped data into full public school data, through 2016-17
#
# Author: Jaren Haber
#
# Date: 07-18-18

# %%
import pandas as pd
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def convert_df(df):
    """Makes a Pandas DataFrame more memory-efficient through intelligent use of Pandas data types: 
    specifically, by storing columns with repetitive Python strings not with the object dtype for unique values 
    (entirely stored in memory) but as categoricals, which are represented by repeated integer values. This is a 
    net gain in memory when the reduced memory size of the category type outweighs the added memory cost of storing 
    one more thing. As such, this function checks the degree of redundancy for a given column before converting it."""
    
    converted_df = pd.DataFrame() # Initialize DF for memory-efficient storage of strings (object types)
    # TO DO: Infer dtypes of df
    df_obj = df.select_dtypes(include=['object']).copy() # Filter to only those columns of object data type

    # TO DO: Don't check out lists of text chunks
    for col in df.columns: 
        if col in df_obj: 
            num_unique_values = len(df_obj[col].unique())
            num_total_values = len(df_obj[col])
            if (num_unique_values / num_total_values) < 0.5: # Only convert data types if at least half of values are duplicates
                converted_df.loc[:,col] = df[col].astype('category') # Store these columns as dtype "category"
            else: 
                converted_df.loc[:,col] = df[col]
        else:    
            converted_df.loc[:,col] = df[col]
                      
    converted_df.select_dtypes(include=['float']).apply(pd.to_numeric,downcast='float')
    converted_df.select_dtypes(include=['int']).apply(pd.to_numeric,downcast='signed')
    
    return converted_df

# %%
# Read in files
df_scraped = pd.read_pickle("../../scrapy_cluster_data/new_processed_df.pkl") # Holds charter scrape data in 'data' column
df_cmos = pd.read_csv("../data/pub_schools_CMO_2015.csv", encoding = "latin1", low_memory=False) # Holds all pub schools data, including CMO info and CMO scraped data 
df_openclose = pd.read_csv("../data/pubschools_openclose_2015.csv", low_memory=False) # Has year opened and year closed
#df_r100 = pd.read_csv("../../text_analysis/data/random_sample_100.csv", sep="\t") # 100 schools, 25 each randomly selected from high prog, high ess, low both, high both

# %%
# Define paths for saving files
full_path = "../data/pubschools_full_2015.pkl" # Holds all text data, both CMOs and schools; all public schools
charters_path = "../../charters_full_2015.pkl" # All text data; only charter schools (regardless if open or not)
missing_path = "../data/charters_noURL.csv" # Only charters without URLs (need to collect and clean)
#r100_path = "../../text_analysis/data/random_sample_100.csv" # Revised 100 random schools

# %%
# Remove unnecessary columns from scraped DF
df_scraped = df_scraped[["NCESSCH", "data"]]
#df_scraped = df_scraped[["NCESSCH", "URL"]]
df_scraped.head(10)
# Out:
#         NCESSCH                            URL
# 0  130123003896  http://099.clayton.k12.ga.us/
# 1  130123003687  http://198.clayton.k12.ga.us/
# 2  350006000811   http://21stcenturypa.com/wp/
# 3  220019300944    http://42charterschool.org/
# 4  411167001641           http://a3school.org/
# 5   40010601892    http://aaechighschools.com/
# 6  490018601483            http://aaiutah.org/
# 7   80345001896               http://aak8.org/
# 8   62703013064        http://ablecharter.net/
# 9  550039002880     http://abs.aasd.k12.wi.us/

# %%
sorted(list(df_openclose))
# Out:
# ['AE',
#  'AEOFFERED',
#  'AM',
#  'AM01F',
#  'AM01M',
#  'AM02F',
#  'AM02M',
#  'AM03F',
#  'AM03M',
#  'AM04F',
#  'AM04M',
#  'AM05F',
#  'AM05M',
#  'AM06F',
#  'AM06M',
#  'AM07F',
#  'AM07M',
#  'AM08F',
#  'AM08M',
#  'AM09F',
#  'AM09M',
#  'AM10F',
#  'AM10M',
#  'AM11F',
#  'AM11M',
#  'AM12F',
#  'AM12M',
#  'AM13F',
#  'AM13M',
#  'AMAEF',
#  'AMAEM',
#  'AMALF',
#  'AMALM',
#  'AMKGF',
#  'AMKGM',
#  'AMPKF',
#  'AMPKM',
#  'AMUGF',
#  'AMUGM',
#  'AS',
#  'AS01F',
#  'AS01M',
#  'AS02F',
#  'AS02M',
#  'AS03F',
#  'AS03M',
#  'AS04F',
#  'AS04M',
#  'AS05F',
#  'AS05M',
#  'AS06F',
#  'AS06M',
#  'AS07F',
#  'AS07M',
#  'AS08F',
#  'AS08M',
#  'AS09F',
#  'AS09M',
#  'AS10F',
#  'AS10M',
#  'AS11F',
#  'AS11M',
#  'AS12F',
#  'AS12M',
#  'AS13F',
#  'AS13M',
#  'ASAEF',
#  'ASAEM',
#  'ASALF',
#  'ASALM',
#  'ASKGF',
#  'ASKGM',
#  'ASPKF',
#  'ASPKM',
#  'ASUGF',
#  'ASUGM',
#  'BIES',
#  'BL',
#  'BL01F',
#  'BL01M',
#  'BL02F',
#  'BL02M',
#  'BL03F',
#  'BL03M',
#  'BL04F',
#  'BL04M',
#  'BL05F',
#  'BL05M',
#  'BL06F',
#  'BL06M',
#  'BL07F',
#  'BL07M',
#  'BL08F',
#  'BL08M',
#  'BL09F',
#  'BL09M',
#  'BL10F',
#  'BL10M',
#  'BL11F',
#  'BL11M',
#  'BL12F',
#  'BL12M',
#  'BL13F',
#  'BL13M',
#  'BLAEF',
#  'BLAEM',
#  'BLALF',
#  'BLALM',
#  'BLKGF',
#  'BLKGM',
#  'BLPKF',
#  'BLPKM',
#  'BLUGF',
#  'BLUGM',
#  'CHARTAUTH1',
#  'CHARTAUTH2',
#  'CHARTAUTHN1',
#  'CHARTAUTHN2',
#  'CHARTER_TEXT',
#  'CHARTER_TEXT15',
#  'CHARTER_TEXT16',
#  'CHARTR00',
#  'CHARTR01',
#  'CHARTR02',
#  'CHARTR03',
#  'CHARTR04',
#  'CHARTR05',
#  'CHARTR06',
#  'CHARTR07',
#  'CHARTR08',
#  'CHARTR09',
#  'CHARTR10_x',
#  'CHARTR10_x.1',
#  'CHARTR10_y',
#  'CHARTR10_y.1',
#  'CHARTR98',
#  'CHARTR99',
#  'EFFECTIVE_DATE',
#  'FIPST',
#  'FRELCH',
#  'FTE',
#  'G01',
#  'G02',
#  'G03',
#  'G04',
#  'G05',
#  'G06',
#  'G07',
#  'G08',
#  'G09',
#  'G10',
#  'G10OFFERED',
#  'G11',
#  'G11OFFERED',
#  'G12',
#  'G12OFFERED',
#  'G13',
#  'G13OFFERED',
#  'G1OFFERED',
#  'G2OFFERED',
#  'G3OFFERED',
#  'G4OFFERED',
#  'G5OFFERED',
#  'G6OFFERED',
#  'G7OFFERED',
#  'G8OFFERED',
#  'G9OFFERED',
#  'GSHI',
#  'GSLO',
#  'HI',
#  'HI01F',
#  'HI01M',
#  'HI02F',
#  'HI02M',
#  'HI03F',
#  'HI03M',
#  'HI04F',
#  'HI04M',
#  'HI05F',
#  'HI05M',
#  'HI06F',
#  'HI06M',
#  'HI07F',
#  'HI07M',
#  'HI08F',
#  'HI08M',
#  'HI09F',
#  'HI09M',
#  'HI10F',
#  'HI10M',
#  'HI11F',
#  'HI11M',
#  'HI12F',
#  'HI12M',
#  'HI13F',
#  'HI13M',
#  'HIAEF',
#  'HIAEM',
#  'HIALF',
#  'HIALM',
#  'HIKGF',
#  'HIKGM',
#  'HIPKF',
#  'HIPKM',
#  'HIUGF',
#  'HIUGM',
#  'HP',
#  'HP01F',
#  'HP01M',
#  'HP02F',
#  'HP02M',
#  'HP03F',
#  'HP03M',
#  'HP04F',
#  'HP04M',
#  'HP05F',
#  'HP05M',
#  'HP06F',
#  'HP06M',
#  'HP07F',
#  'HP07M',
#  'HP08F',
#  'HP08M',
#  'HP09F',
#  'HP09M',
#  'HP10F',
#  'HP10M',
#  'HP11F',
#  'HP11M',
#  'HP12F',
#  'HP12M',
#  'HP13F',
#  'HP13M',
#  'HPAEF',
#  'HPAEM',
#  'HPALF',
#  'HPALM',
#  'HPKGF',
#  'HPKGM',
#  'HPPKF',
#  'HPPKM',
#  'HPUGF',
#  'HPUGM',
#  'IGOFFERED',
#  'ISFLE',
#  'ISFTEPUP',
#  'ISMEMPUP',
#  'ISPELM',
#  'ISPFEMALE',
#  'ISPWHITE',
#  'KG',
#  'KGOFFERED',
#  'LCITY',
#  'LEAID',
#  'LEA_NAME',
#  'LEVEL',
#  'LSTATE',
#  'LSTREET1',
#  'LSTREET2',
#  'LSTREET3',
#  'LZIP',
#  'LZIP4',
#  'MAGNET_TEXT',
#  'MCITY',
#  'MEMBER',
#  'MSTATE',
#  'MSTREET1',
#  'MSTREET2',
#  'MSTREET3',
#  'MZIP',
#  'MZIP4',
#  'NCESSCH',
#  'NOGRADES',
#  'NSLPSTATUS_CODE',
#  'NSLPSTATUS_TEXT',
#  'OUT_OF_STATE_FLAG',
#  'PHONE',
#  'PK',
#  'PKOFFERED',
#  'RECONSTF10_x',
#  'RECONSTF10_x.1',
#  'RECONSTF10_y',
#  'RECONSTF10_y.1',
#  'RECONSTY10_x',
#  'RECONSTY10_x.1',
#  'RECONSTY10_y',
#  'RECONSTY10_y.1',
#  'RECON_STATUS',
#  'RECON_STATUS15',
#  'RECON_STATUS16',
#  'REDLCH',
#  'SCHID',
#  'SCHNAM00',
#  'SCHNAM01',
#  'SCHNAM02',
#  'SCHNAM03',
#  'SCHNAM04',
#  'SCHNAM05',
#  'SCHNAM06',
#  'SCHNAM07',
#  'SCHNAM08',
#  'SCHNAM09',
#  'SCHNAM10',
#  'SCHNAM11',
#  'SCHNAM12',
#  'SCHNAM13',
#  'SCHNAM15',
#  'SCHNAM16',
#  'SCHNAM98',
#  'SCHNAM99',
#  'SCH_NAME',
#  'SCH_TYPE',
#  'SCH_TYPE_TEXT',
#  'SEANAME',
#  'SHARED_TIME',
#  'STABR',
#  'STATENAME',
#  'STATUS00',
#  'STATUS01',
#  'STATUS02',
#  'STATUS03',
#  'STATUS04',
#  'STATUS05',
#  'STATUS06',
#  'STATUS07',
#  'STATUS08',
#  'STATUS09',
#  'STATUS10',
#  'STATUS11',
#  'STATUS12',
#  'STATUS13',
#  'STATUS98',
#  'STATUS99',
#  'STITLEI',
#  'ST_LEAID',
#  'ST_SCHID',
#  'SURVYEAR',
#  'SY_STATUS',
#  'SY_STATUS15',
#  'SY_STATUS16',
#  'SY_STATUS_TEXT',
#  'TITLEI',
#  'TITLEI_STATUS',
#  'TITLEI_TEXT',
#  'TOTAL',
#  'TOTFRL',
#  'TR',
#  'TR01F',
#  'TR01M',
#  'TR02F',
#  'TR02M',
#  'TR03F',
#  'TR03M',
#  'TR04F',
#  'TR04M',
#  'TR05F',
#  'TR05M',
#  'TR06F',
#  'TR06M',
#  'TR07F',
#  'TR07M',
#  'TR08F',
#  'TR08M',
#  'TR09F',
#  'TR09M',
#  'TR10F',
#  'TR10M',
#  'TR11F',
#  'TR11M',
#  'TR12F',
#  'TR12M',
#  'TR13F',
#  'TR13M',
#  'TRAEF',
#  'TRAEM',
#  'TRALF',
#  'TRALM',
#  'TRKGF',
#  'TRKGM',
#  'TRPKF',
#  'TRPKM',
#  'TRUGF',
#  'TRUGM',
#  'UG',
#  'UGOFFERED',
#  'UNION',
#  'UPDATED_STATUS',
#  'UPDATED_STATUS_TEXT',
#  'VIRTUAL',
#  'WH',
#  'WH01F',
#  'WH01M',
#  'WH02F',
#  'WH02M',
#  'WH03F',
#  'WH03M',
#  'WH04F',
#  'WH04M',
#  'WH05F',
#  'WH05M',
#  'WH06F',
#  'WH06M',
#  'WH07F',
#  'WH07M',
#  'WH08F',
#  'WH08M',
#  'WH09F',
#  'WH09M',
#  'WH10F',
#  'WH10M',
#  'WH11F',
#  'WH11M',
#  'WH12F',
#  'WH12M',
#  'WH13F',
#  'WH13M',
#  'WHAEF',
#  'WHAEM',
#  'WHALF',
#  'WHALM',
#  'WHKGF',
#  'WHKGM',
#  'WHPKF',
#  'WHPKM',
#  'WHUGF',
#  'WHUGM',
#  'YEAR_CLOSED',
#  'YEAR_OPENED']

# %%
# Remove unnecessary columns from year opened/closed DF
df_openclose = df_openclose[["NCESSCH", "MEMBER", "TOTFRL", "TITLEI", "YEAR_OPENED", "YEAR_CLOSED"]]
df_openclose.head(10)
# Out:
#              NCESSCH  MEMBER  TOTFRL TITLEI  YEAR_OPENED  YEAR_CLOSED
# 0       1.000020e+10    -1.0    -1.0      M       1998.0          NaN
# 1       1.000020e+10     NaN     NaN    NaN       1998.0       2014.0
# 2       1.000020e+10    -1.0    -1.0      M       2003.0          NaN
# 3       1.000020e+10    -1.0    -1.0      M       2003.0          NaN
# 4       1.000020e+10    -1.0    -1.0      M       1998.0          NaN
# 5       1.000020e+10    -1.0    -1.0      M       1998.0          NaN
# 6       1.000020e+10    -1.0    -1.0      M       2006.0          NaN
# 7       1.000050e+10   677.0   280.0      1       1998.0          NaN
# 8       1.000050e+10  1171.0   370.0      1       1998.0          NaN
# 9       1.000050e+10   748.0   326.0      1       1998.0          NaN
# 10      1.000050e+10   813.0   396.0      1       1998.0          NaN
# 11      1.000050e+10   474.0   234.0      1       1998.0          NaN
# 12      1.000050e+10  1082.0   510.0      1       2009.0          NaN
# 13      1.000060e+10   420.0   247.0      1       1998.0          NaN
# 14      1.000060e+10   516.0   423.0      1       1998.0          NaN
# 15      1.000060e+10   139.0    81.0      1       1998.0          NaN
# 16      1.000060e+10   474.0   397.0      1       1998.0          NaN
# 17      1.000060e+10   590.0   410.0      1       1998.0          NaN
# 18      1.000060e+10   282.0   212.0      1       1998.0          NaN
# 19      1.000060e+10   476.0   201.0      1       1998.0          NaN
# 20      1.000060e+10   240.0   177.0      1       1998.0          NaN
# 21      1.000060e+10    -1.0    -1.0      2       2016.0          NaN
# 22      1.000060e+10    -1.0    -1.0      M       2016.0          NaN
# 23      1.000060e+10   495.0   405.0      1       1999.0          NaN
# 24      1.000060e+10   245.0   170.0      1       2001.0          NaN
# 25      1.000060e+10   371.0   234.0      1       2003.0          NaN
# 26      1.000060e+10   426.0   232.0      1       1998.0          NaN
# 27      1.000060e+10   462.0   377.0      1       1998.0          NaN
# 28      1.000060e+10   511.0   443.0      1       2012.0          NaN
# 29      1.000070e+10   490.0   208.0      1       1998.0          NaN
# ...              ...     ...     ...    ...          ...          ...
# 136774  6.300028e+11     NaN     NaN    NaN       2016.0          NaN
# 136775  6.300028e+11     NaN     NaN    NaN       2016.0          NaN
# 136776  6.300028e+11     NaN     NaN    NaN       2016.0          NaN
# 136777  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136778  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136779  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136780  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136781  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136782  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136783  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136784  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136785  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136786  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136787  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136788  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136789  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136790  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136791  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136792  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136793  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136794  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136795  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136796  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136797  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136798  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136799  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136800  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136801  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136802  6.300029e+11     NaN     NaN    NaN       2016.0          NaN
# 136803  6.600002e+11     NaN     NaN    NaN       2016.0          NaN
#
# [136804 rows x 6 columns]

# %%
# Prepare for merge by coercing 'NCESSCH' columns to type float64
df_scraped["NCESSCH"] = df_scraped["NCESSCH"].astype(float)
df_cmos["NCESSCH"] = df_cmos["NCESSCH"].astype(float)
df_openclose["NCESSCH"] = df_openclose["NCESSCH"].astype(float)
#df_r100["NCESSCH"] = df_r100["NCESSCH"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NCESSCH'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-b782e94d4a70> in <module>()
#       3 #df_cmos["NCESSCH"] = df_cmos["NCESSCH"].astype(float)
#       4 df_openclose["NCESSCH"] = df_openclose["NCESSCH"].astype(float)
# ----> 5 df_r100["NCESSCH"] = df_r100["NCESSCH"].astype(float)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NCESSCH'

# %%
# Add 'data' column from df_scraped to df_cmos, joining on 'NCESSCH'
df_full = pd.merge(df_cmos, df_scraped, how="outer", on="NCESSCH")

# %%
# Add columns from df_openclose to df_full, joining on 'NCESSCH'
df_full = pd.merge(df_full, df_openclose, how="outer", on="NCESSCH")

# %%
# Reduce memory load by converting dtypes:
#df_full = convert_df(df_full)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e0a315aed960> in <module>()
#       1 # Reduce memory load by converting dtypes:
# ----> 2 df_full = convert_df(df_full)
#
# <ipython-input-2-7d5256f56072> in convert_df(df)
#      12     for col in df.columns:
#      13         if col in df_obj:
# ---> 14             num_unique_values = len(df_obj[col].unique())
#      15             num_total_values = len(df_obj[col])
#      16             if (num_unique_values / num_total_values) < 0.5: # Only convert data types if at least half of values are duplicates
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py in unique(self)
#    1491         Categories (3, object): [a < b < c]
#    1492         """
# -> 1493         result = super(Series, self).unique()
#    1494
#    1495         if is_datetime64tz_dtype(self.dtype):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/base.py in unique(self)
#    1047         else:
#    1048             from pandas.core.algorithms import unique1d
# -> 1049             result = unique1d(values)
#    1050
#    1051         return result
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/algorithms.py in unique(values)
#     366
#     367     table = htable(len(values))
# --> 368     uniques = table.unique(values)
#     369     uniques = _reconstruct_data(uniques, dtype, original)
#     370
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# TypeError: unhashable type: 'list'

# %%
df_full.head(10)
# Out:
#    Unnamed: 0                              CMO_NAME  CMO_MEMSUM  \
# 0           0                                  AAEC      1320.0
# 1         295  Arizona Agribusiness & Equine Center      1320.0
# 2           1                                  AAEC      1320.0
# 3         296  Arizona Agribusiness & Equine Center      1320.0
# 4           2                                  AAEC      1320.0
# 5         297  Arizona Agribusiness & Equine Center      1320.0
# 6           3       ACADEMY OF SKILLS AND KNOWLEDGE      1161.0
# 7           4       ACADEMY OF SKILLS AND KNOWLEDGE      1161.0
# 8           5       ACADEMY OF SKILLS AND KNOWLEDGE      1161.0
# 9           6      ACCELERATED INTERMEDIATE ACADEMY       281.0
#
#                                           SCH_NAME CMO_STATE  CMO_SCHNUM  \
# 0  ARIZONA AGRIBUSINESS & EQUINE CENTER - ESTRELLA        AZ         6.0
# 1  ARIZONA AGRIBUSINESS & EQUINE CENTER - ESTRELLA        AZ         6.0
# 2                               AAEC - SMCC CAMPUS        AZ         6.0
# 3                               AAEC - SMCC CAMPUS        AZ         6.0
# 4                           AAEC - PARADISE VALLEY        AZ         6.0
# 5                           AAEC - PARADISE VALLEY        AZ         6.0
# 6                        CUMBERLAND ACADEMY MIDDLE        TX         4.0
# 7                                   CUMBERLAND H S        TX         4.0
# 8                               CUMBERLAND ACADEMY        TX         4.0
# 9               ACCELERATED INTERDISCIPLINARY ACAD        TX         3.0
#
#                              CMO_URL  CMO_NUMSTATES CMO_ALLSTATES CMO_SECTOR  \
# 0   https://www.aaechighschools.com/            1.0            AZ        NaN
# 1   https://www.aaechighschools.com/            1.0            AZ        CMO
# 2   https://www.aaechighschools.com/            1.0            AZ        NaN
# 3   https://www.aaechighschools.com/            1.0            AZ        CMO
# 4   https://www.aaechighschools.com/            1.0            AZ        NaN
# 5   https://www.aaechighschools.com/            1.0            AZ        CMO
# 6  http://www.cumberlandacademy.com/            1.0            TX        NaN
# 7  http://www.cumberlandacademy.com/            1.0            TX        NaN
# 8  http://www.cumberlandacademy.com/            1.0            TX        NaN
# 9  http://www.aiacharterschools.org/            1.0            TX        NaN
#
#       ...       POPTOT_S16 POP517_S16 CHILDPOV_S16 TRUE_CHARTER  \
# 0     ...              NaN        NaN          NaN            1
# 1     ...              NaN        NaN          NaN            1
# 2     ...              NaN        NaN          NaN            1
# 3     ...              NaN        NaN          NaN            1
# 4     ...              NaN        NaN          NaN            1
# 5     ...              NaN        NaN          NaN            1
# 6     ...              NaN        NaN          NaN            1
# 7     ...              NaN        NaN          NaN            1
# 8     ...              NaN        NaN          NaN            1
# 9     ...              NaN        NaN          NaN            1
#
#                                                 data MEMBER TOTFRL  TITLEI  \
# 0  [(https://www.aaechighschools.com/public-chart...  450.0   -1.0       1
# 1  [(https://www.aaechighschools.com/public-chart...  450.0   -1.0       1
# 2  [(https://www.aaechighschools.com/public-chart...  380.0  282.0       1
# 3  [(https://www.aaechighschools.com/public-chart...  380.0  282.0       1
# 4  [(https://www.aaechighschools.com/index.php, F...  386.0   -1.0       1
# 5  [(https://www.aaechighschools.com/index.php, F...  386.0   -1.0       1
# 6  [(https://ms.cumberlandacademy.com/, False, 0,...  528.0  193.0       1
# 7  [(https://hs.cumberlandacademy.com/, False, 0,...    NaN    NaN     NaN
# 8  [(https://elem.cumberlandacademy.com/, False, ...  502.0  204.0       1
# 9  [(http://www.aiacharterschools.org/, False, 0,...  254.0  243.0       1
#
#   YEAR_OPENED  YEAR_CLOSED
# 0      2010.0          NaN
# 1      2010.0          NaN
# 2      2005.0          NaN
# 3      2005.0          NaN
# 4      1998.0          NaN
# 5      1998.0          NaN
# 6      2013.0          NaN
# 7      2015.0          NaN
# 8      1998.0          NaN
# 9      2004.0          NaN
#
# [10 rows x 657 columns]

# %%
list(df_full)
# Out:
# ['Unnamed: 0',
#  'CMO_NAME',
#  'CMO_MEMSUM',
#  'SCH_NAME',
#  'CMO_STATE',
#  'CMO_SCHNUM',
#  'CMO_URL',
#  'CMO_NUMSTATES',
#  'CMO_ALLSTATES',
#  'CMO_SECTOR',
#  'CMO_NUMSTUDENTS_CREDO17',
#  'CMO_TYPE',
#  'CMO_WEBTEXT',
#  'SURVYEAR',
#  'FIPST',
#  'STABR',
#  'SEANAME',
#  'LEAID',
#  'ST_LEAID',
#  'SCHID',
#  'ST_SCHID',
#  'NCESSCH',
#  'MSTREET1',
#  'MSTREET2',
#  'MSTREET3',
#  'MCITY',
#  'MSTATE',
#  'MZIP',
#  'MZIP4',
#  'PHONE',
#  'LSTREET1',
#  'LSTREET2',
#  'LSTREET3',
#  'LCITY',
#  'LSTATE',
#  'LZIP',
#  'LZIP4',
#  'UNION',
#  'OUT_OF_STATE_FLAG',
#  'SCH_TYPE_TEXT',
#  'SCH_TYPE',
#  'RECON_STATUS',
#  'GSLO',
#  'GSHI',
#  'LEVEL',
#  'VIRTUAL',
#  'BIES',
#  'SY_STATUS_TEXT',
#  'SY_STATUS',
#  'UPDATED_STATUS_TEXT',
#  'UPDATED_STATUS',
#  'EFFECTIVE_DATE',
#  'CHARTER_TEXT',
#  'PKOFFERED',
#  'KGOFFERED',
#  'G1OFFERED',
#  'G2OFFERED',
#  'G3OFFERED',
#  'G4OFFERED',
#  'G5OFFERED',
#  'G6OFFERED',
#  'G7OFFERED',
#  'G8OFFERED',
#  'G9OFFERED',
#  'G10OFFERED',
#  'G11OFFERED',
#  'G12OFFERED',
#  'G13OFFERED',
#  'AEOFFERED',
#  'UGOFFERED',
#  'NOGRADES',
#  'CHARTAUTH1',
#  'CHARTAUTHN1',
#  'CHARTAUTH2',
#  'CHARTAUTHN2',
#  'IGOFFERED',
#  'WEBSITE',
#  'FRELCH',
#  'REDLCH',
#  'PK',
#  'KG',
#  'G01',
#  'G02',
#  'G03',
#  'G04',
#  'G05',
#  'G06',
#  'G07',
#  'G08',
#  'G09',
#  'G10',
#  'G11',
#  'G12',
#  'G13',
#  'UG',
#  'AE',
#  'TOTAL',
#  'AMPKM',
#  'AMPKF',
#  'ASPKM',
#  'ASPKF',
#  'HIPKM',
#  'HIPKF',
#  'BLPKM',
#  'BLPKF',
#  'WHPKM',
#  'WHPKF',
#  'HPPKM',
#  'HPPKF',
#  'TRPKM',
#  'TRPKF',
#  'AMKGM',
#  'AMKGF',
#  'ASKGM',
#  'ASKGF',
#  'HIKGM',
#  'HIKGF',
#  'BLKGM',
#  'BLKGF',
#  'WHKGM',
#  'WHKGF',
#  'HPKGM',
#  'HPKGF',
#  'TRKGM',
#  'TRKGF',
#  'AM01M',
#  'AM01F',
#  'AS01M',
#  'AS01F',
#  'HI01M',
#  'HI01F',
#  'BL01M',
#  'BL01F',
#  'WH01M',
#  'WH01F',
#  'HP01M',
#  'HP01F',
#  'TR01M',
#  'TR01F',
#  'AM02M',
#  'AM02F',
#  'AS02M',
#  'AS02F',
#  'HI02M',
#  'HI02F',
#  'BL02M',
#  'BL02F',
#  'WH02M',
#  'WH02F',
#  'HP02M',
#  'HP02F',
#  'TR02M',
#  'TR02F',
#  'AM03M',
#  'AM03F',
#  'AS03M',
#  'AS03F',
#  'HI03M',
#  'HI03F',
#  'BL03M',
#  'BL03F',
#  'WH03M',
#  'WH03F',
#  'HP03M',
#  'HP03F',
#  'TR03M',
#  'TR03F',
#  'AM04M',
#  'AM04F',
#  'AS04M',
#  'AS04F',
#  'HI04M',
#  'HI04F',
#  'BL04M',
#  'BL04F',
#  'WH04M',
#  'WH04F',
#  'HP04M',
#  'HP04F',
#  'TR04M',
#  'TR04F',
#  'AM05M',
#  'AM05F',
#  'AS05M',
#  'AS05F',
#  'HI05M',
#  'HI05F',
#  'BL05M',
#  'BL05F',
#  'WH05M',
#  'WH05F',
#  'HP05M',
#  'HP05F',
#  'TR05M',
#  'TR05F',
#  'AM06M',
#  'AM06F',
#  'AS06M',
#  'AS06F',
#  'HI06M',
#  'HI06F',
#  'BL06M',
#  'BL06F',
#  'WH06M',
#  'WH06F',
#  'HP06M',
#  'HP06F',
#  'TR06M',
#  'TR06F',
#  'AM07M',
#  'AM07F',
#  'AS07M',
#  'AS07F',
#  'HI07M',
#  'HI07F',
#  'BL07M',
#  'BL07F',
#  'WH07M',
#  'WH07F',
#  'HP07M',
#  'HP07F',
#  'TR07M',
#  'TR07F',
#  'AM08M',
#  'AM08F',
#  'AS08M',
#  'AS08F',
#  'HI08M',
#  'HI08F',
#  'BL08M',
#  'BL08F',
#  'WH08M',
#  'WH08F',
#  'HP08M',
#  'HP08F',
#  'TR08M',
#  'TR08F',
#  'AM09M',
#  'AM09F',
#  'AS09M',
#  'AS09F',
#  'HI09M',
#  'HI09F',
#  'BL09M',
#  'BL09F',
#  'WH09M',
#  'WH09F',
#  'HP09M',
#  'HP09F',
#  'TR09M',
#  'TR09F',
#  'AM10M',
#  'AM10F',
#  'AS10M',
#  'AS10F',
#  'HI10M',
#  'HI10F',
#  'BL10M',
#  'BL10F',
#  'WH10M',
#  'WH10F',
#  'HP10M',
#  'HP10F',
#  'TR10M',
#  'TR10F',
#  'AM11M',
#  'AM11F',
#  'AS11M',
#  'AS11F',
#  'HI11M',
#  'HI11F',
#  'BL11M',
#  'BL11F',
#  'WH11M',
#  'WH11F',
#  'HP11M',
#  'HP11F',
#  'TR11M',
#  'TR11F',
#  'AM12M',
#  'AM12F',
#  'AS12M',
#  'AS12F',
#  'HI12M',
#  'HI12F',
#  'BL12M',
#  'BL12F',
#  'WH12M',
#  'WH12F',
#  'HP12M',
#  'HP12F',
#  'TR12M',
#  'TR12F',
#  'AM13M',
#  'AM13F',
#  'AS13M',
#  'AS13F',
#  'HI13M',
#  'HI13F',
#  'BL13M',
#  'BL13F',
#  'WH13M',
#  'WH13F',
#  'HP13M',
#  'HP13F',
#  'TR13M',
#  'TR13F',
#  'AMUGM',
#  'AMUGF',
#  'ASUGM',
#  'ASUGF',
#  'HIUGM',
#  'HIUGF',
#  'BLUGM',
#  'BLUGF',
#  'WHUGM',
#  'WHUGF',
#  'HPUGM',
#  'HPUGF',
#  'TRUGM',
#  'TRUGF',
#  'AMAEM',
#  'AMAEF',
#  'ASAEM',
#  'ASAEF',
#  'HIAEM',
#  'HIAEF',
#  'BLAEM',
#  'BLAEF',
#  'WHAEM',
#  'WHAEF',
#  'HPAEM',
#  'HPAEF',
#  'TRAEM',
#  'TRAEF',
#  'AM',
#  'AMALM',
#  'AMALF',
#  'AS',
#  'ASALM',
#  'ASALF',
#  'HI',
#  'HIALM',
#  'HIALF',
#  'BL',
#  'BLALM',
#  'BLALF',
#  'WH',
#  'WHALM',
#  'WHALF',
#  'HP',
#  'HPALM',
#  'HPALF',
#  'TR',
#  'TRALM',
#  'TRALF',
#  'TITLEI_TEXT',
#  'TITLEI_STATUS',
#  'STITLEI',
#  'SHARED_TIME',
#  'MAGNET_TEXT',
#  'NSLPSTATUS_TEXT',
#  'NSLPSTATUS_CODE',
#  'NAME',
#  'OPSTFIPS',
#  'LSTREE',
#  'STFIP15',
#  'CNTY15',
#  'NMCNTY15',
#  'LOCALE15',
#  'LAT1516',
#  'LON1516',
#  'CBSA15',
#  'NMCBSA15',
#  'CBSATYPE15',
#  'CSA15',
#  'NMCSA15',
#  'NECTA15',
#  'NMNECTA15',
#  'CD15',
#  'SLDL15',
#  'SLDU15',
#  'Unnamed: 0.1',
#  'LSTREET114',
#  'LSTREET214',
#  'LSTREET314',
#  'LCITY14',
#  'LSTATE14',
#  'LZIP14',
#  'ISFLE',
#  'ISMEMPUP',
#  'ISPELM',
#  'ISPFEMALE',
#  'ISPWHITE',
#  'ISFTEPUP',
#  'SCHNAM98',
#  'CHARTR98',
#  'STATUS98',
#  'SCHNAM99',
#  'CHARTR99',
#  'STATUS99',
#  'SCHNAM00',
#  'CHARTR00',
#  'STATUS00',
#  'SCHNAM01',
#  'CHARTR01',
#  'STATUS01',
#  'SCHNAM02',
#  'CHARTR02',
#  'STATUS02',
#  'SCHNAM03',
#  'CHARTR03',
#  'STATUS03',
#  'SCHNAM04',
#  'CHARTR04',
#  'STATUS04',
#  'SCHNAM05',
#  'CHARTR05',
#  'STATUS05',
#  'SCHNAM06',
#  'CHARTR06',
#  'STATUS06',
#  'SCHNAM07',
#  'CHARTR07',
#  'STATUS07',
#  'SCHNAM08',
#  'CHARTR08',
#  'STATUS08',
#  'SCHNAM09',
#  'CHARTR09',
#  'STATUS09',
#  'SCHNAM10',
#  'CHARTR10',
#  'STATUS10',
#  'RECONSTY10',
#  'RECONSTF10',
#  'SCHNAM11',
#  'CHARTR11',
#  'STATUS11',
#  'RECONSTY11',
#  'RECONSTF11',
#  'SCHNAM12',
#  'CHARTR12',
#  'STATUS12',
#  'RECONSTY12',
#  'RECONSTF12',
#  'SCHNAM13',
#  'CHARTR13',
#  'STATUS13',
#  'RECONSTY13',
#  'RECONSTF13',
#  'SCHNAM15',
#  'CHARTER_TEXT15',
#  'SY_STATUS15',
#  'RECON_STATUS15',
#  'SCHNAM16',
#  'CHARTER_TEXT16',
#  'SY_STATUS16',
#  'RECON_STATUS16',
#  'PVI2017',
#  'PVI2014',
#  'CONUM',
#  'CONAME',
#  'CD',
#  'CBSA',
#  'CSA',
#  'NECTA',
#  'METMIC',
#  'ALL_MTH00NUMVALID_1415',
#  'ALL_RLA00NUMVALID_1415',
#  'LSTREET116',
#  'LSTREET216',
#  'LSTREET316',
#  'LCITY16',
#  'LSTATE16',
#  'LZIP16',
#  'ADDRESS16',
#  'ALL_RLA00NUMVALID_1516',
#  'ALL_RLA00PCTPROF_1516',
#  'ALL_MTH00NUMVALID_1516',
#  'ALL_MTH00PCTPROF_1516',
#  'ess_strength',
#  'prog_strength',
#  'SD_lv_PVI_2014',
#  'SD_lv_PVI_2017',
#  'Geo_FIPS',
#  'Geo_NAME',
#  'Geo_QName',
#  'Geo_STUSAB',
#  'Geo_SUMLEV',
#  'Geo_FILEID',
#  'Geo_LOGRECNO',
#  'Geo_STATE',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_GEOID',
#  'Geo_AREALAND',
#  'Geo_AREAWATR',
#  'SE_T002_001',
#  'SE_T002_002',
#  'SE_T002_003',
#  'PCT_SE_T009_002',
#  'PCT_SE_T009_003',
#  'PCT_SE_T009_004',
#  'PCT_SE_T009_005',
#  'PCT_SE_T013_002',
#  'PCT_SE_T013_003',
#  'PCT_SE_T013_004',
#  'PCT_SE_T013_005',
#  'PCT_SE_T013_006',
#  'PCT_SE_T013_007',
#  'PCT_SE_T013_008',
#  'SE_T165_001',
#  'PCT_SE_T165_002',
#  'PCT_SE_T165_003',
#  'PCT_SE_T165_016',
#  'PCT_SE_T165_017',
#  'PCT_SE_T167_002',
#  'PCT_SE_T167_008',
#  'SE_T022_001',
#  'PCT_SE_T022_002',
#  'PCT_SE_T022_003',
#  'PCT_SE_T022_004',
#  'PCT_SE_T022_005',
#  'PCT_SE_T022_006',
#  'SE_T025_001',
#  'PCT_SE_T025_002',
#  'PCT_SE_T025_003',
#  'PCT_SE_T025_004',
#  'PCT_SE_T025_005',
#  'PCT_SE_T025_006',
#  'PCT_SE_T025_007',
#  'PCT_SE_T025_008',
#  'SE_T028_001',
#  'PCT_SE_T028_002',
#  'PCT_SE_T028_003',
#  'PCT_SE_T029_002',
#  'PCT_SE_T029_003',
#  'PCT_SE_T029_004',
#  'PCT_SE_T029_005',
#  'PCT_SE_T029_006',
#  'PCT_SE_T029_007',
#  'PCT_SE_T029_008',
#  'PCT_SE_T029_009',
#  'PCT_SE_T029_010',
#  'PCT_SE_T029_011',
#  'SE_T030_001',
#  'PCT_SE_T030_002',
#  'PCT_SE_T030_003',
#  'PCT_SE_T037_002',
#  'PCT_SE_T037_003',
#  'PCT_SE_T048_002',
#  'PCT_SE_T048_003',
#  'PCT_SE_T049_002',
#  'PCT_SE_T049_003',
#  'PCT_SE_T049_004',
#  'PCT_SE_T049_005',
#  'PCT_SE_T049_006',
#  'PCT_SE_T049_007',
#  'PCT_SE_T049_008',
#  'PCT_SE_T049_009',
#  'PCT_SE_T049_010',
#  'PCT_SE_T049_011',
#  'PCT_SE_T049_012',
#  'PCT_SE_T049_013',
#  'PCT_SE_T049_014',
#  'PCT_SE_T053_006',
#  'SE_T057_001',
#  'SE_T058_002',
#  'SE_T058_003',
#  'SE_T058_004',
#  'SE_T058_005',
#  'SE_T058_006',
#  'SE_T058_007',
#  'SE_T058_008',
#  'SE_T058_009',
#  'SE_T058_010',
#  'SE_T083_001',
#  'SE_T157_001',
#  'SE_T098_001',
#  'SE_T101_001',
#  'PCT_SE_T103_002',
#  'PCT_SE_T103_003',
#  'PCT_SE_T103_004',
#  'PCT_SE_T103_005',
#  'PCT_SE_T103_006',
#  'PCT_SE_T113_002',
#  'PCT_SE_T113_011',
#  'SE_T114_001',
#  'PCT_SE_T114_002',
#  'PCT_SE_T114_003',
#  'PCT_SE_T130_002',
#  'PCT_SE_T130_003',
#  'PCT_SE_T130_004',
#  'PCT_SE_T130_005',
#  'PCT_SE_T130_006',
#  'PCT_SE_T133_002',
#  'PCT_SE_T133_003',
#  'PCT_SE_T133_004',
#  'PCT_SE_T133_005',
#  'PCT_SE_T139_002',
#  'PCT_SE_T139_034',
#  'PCT_SE_T139_067',
#  'PCT_SE_T139_085',
#  'PCT_SE_T139_090',
#  'SE_T145_001',
#  'PCT_SE_T145_002',
#  'PCT_SE_T145_003',
#  'PCT_SE_T145_004',
#  'PCT_SE_T145_005',
#  'close99',
#  'close00',
#  'close01',
#  'close02',
#  'close03',
#  'close04',
#  'close05',
#  'close06',
#  'close07',
#  'close08',
#  'close09',
#  'close10',
#  'close11',
#  'close12',
#  'close13',
#  'close14',
#  'close15',
#  'close16',
#  'close_rate99',
#  'close_rate00',
#  'close_rate01',
#  'close_rate02',
#  'close_rate03',
#  'close_rate04',
#  'close_rate05',
#  'close_rate06',
#  'close_rate07',
#  'close_rate08',
#  'close_rate09',
#  'close_rate10',
#  'close_rate11',
#  'close_rate12',
#  'close_rate13',
#  'close_rate14',
#  'close_rate15',
#  'close_rate16',
#  'POPTOT_S16',
#  'POP517_S16',
#  'CHILDPOV_S16',
#  'TRUE_CHARTER',
#  'data',
#  'MEMBER',
#  'TOTFRL',
#  'TITLEI',
#  'YEAR_OPENED',
#  'YEAR_CLOSED']

# %%
# Clean up columns a bit
df_full.rename(columns={'data':'WEBTEXT'}, inplace=True) # Rename 'data' to 'WEBTEXT'

df_full = df_full.drop(["Unnamed: 0", "Unnamed: 0.1"], axis=1) # Drop mystery columns

# %%
# Save this largesse file to full_path
df_full.to_pickle(full_path)

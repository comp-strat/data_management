# %%
import pandas as pd

# %% [markdown]
# ## Read new data and current pubschools data

# %%
#read new 2017-18 data 
new_data = pd.read_csv('ccd_sch_029_1718_w_0a_03302018.csv')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (15,22,39,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#read current pubschools data 
pubschools = pd.read_pickle('pubschools_full_2015.pkl')

# %% [markdown]
# ## Keep only variables needed in new data

# %%
def load_list(file_path):
    """Loads list into memory. Must be assigned to object.
    Input: Path to file
    Output: List object"""
    
    textlist = []
    with open(file_path) as file_handler:
        line = file_handler.readline()
        while line:
            textlist.append(line)
            line = file_handler.readline()
    return textlist

# %%
#read variables to keep 
vars_to_keep = ['TOT_LEPENR_M', 'TOT_LEPENR_F', 'TOT_LEPPROGENR_M', 'TOT_LEPPROGENR_F', 'TOT_IDEAENR_M', 'TOT_IDEAENR_F', 'SCH_IDEAENR_LEP_M', 'SCH_IDEAENR_LEP_F', 'TOT_504ENR_M', 'TOT_504ENR_F', 'TOT_GTENR_M', 'TOT_GTENR_F', 'SCH_CREDITRECOVERYENR', 'SCH_APCOURSES', 'TOT_APENR_M', 'TOT_APENR_F', 'TOT_APEXAM_ONEORMORE_M', 'TOT_APEXAM_ONEORMORE_F', 'TOT_APEXAM_NONE_M', 'TOT_APEXAM_NONE_F', 'TOT_APPASS_ONEORMORE_M', 'TOT_APPASS_ONEORMORE_F', 'TOT_APPASS_NONE_M', 'TOT_APPASS_NONE_F', 'TOT_IBENR_M', 'TOT_IBENR_F', 'TOT_SATACT_M', 'TOT_SATACT_F', 'SCH_PSDISC_CORP_HI_M', 'SCH_PSDISC_CORP_HI_F', 'SCH_PSDISC_CORP_AM_M', 'SCH_PSDISC_CORP_AM_F', 'SCH_PSDISC_CORP_AS_M', 'SCH_PSDISC_CORP_AS_F', 'SCH_PSDISC_CORP_HP_M', 'SCH_PSDISC_CORP_HP_F', 'SCH_PSDISC_CORP_BL_M', 'SCH_PSDISC_CORP_BL_F', 'SCH_PSDISC_CORP_WH_M', 'SCH_PSDISC_CORP_WH_F', 'SCH_PSDISC_CORP_TR_M', 'SCH_PSDISC_CORP_TR_F', 'TOT_PSDISC_CORP_M', 'TOT_PSDISC_CORP_F', 'SCH_PSDISC_CORP_LEP_M', 'SCH_PSDISC_CORP_LEP_F', 'SCH_PSDISC_CORP_IDEA_M', 'SCH_PSDISC_CORP_IDEA_F', 'SCH_PSCORPINSTANCES_ALL', 'TOT_PSDISC_SINGOOS_M', 'TOT_PSDISC_SINGOOS_F', 'TOT_PSDISC_MULTOOS_M', 'TOT_PSDISC_MULTOOS_F', 'SCH_PSOOSINSTANCES_ALL', 'SCH_PSOOSINSTANCES_IDEA', 'SCH_OOSINSTANCES_WODIS', 'SCH_OOSINSTANCES_IDEA', 'SCH_OOSINSTANCES_504', 'SCH_DAYSMISSED_HI_M', 'SCH_DAYSMISSED_HI_F', 'SCH_DAYSMISSED_AM_M', 'SCH_DAYSMISSED_AM_F', 'SCH_DAYSMISSED_AS_M', 'SCH_DAYSMISSED_AS_F', 'SCH_DAYSMISSED_HP_M', 'SCH_DAYSMISSED_HP_F', 'SCH_DAYSMISSED_BL_M', 'SCH_DAYSMISSED_BL_F', 'SCH_DAYSMISSED_WH_M', 'SCH_DAYSMISSED_WH_F', 'SCH_DAYSMISSED_TR_M', 'SCH_DAYSMISSED_TR_F', 'TOT_DAYSMISSED_M', 'TOT_DAYSMISSED_F', 'SCH_DAYSMISSED_LEP_M', 'SCH_DAYSMISSED_LEP_F', 'SCH_DAYSMISSED_504_M', 'SCH_DAYSMISSED_504_F', 'SCH_DAYSMISSED_IDEA_M', 'SCH_DAYSMISSED_IDEA_F', 'SCH_PSDISC_EXP_HI_M', 'SCH_PSDISC_EXP_HI_F', 'SCH_PSDISC_EXP_AM_M', 'SCH_PSDISC_EXP_AM_F', 'SCH_PSDISC_EXP_AS_M', 'SCH_PSDISC_EXP_AS_F', 'SCH_PSDISC_EXP_HP_M', 'SCH_PSDISC_EXP_HP_F', 'SCH_PSDISC_EXP_BL_M', 'SCH_PSDISC_EXP_BL_F', 'SCH_PSDISC_EXP_WH_M', 'SCH_PSDISC_EXP_WH_F', 'SCH_PSDISC_EXP_TR_M', 'SCH_PSDISC_EXP_TR_F', 'TOT_PSDISC_EXP_M', 'TOT_PSDISC_EXP_F', 'SCH_PSDISC_EXP_LEP_M', 'SCH_PSDISC_EXP_LEP_F', 'SCH_PSDISC_EXP_IDEA_M', 'SCH_PSDISC_EXP_IDEA_F', 'TOT_DISCWODIS_EXPWE_M', 'TOT_DISCWODIS_EXPWE_F', 'TOT_DISCWODIS_EXPWOE_M', 'TOT_DISCWODIS_EXPWOE_F', 'SCH_DISCWODIS_EXPZT_HI_M', 'SCH_DISCWODIS_EXPZT_HI_F', 'SCH_DISCWODIS_EXPZT_AM_M', 'SCH_DISCWODIS_EXPZT_AM_F', 'SCH_DISCWODIS_EXPZT_AS_M', 'SCH_DISCWODIS_EXPZT_AS_F', 'SCH_DISCWODIS_EXPZT_HP_M', 'SCH_DISCWODIS_EXPZT_HP_F', 'SCH_DISCWODIS_EXPZT_BL_M', 'SCH_DISCWODIS_EXPZT_BL_F', 'SCH_DISCWODIS_EXPZT_WH_M', 'SCH_DISCWODIS_EXPZT_WH_F', 'SCH_DISCWODIS_EXPZT_TR_M', 'SCH_DISCWODIS_EXPZT_TR_F', 'TOT_DISCWODIS_EXPZT_M', 'TOT_DISCWODIS_EXPZT_F', 'SCH_DISCWODIS_EXPZT_LEP_M', 'SCH_DISCWODIS_EXPZT_LEP_F', 'TOT_DISCWDIS_EXPWE_IDEA_M', 'TOT_DISCWDIS_EXPWE_IDEA_F', 'TOT_DISCWDIS_EXPWOE_IDEA_M', 'TOT_DISCWDIS_EXPWOE_IDEA_F', 'SCH_DISCWDIS_EXPZT_IDEA_HI_M', 'SCH_DISCWDIS_EXPZT_IDEA_HI_F', 'SCH_DISCWDIS_EXPZT_IDEA_AM_M', 'SCH_DISCWDIS_EXPZT_IDEA_AM_F', 'SCH_DISCWDIS_EXPZT_IDEA_AS_M', 'SCH_DISCWDIS_EXPZT_IDEA_AS_F', 'SCH_DISCWDIS_EXPZT_IDEA_HP_M', 'SCH_DISCWDIS_EXPZT_IDEA_HP_F', 'SCH_DISCWDIS_EXPZT_IDEA_BL_M', 'SCH_DISCWDIS_EXPZT_IDEA_BL_F', 'SCH_DISCWDIS_EXPZT_IDEA_WH_M', 'SCH_DISCWDIS_EXPZT_IDEA_WH_F', 'SCH_DISCWDIS_EXPZT_IDEA_TR_M', 'SCH_DISCWDIS_EXPZT_IDEA_TR_F', 'TOT_DISCWDIS_EXPZT_IDEA_M', 'TOT_DISCWDIS_EXPZT_IDEA_F', 'SCH_DISCWDIS_EXPZT_LEP_M', 'SCH_DISCWDIS_EXPZT_LEP_F', 'SCH_DISCWDIS_EXPZT_504_M', 'SCH_DISCWDIS_EXPZT_504_F', 'TOT_DISCWODIS_TFRALT_M', 'TOT_DISCWODIS_TFRALT_F', 'TOT_DISCWDIS_TFRALT_IDEA_M', 'TOT_DISCWDIS_TFRALT_IDEA_F', 'TOT_DISCWODIS_REF_M', 'TOT_DISCWODIS_REF_F', 'TOT_DISCWDIS_REF_IDEA_M', 'TOT_DISCWDIS_REF_IDEA_F', 'TOT_DISCWODIS_ARR_M', 'TOT_DISCWODIS_ARR_F', 'TOT_DISCWDIS_ARR_IDEA_M', 'TOT_DISCWDIS_ARR_IDEA_F', 'SCH_OFFENSE_RAPE', 'SCH_OFFENSE_BATT', 'SCH_OFFENSE_ROBWW', 'SCH_OFFENSE_ROBWX', 'SCH_OFFENSE_ROBWOW', 'SCH_OFFENSE_ATTWW', 'SCH_OFFENSE_ATTWX', 'SCH_OFFENSE_ATTWOW', 'SCH_OFFENSE_THRWW', 'SCH_OFFENSE_THRWX', 'SCH_OFFENSE_THRWOW', 'SCH_OFFENSE_POSSWX', 'TOT_RS_NONIDEA_MECH_M', 'TOT_RS_NONIDEA_MECH_F', 'TOT_RS_NONIDEA_PHYS_M', 'TOT_RS_NONIDEA_PHYS_F', 'TOT_RS_NONIDEA_SECL_M', 'TOT_RS_NONIDEA_SECL_F', 'TOT_RS_IDEA_MECH_M', 'TOT_RS_IDEA_MECH_F', 'TOT_RS_IDEA_PHYS_M', 'TOT_RS_IDEA_PHYS_F', 'TOT_RS_IDEA_SECL_M', 'TOT_RS_IDEA_SECL_F', 'SCH_RSINSTANCES_MECH_WODIS', 'SCH_RSINSTANCES_MECH_IDEA', 'SCH_RSINSTANCES_MECH_504', 'SCH_RSINSTANCES_PHYS_WODIS', 'SCH_RSINSTANCES_PHYS_IDEA', 'SCH_RSINSTANCES_PHYS_504', 'SCH_RSINSTANCES_SECL_WODIS', 'SCH_RSINSTANCES_SECL_IDEA', 'SCH_RSINSTANCES_SECL_504', 'SCH_HBALLEGATIONS_SEX', 'SCH_HBALLEGATIONS_RAC', 'SCH_HBALLEGATIONS_DIS', 'SCH_HBALLEGATIONS_ORI', 'SCH_HBALLEGATIONS_REL', 'TOT_HBREPORTED_SEX_M', 'TOT_HBREPORTED_SEX_F', 'TOT_HBREPORTED_RAC_M', 'TOT_HBREPORTED_RAC_F', 'TOT_HBREPORTED_DIS_M', 'TOT_HBREPORTED_DIS_F', 'TOT_ABSENT_M', 'TOT_ABSENT_F', 'TOT_RET_KG_M', 'TOT_RET_KG_F', 'TOT_RET_G01_M', 'TOT_RET_G01_F', 'TOT_RET_G02_M', 'TOT_RET_G02_F', 'TOT_RET_G03_M', 'TOT_RET_G03_F', 'TOT_RET_G04_M', 'TOT_RET_G04_F', 'TOT_RET_G05_M', 'TOT_RET_G05_F', 'TOT_RET_G06_M', 'TOT_RET_G06_F', 'TOT_RET_G07_M', 'TOT_RET_G07_F', 'TOT_RET_G08_M', 'TOT_RET_G08_F', 'TOT_RET_G09_M', 'TOT_RET_G09_F', 'TOT_RET_G10_M', 'TOT_RET_G10_F', 'TOT_RET_G11_M', 'TOT_RET_G11_F', 'TOT_RET_G12_M', 'TOT_RET_G12_F', 'TOT_SSPART', 'SCH_FTE_TEACH_WOFED', 'SCH_NPE_WOFED', 'SCH_FTE_AID_WOFED', 'SCH_FTE_SUP_WOFED', 'SCH_FTE_ADM_WOFED', 'SCH_FTE_AID_WFED', 'SCH_FTE_SUP_WFED', 'SCH_FTE_ADM_WFED', 'SCH_FTETEACH_TOT', 'SCH_FTETEACH_CERT', 'SCH_FTETEACH_NOTCERT', 'SCH_FTETEACH_FY', 'SCH_FTETEACH_SY', 'SCH_TEACHERS_CURR_TOT', 'SCH_TEACHERS_PREV_TOT', 'SCH_FTECOUNSELORS', 'SCH_FTETEACH_ABSENT', 'SCH_FTESECURITY_LEO', 'SCH_FTESECURITY_GUA', 'SCH_FTESERVICES_NUR', 'SCH_FTESERVICES_PSY', 'SCH_FTESERVICES_SOC', 'SCH_CREDITRECOVERY_IND', 'SCH_SSCLASSES_IND', 'SCH_APENR_IND', 'SCH_IBENR_IND', 'SCH_CORPINSTANCES_IND', 'SCH_FIREARM_IND', 'SCH_HOMICIDE_IND', 'SCH_RET_KG_IND', 'SCH_RET_G01_IND', 'SCH_RET_G02_IND', 'SCH_RET_G03_IND', 'SCH_RET_G04_IND', 'SCH_RET_G05_IND', 'SCH_RET_G06_IND', 'SCH_RET_G07_IND', 'SCH_RET_G08_IND', 'SCH_RET_G09_IND', 'SCH_RET_G10_IND', 'SCH_RET_G11_IND', 'SCH_RET_G12_IND', 'SCH_SSATHLETICS_IND']

# %%
new_data
# Out:
#       SCHOOL_YEAR  FIPST       STATENAME  ST  \
# 0       2017-2018      1         ALABAMA  AL
# 1       2017-2018      1         ALABAMA  AL
# 2       2017-2018      1         ALABAMA  AL
# 3       2017-2018      1         ALABAMA  AL
# 4       2017-2018      1         ALABAMA  AL
# 5       2017-2018      1         ALABAMA  AL
# 6       2017-2018      1         ALABAMA  AL
# 7       2017-2018      1         ALABAMA  AL
# 8       2017-2018      1         ALABAMA  AL
# 9       2017-2018      1         ALABAMA  AL
# 10      2017-2018      1         ALABAMA  AL
# 11      2017-2018      1         ALABAMA  AL
# 12      2017-2018      1         ALABAMA  AL
# 13      2017-2018      1         ALABAMA  AL
# 14      2017-2018      1         ALABAMA  AL
# 15      2017-2018      1         ALABAMA  AL
# 16      2017-2018      1         ALABAMA  AL
# 17      2017-2018      1         ALABAMA  AL
# 18      2017-2018      1         ALABAMA  AL
# 19      2017-2018      1         ALABAMA  AL
# 20      2017-2018      1         ALABAMA  AL
# 21      2017-2018      1         ALABAMA  AL
# 22      2017-2018      1         ALABAMA  AL
# 23      2017-2018      1         ALABAMA  AL
# 24      2017-2018      1         ALABAMA  AL
# 25      2017-2018      1         ALABAMA  AL
# 26      2017-2018      1         ALABAMA  AL
# 27      2017-2018      1         ALABAMA  AL
# 28      2017-2018      1         ALABAMA  AL
# 29      2017-2018      1         ALABAMA  AL
# ...           ...    ...             ...  ..
# 65478   2017-2018     37  NORTH CAROLINA  NC
# 65479   2017-2018     37  NORTH CAROLINA  NC
# 65480   2017-2018     37  NORTH CAROLINA  NC
# 65481   2017-2018     37  NORTH CAROLINA  NC
# 65482   2017-2018     37  NORTH CAROLINA  NC
# 65483   2017-2018     37  NORTH CAROLINA  NC
# 65484   2017-2018     37  NORTH CAROLINA  NC
# 65485   2017-2018     37  NORTH CAROLINA  NC
# 65486   2017-2018     37  NORTH CAROLINA  NC
# 65487   2017-2018     37  NORTH CAROLINA  NC
# 65488   2017-2018     37  NORTH CAROLINA  NC
# 65489   2017-2018     37  NORTH CAROLINA  NC
# 65490   2017-2018     37  NORTH CAROLINA  NC
# 65491   2017-2018     37  NORTH CAROLINA  NC
# 65492   2017-2018     37  NORTH CAROLINA  NC
# 65493   2017-2018     37  NORTH CAROLINA  NC
# 65494   2017-2018     37  NORTH CAROLINA  NC
# 65495   2017-2018     37  NORTH CAROLINA  NC
# 65496   2017-2018     37  NORTH CAROLINA  NC
# 65497   2017-2018     37  NORTH CAROLINA  NC
# 65498   2017-2018     37  NORTH CAROLINA  NC
# 65499   2017-2018     37  NORTH CAROLINA  NC
# 65500   2017-2018     37  NORTH CAROLINA  NC
# 65501   2017-2018     37  NORTH CAROLINA  NC
# 65502   2017-2018     37  NORTH CAROLINA  NC
# 65503   2017-2018     37  NORTH CAROLINA  NC
# 65504   2017-2018     37  NORTH CAROLINA  NC
# 65505   2017-2018     37  NORTH CAROLINA  NC
# 65506   2017-2018     37  NORTH CAROLINA  NC
# 65507   2017-2018     37  NORTH CAROLINA  NC
#
#                                    SCH_NAME                  LEA_NAME  \
# 0                 Albertville Middle School          Albertville City
# 1                   Albertville High School          Albertville City
# 2                   Evans Elementary School          Albertville City
# 3             Albertville Elementary School          Albertville City
# 4       Big Spring Lake Kindergarten School          Albertville City
# 5                Albertville Primary School          Albertville City
# 6              Kate Duncan Smith DAR Middle           Marshall County
# 7                        Asbury High School           Marshall County
# 8                         Claysville School           Marshall County
# 9                 Douglas Elementary School           Marshall County
# 10                      Douglas High School           Marshall County
# 11      Brindlee Mountain Elementary School           Marshall County
# 12             Kate D Smith DAR High School           Marshall County
# 13         Brindlee Mountain Primary School           Marshall County
# 14              Marshall Alternative School           Marshall County
# 15                Marshall Technical School           Marshall County
# 16                  Robert D Sloman Primary           Marshall County
# 17          Brindlee Mountain Middle School           Marshall County
# 18            Brindlee Mountain High School           Marshall County
# 19       Kate D Smith DAR Elementary School           Marshall County
# 20                    Douglas Middle School           Marshall County
# 21                 Asbury Elementary School           Marshall County
# 22        Trace Crossings Elementary School               Hoover City
# 23              Greystone Elementary School               Hoover City
# 24                       Hoover High School               Hoover City
# 25                      Berry Middle School               Hoover City
# 26     South Shades Crest Elementary School               Hoover City
# 27            Robert F Bumpus Middle School               Hoover City
# 28                   Spain Park High School               Hoover City
# 29            Deer Valley Elementary School               Hoover City
# ...                                     ...                       ...
# 65478                 W T Griggs Elementary  Currituck County Schools
# 65479               Currituck County Middle  Currituck County Schools
# 65480              Knotts Island Elementary  Currituck County Schools
# 65481                     Moyock Elementary  Currituck County Schools
# 65482            Shawboro Elementary School  Currituck County Schools
# 65483                         Moyock Middle  Currituck County Schools
# 65484            The JP Knapp ECH (i)School  Currituck County Schools
# 65485                 Jarvisburg Elementary  Currituck County Schools
# 65486        Cape Hatteras Secondary School       Dare County Schools
# 65487          Kitty Hawk Elementary School       Dare County Schools
# 65488              Manteo Elementary School       Dare County Schools
# 65489                    Manteo High School       Dare County Schools
# 65490       Cape Hatteras Elementary School       Dare County Schools
# 65491                 Dare Learning Academy       Dare County Schools
# 65492                  Manteo Middle School       Dare County Schools
# 65493        First Flight Elementary School       Dare County Schools
# 65494            First Flight Middle School       Dare County Schools
# 65495              First Flight High School       Dare County Schools
# 65496           Nags Head Elementary School       Dare County Schools
# 65497               Central Davidson Middle   Davidson County Schools
# 65498                 Central Davidson High   Davidson County Schools
# 65499                  Stoner-Thomas School   Davidson County Schools
# 65500                 Churchland Elementary   Davidson County Schools
# 65501           Davidson County High School   Davidson County Schools
# 65502             Davis-Townsend Elementary   Davidson County Schools
# 65503                     Denton Elementary   Davidson County Schools
# 65504                 E Lawson Brown Middle   Davidson County Schools
# 65505                    East Davidson High   Davidson County Schools
# 65506                 Fair Grove Elementary   Davidson County Schools
# 65507                      Hasty Elementary   Davidson County Schools
#
#        STATE_AGENCY_NO  UNION ST_LEAID    LEAID     ...      G_10_OFFERED  \
# 0                    1    NaN   AL-101   100005     ...                No
# 1                    1    NaN   AL-101   100005     ...               Yes
# 2                    1    NaN   AL-101   100005     ...                No
# 3                    1    NaN   AL-101   100005     ...                No
# 4                    1    NaN   AL-101   100005     ...                No
# 5                    1    NaN   AL-101   100005     ...                No
# 6                    1    NaN   AL-048   100006     ...                No
# 7                    1    NaN   AL-048   100006     ...               Yes
# 8                    1    NaN   AL-048   100006     ...                No
# 9                    1    NaN   AL-048   100006     ...                No
# 10                   1    NaN   AL-048   100006     ...               Yes
# 11                   1    NaN   AL-048   100006     ...                No
# 12                   1    NaN   AL-048   100006     ...               Yes
# 13                   1    NaN   AL-048   100006     ...                No
# 14                   1    NaN   AL-048   100006     ...               Yes
# 15                   1    NaN   AL-048   100006     ...               Yes
# 16                   1    NaN   AL-048   100006     ...                No
# 17                   1    NaN   AL-048   100006     ...                No
# 18                   1    NaN   AL-048   100006     ...               Yes
# 19                   1    NaN   AL-048   100006     ...                No
# 20                   1    NaN   AL-048   100006     ...                No
# 21                   1    NaN   AL-048   100006     ...                No
# 22                   1    NaN   AL-158   100007     ...                No
# 23                   1    NaN   AL-158   100007     ...                No
# 24                   1    NaN   AL-158   100007     ...               Yes
# 25                   1    NaN   AL-158   100007     ...                No
# 26                   1    NaN   AL-158   100007     ...                No
# 27                   1    NaN   AL-158   100007     ...                No
# 28                   1    NaN   AL-158   100007     ...               Yes
# 29                   1    NaN   AL-158   100007     ...                No
# ...                ...    ...      ...      ...     ...               ...
# 65478                1    NaN   NC-270  3701080     ...                No
# 65479                1    NaN   NC-270  3701080     ...                No
# 65480                1    NaN   NC-270  3701080     ...                No
# 65481                1    NaN   NC-270  3701080     ...                No
# 65482                1    NaN   NC-270  3701080     ...                No
# 65483                1    NaN   NC-270  3701080     ...                No
# 65484                1    NaN   NC-270  3701080     ...               Yes
# 65485                1    NaN   NC-270  3701080     ...                No
# 65486                1    NaN   NC-280  3701110     ...               Yes
# 65487                1    NaN   NC-280  3701110     ...                No
# 65488                1    NaN   NC-280  3701110     ...                No
# 65489                1    NaN   NC-280  3701110     ...               Yes
# 65490                1    NaN   NC-280  3701110     ...                No
# 65491                1    NaN   NC-280  3701110     ...               Yes
# 65492                1    NaN   NC-280  3701110     ...                No
# 65493                1    NaN   NC-280  3701110     ...                No
# 65494                1    NaN   NC-280  3701110     ...                No
# 65495                1    NaN   NC-280  3701110     ...               Yes
# 65496                1    NaN   NC-280  3701110     ...                No
# 65497                1    NaN   NC-290  3701140     ...                No
# 65498                1    NaN   NC-290  3701140     ...               Yes
# 65499                1    NaN   NC-290  3701140     ...               Yes
# 65500                1    NaN   NC-290  3701140     ...                No
# 65501                1    NaN   NC-290  3701140     ...               Yes
# 65502                1    NaN   NC-290  3701140     ...                No
# 65503                1    NaN   NC-290  3701140     ...                No
# 65504                1    NaN   NC-290  3701140     ...                No
# 65505                1    NaN   NC-290  3701140     ...               Yes
# 65506                1    NaN   NC-290  3701140     ...                No
# 65507                1    NaN   NC-290  3701140     ...               NaN
#
#        G_11_OFFERED  G_12_OFFERED G_13_OFFERED G_UG_OFFERED G_AE_OFFERED GSLO  \
# 0                No            No           No           No           No   07
# 1               Yes           Yes           No           No           No   09
# 2                No            No           No           No           No   05
# 3                No            No           No           No           No   03
# 4                No            No           No           No           No   KG
# 5                No            No           No           No           No   01
# 6                No            No           No           No           No   05
# 7               Yes           Yes           No           No           No   06
# 8                No            No           No           No           No   PK
# 9                No            No           No           No           No   03
# 10              Yes           Yes           No           No           No   09
# 11               No            No           No           No           No   03
# 12              Yes           Yes           No           No           No   09
# 13               No            No           No           No           No   PK
# 14              Yes           Yes           No           No           No   03
# 15              Yes           Yes           No           No           No   10
# 16               No            No           No           No           No   PK
# 17               No            No           No           No           No   06
# 18              Yes           Yes           No           No           No   06
# 19               No            No           No           No           No   KG
# 20               No            No           No           No           No   06
# 21               No            No           No           No           No   PK
# 22               No            No           No           No           No   KG
# 23               No            No           No           No           No   KG
# 24              Yes           Yes           No           No           No   09
# 25               No            No           No           No           No   06
# 26               No            No           No           No           No   KG
# 27               No            No           No           No           No   07
# 28              Yes           Yes           No           No           No   09
# 29               No            No           No           No           No   KG
# ...             ...           ...          ...          ...          ...  ...
# 65478            No            No           No           No           No   PK
# 65479            No            No           No           No           No   06
# 65480            No            No           No           No           No   KG
# 65481            No            No           No           No           No   KG
# 65482            No            No           No           No           No   KG
# 65483            No            No           No           No           No   06
# 65484           Yes           Yes          Yes           No           No   09
# 65485            No            No           No           No           No   KG
# 65486           Yes           Yes           No           No           No   06
# 65487            No            No           No           No           No   KG
# 65488            No            No           No           No           No   PK
# 65489           Yes           Yes           No           No           No   09
# 65490            No            No           No           No           No   PK
# 65491           Yes           Yes           No           No           No   09
# 65492            No            No           No           No           No   06
# 65493            No            No           No           No           No   PK
# 65494            No            No           No           No           No   06
# 65495           Yes           Yes           No           No           No   09
# 65496            No            No           No           No           No   PK
# 65497            No            No           No           No           No   06
# 65498           Yes           Yes           No           No           No   09
# 65499           Yes           Yes           No           No           No   KG
# 65500            No            No           No           No           No   PK
# 65501           Yes           Yes           No           No           No   06
# 65502            No            No           No           No           No   PK
# 65503            No            No           No           No           No   PK
# 65504            No            No           No           No           No   06
# 65505           Yes           Yes           No           No           No   09
# 65506            No            No           No           No           No   PK
# 65507           NaN           NaN          NaN          NaN          NaN  NaN
#
#       GSHI       LEVEL    IGOFFERED
# 0       08      Middle  As reported
# 1       12        High  As reported
# 2       06      Middle  As reported
# 3       04  Elementary  As reported
# 4       KG  Elementary  As reported
# 5       02  Elementary  As reported
# 6       08      Middle  As reported
# 7       12       Other  As reported
# 8       04  Elementary  As reported
# 9       05  Elementary  As reported
# 10      12        High  As reported
# 11      05  Elementary  As reported
# 12      12        High  As reported
# 13      02  Elementary  As reported
# 14      12       Other  As reported
# 15      12        High  As reported
# 16      02  Elementary  As reported
# 17      08      Middle  As reported
# 18      12       Other  As reported
# 19      04  Elementary  As reported
# 20      08      Middle  As reported
# 21      05  Elementary  As reported
# 22      04  Elementary  As reported
# 23      05  Elementary  As reported
# 24      12        High  As reported
# 25      08      Middle  As reported
# 26      04  Elementary  As reported
# 27      08      Middle  As reported
# 28      12        High  As reported
# 29      04  Elementary  As reported
# ...    ...         ...          ...
# 65478   05  Elementary  As reported
# 65479   08      Middle  As reported
# 65480   05  Elementary  As reported
# 65481   05  Elementary  As reported
# 65482   05  Elementary  As reported
# 65483   08      Middle  As reported
# 65484   13        High  As reported
# 65485   05  Elementary  As reported
# 65486   12       Other  As reported
# 65487   05  Elementary  As reported
# 65488   05  Elementary  As reported
# 65489   12        High  As reported
# 65490   05  Elementary  As reported
# 65491   12        High  As reported
# 65492   08      Middle  As reported
# 65493   05  Elementary  As reported
# 65494   08      Middle  As reported
# 65495   12        High  As reported
# 65496   05  Elementary  As reported
# 65497   08      Middle  As reported
# 65498   12        High  As reported
# 65499   12       Other  As reported
# 65500   05  Elementary  As reported
# 65501   12       Other  As reported
# 65502   05  Elementary  As reported
# 65503   05  Elementary  As reported
# 65504   08      Middle  As reported
# 65505   12        High  As reported
# 65506   05  Elementary  As reported
# 65507  NaN         NaN          NaN
#
# [65508 rows x 65 columns]

# %%
filtered_new_data = new_data[vars_to_keep]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-d2765f9b4186> in <module>()
# ----> 1 filtered_new_data = new_data[vars_to_keep]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['TOT_LEPENR_M' 'TOT_LEPENR_F' 'TOT_LEPPROGENR_M' 'TOT_LEPPROGENR_F'\n 'TOT_IDEAENR_M' 'TOT_IDEAENR_F' 'SCH_IDEAENR_LEP_M' 'SCH_IDEAENR_LEP_F'\n 'TOT_504ENR_M' 'TOT_504ENR_F' 'TOT_GTENR_M' 'TOT_GTENR_F'\n 'SCH_CREDITRECOVERYENR' 'SCH_APCOURSES' 'TOT_APENR_M' 'TOT_APENR_F'\n 'TOT_APEXAM_ONEORMORE_M' 'TOT_APEXAM_ONEORMORE_F' 'TOT_APEXAM_NONE_M'\n 'TOT_APEXAM_NONE_F' 'TOT_APPASS_ONEORMORE_M' 'TOT_APPASS_ONEORMORE_F'\n 'TOT_APPASS_NONE_M' 'TOT_APPASS_NONE_F' 'TOT_IBENR_M' 'TOT_IBENR_F'\n 'TOT_SATACT_M' 'TOT_SATACT_F' 'SCH_PSDISC_CORP_HI_M'\n 'SCH_PSDISC_CORP_HI_F' 'SCH_PSDISC_CORP_AM_M' 'SCH_PSDISC_CORP_AM_F'\n 'SCH_PSDISC_CORP_AS_M' 'SCH_PSDISC_CORP_AS_F' 'SCH_PSDISC_CORP_HP_M'\n 'SCH_PSDISC_CORP_HP_F' 'SCH_PSDISC_CORP_BL_M' 'SCH_PSDISC_CORP_BL_F'\n 'SCH_PSDISC_CORP_WH_M' 'SCH_PSDISC_CORP_WH_F' 'SCH_PSDISC_CORP_TR_M'\n 'SCH_PSDISC_CORP_TR_F' 'TOT_PSDISC_CORP_M' 'TOT_PSDISC_CORP_F'\n 'SCH_PSDISC_CORP_LEP_M' 'SCH_PSDISC_CORP_LEP_F' 'SCH_PSDISC_CORP_IDEA_M'\n 'SCH_PSDISC_CORP_IDEA_F' 'SCH_PSCORPINSTANCES_ALL' 'TOT_PSDISC_SINGOOS_M'\n 'TOT_PSDISC_SINGOOS_F' 'TOT_PSDISC_MULTOOS_M' 'TOT_PSDISC_MULTOOS_F'\n 'SCH_PSOOSINSTANCES_ALL' 'SCH_PSOOSINSTANCES_IDEA'\n 'SCH_OOSINSTANCES_WODIS' 'SCH_OOSINSTANCES_IDEA' 'SCH_OOSINSTANCES_504'\n 'SCH_DAYSMISSED_HI_M' 'SCH_DAYSMISSED_HI_F' 'SCH_DAYSMISSED_AM_M'\n 'SCH_DAYSMISSED_AM_F' 'SCH_DAYSMISSED_AS_M' 'SCH_DAYSMISSED_AS_F'\n 'SCH_DAYSMISSED_HP_M' 'SCH_DAYSMISSED_HP_F' 'SCH_DAYSMISSED_BL_M'\n 'SCH_DAYSMISSED_BL_F' 'SCH_DAYSMISSED_WH_M' 'SCH_DAYSMISSED_WH_F'\n 'SCH_DAYSMISSED_TR_M' 'SCH_DAYSMISSED_TR_F' 'TOT_DAYSMISSED_M'\n 'TOT_DAYSMISSED_F' 'SCH_DAYSMISSED_LEP_M' 'SCH_DAYSMISSED_LEP_F'\n 'SCH_DAYSMISSED_504_M' 'SCH_DAYSMISSED_504_F' 'SCH_DAYSMISSED_IDEA_M'\n 'SCH_DAYSMISSED_IDEA_F' 'SCH_PSDISC_EXP_HI_M' 'SCH_PSDISC_EXP_HI_F'\n 'SCH_PSDISC_EXP_AM_M' 'SCH_PSDISC_EXP_AM_F' 'SCH_PSDISC_EXP_AS_M'\n 'SCH_PSDISC_EXP_AS_F' 'SCH_PSDISC_EXP_HP_M' 'SCH_PSDISC_EXP_HP_F'\n 'SCH_PSDISC_EXP_BL_M' 'SCH_PSDISC_EXP_BL_F' 'SCH_PSDISC_EXP_WH_M'\n 'SCH_PSDISC_EXP_WH_F' 'SCH_PSDISC_EXP_TR_M' 'SCH_PSDISC_EXP_TR_F'\n 'TOT_PSDISC_EXP_M' 'TOT_PSDISC_EXP_F' 'SCH_PSDISC_EXP_LEP_M'\n 'SCH_PSDISC_EXP_LEP_F' 'SCH_PSDISC_EXP_IDEA_M' 'SCH_PSDISC_EXP_IDEA_F'\n 'TOT_DISCWODIS_EXPWE_M' 'TOT_DISCWODIS_EXPWE_F' 'TOT_DISCWODIS_EXPWOE_M'\n 'TOT_DISCWODIS_EXPWOE_F' 'SCH_DISCWODIS_EXPZT_HI_M'\n 'SCH_DISCWODIS_EXPZT_HI_F' 'SCH_DISCWODIS_EXPZT_AM_M'\n 'SCH_DISCWODIS_EXPZT_AM_F' 'SCH_DISCWODIS_EXPZT_AS_M'\n 'SCH_DISCWODIS_EXPZT_AS_F' 'SCH_DISCWODIS_EXPZT_HP_M'\n 'SCH_DISCWODIS_EXPZT_HP_F' 'SCH_DISCWODIS_EXPZT_BL_M'\n 'SCH_DISCWODIS_EXPZT_BL_F' 'SCH_DISCWODIS_EXPZT_WH_M'\n 'SCH_DISCWODIS_EXPZT_WH_F' 'SCH_DISCWODIS_EXPZT_TR_M'\n 'SCH_DISCWODIS_EXPZT_TR_F' 'TOT_DISCWODIS_EXPZT_M' 'TOT_DISCWODIS_EXPZT_F'\n 'SCH_DISCWODIS_EXPZT_LEP_M' 'SCH_DISCWODIS_EXPZT_LEP_F'\n 'TOT_DISCWDIS_EXPWE_IDEA_M' 'TOT_DISCWDIS_EXPWE_IDEA_F'\n 'TOT_DISCWDIS_EXPWOE_IDEA_M' 'TOT_DISCWDIS_EXPWOE_IDEA_F'\n 'SCH_DISCWDIS_EXPZT_IDEA_HI_M' 'SCH_DISCWDIS_EXPZT_IDEA_HI_F'\n 'SCH_DISCWDIS_EXPZT_IDEA_AM_M' 'SCH_DISCWDIS_EXPZT_IDEA_AM_F'\n 'SCH_DISCWDIS_EXPZT_IDEA_AS_M' 'SCH_DISCWDIS_EXPZT_IDEA_AS_F'\n 'SCH_DISCWDIS_EXPZT_IDEA_HP_M' 'SCH_DISCWDIS_EXPZT_IDEA_HP_F'\n 'SCH_DISCWDIS_EXPZT_IDEA_BL_M' 'SCH_DISCWDIS_EXPZT_IDEA_BL_F'\n 'SCH_DISCWDIS_EXPZT_IDEA_WH_M' 'SCH_DISCWDIS_EXPZT_IDEA_WH_F'\n 'SCH_DISCWDIS_EXPZT_IDEA_TR_M' 'SCH_DISCWDIS_EXPZT_IDEA_TR_F'\n 'TOT_DISCWDIS_EXPZT_IDEA_M' 'TOT_DISCWDIS_EXPZT_IDEA_F'\n 'SCH_DISCWDIS_EXPZT_LEP_M' 'SCH_DISCWDIS_EXPZT_LEP_F'\n 'SCH_DISCWDIS_EXPZT_504_M' 'SCH_DISCWDIS_EXPZT_504_F'\n 'TOT_DISCWODIS_TFRALT_M' 'TOT_DISCWODIS_TFRALT_F'\n 'TOT_DISCWDIS_TFRALT_IDEA_M' 'TOT_DISCWDIS_TFRALT_IDEA_F'\n 'TOT_DISCWODIS_REF_M' 'TOT_DISCWODIS_REF_F' 'TOT_DISCWDIS_REF_IDEA_M'\n 'TOT_DISCWDIS_REF_IDEA_F' 'TOT_DISCWODIS_ARR_M' 'TOT_DISCWODIS_ARR_F'\n 'TOT_DISCWDIS_ARR_IDEA_M' 'TOT_DISCWDIS_ARR_IDEA_F' 'SCH_OFFENSE_RAPE'\n 'SCH_OFFENSE_BATT' 'SCH_OFFENSE_ROBWW' 'SCH_OFFENSE_ROBWX'\n 'SCH_OFFENSE_ROBWOW' 'SCH_OFFENSE_ATTWW' 'SCH_OFFENSE_ATTWX'\n 'SCH ...

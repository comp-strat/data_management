# %%
% matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
import numpy as np

# %%
import re

# %%
filepath = '../../charters_full_2015_250_counts.pkl'

# %%
df = pd.read_pickle(filepath)
list(df)
# Out:
# ['CMO_NAME',
#  'CMO_MEMSUM',
#  'SCH_NAME',
#  'CMO_STATE',
#  'CMO_SCHNUM',
#  'CMO_URL',
#  'CMO_NUMSTATES',
#  'CMO_ALLSTATES',
#  'CMO_SECTOR',
#  'CMO_NUMSTUDENTS_CREDO17',
#  'CMO_TYPE',
#  'CMO_WEBTEXT',
#  'SURVYEAR',
#  'FIPST',
#  'STABR',
#  'SEANAME',
#  'LEAID',
#  'ST_LEAID',
#  'SCHID',
#  'ST_SCHID',
#  'NCESSCH',
#  'MSTREET1',
#  'MSTREET2',
#  'MSTREET3',
#  'MCITY',
#  'MSTATE',
#  'MZIP',
#  'MZIP4',
#  'PHONE',
#  'LSTREET1',
#  'LSTREET2',
#  'LSTREET3',
#  'LCITY',
#  'LSTATE',
#  'LZIP',
#  'LZIP4',
#  'UNION',
#  'OUT_OF_STATE_FLAG',
#  'SCH_TYPE_TEXT',
#  'SCH_TYPE',
#  'RECON_STATUS',
#  'GSLO',
#  'GSHI',
#  'LEVEL',
#  'VIRTUAL',
#  'BIES',
#  'SY_STATUS_TEXT',
#  'SY_STATUS',
#  'UPDATED_STATUS_TEXT',
#  'UPDATED_STATUS',
#  'EFFECTIVE_DATE',
#  'CHARTER_TEXT',
#  'G13OFFERED',
#  'AEOFFERED',
#  'UGOFFERED',
#  'NOGRADES',
#  'CHARTAUTH1',
#  'CHARTAUTHN1',
#  'CHARTAUTH2',
#  'CHARTAUTHN2',
#  'IGOFFERED',
#  'WEBSITE',
#  'FRELCH',
#  'REDLCH',
#  'AE',
#  'TOTAL',
#  'AM',
#  'AMALM',
#  'AMALF',
#  'AS',
#  'ASALM',
#  'ASALF',
#  'HI',
#  'HIALM',
#  'HIALF',
#  'BL',
#  'BLALM',
#  'BLALF',
#  'WH',
#  'WHALM',
#  'WHALF',
#  'HP',
#  'HPALM',
#  'HPALF',
#  'TR',
#  'TRALM',
#  'TRALF',
#  'TITLEI_TEXT',
#  'TITLEI_STATUS',
#  'STITLEI',
#  'SHARED_TIME',
#  'MAGNET_TEXT',
#  'NSLPSTATUS_TEXT',
#  'NSLPSTATUS_CODE',
#  'NAME',
#  'OPSTFIPS',
#  'LSTREE',
#  'STFIP15',
#  'CNTY15',
#  'NMCNTY15',
#  'LOCALE15',
#  'LAT1516',
#  'LON1516',
#  'CBSA15',
#  'NMCBSA15',
#  'CBSATYPE15',
#  'CSA15',
#  'NMCSA15',
#  'NECTA15',
#  'NMNECTA15',
#  'CD15',
#  'SLDL15',
#  'SLDU15',
#  'LSTREET114',
#  'LSTREET214',
#  'LSTREET314',
#  'LCITY14',
#  'LSTATE14',
#  'LZIP14',
#  'ISFLE',
#  'ISFTEPUP',
#  'SCHNAM98',
#  'CHARTR98',
#  'STATUS98',
#  'SCHNAM99',
#  'CHARTR99',
#  'STATUS99',
#  'SCHNAM00',
#  'CHARTR00',
#  'STATUS00',
#  'SCHNAM01',
#  'CHARTR01',
#  'STATUS01',
#  'SCHNAM02',
#  'CHARTR02',
#  'STATUS02',
#  'SCHNAM03',
#  'CHARTR03',
#  'STATUS03',
#  'SCHNAM04',
#  'CHARTR04',
#  'STATUS04',
#  'SCHNAM05',
#  'CHARTR05',
#  'STATUS05',
#  'SCHNAM06',
#  'CHARTR06',
#  'STATUS06',
#  'SCHNAM07',
#  'CHARTR07',
#  'STATUS07',
#  'SCHNAM08',
#  'CHARTR08',
#  'STATUS08',
#  'SCHNAM09',
#  'CHARTR09',
#  'STATUS09',
#  'SCHNAM10',
#  'CHARTR10',
#  'STATUS10',
#  'RECONSTY10',
#  'RECONSTF10',
#  'SCHNAM11',
#  'CHARTR11',
#  'STATUS11',
#  'RECONSTY11',
#  'RECONSTF11',
#  'SCHNAM12',
#  'CHARTR12',
#  'STATUS12',
#  'RECONSTY12',
#  'RECONSTF12',
#  'SCHNAM13',
#  'CHARTR13',
#  'STATUS13',
#  'RECONSTY13',
#  'RECONSTF13',
#  'SCHNAM15',
#  'CHARTER_TEXT15',
#  'SY_STATUS15',
#  'RECON_STATUS15',
#  'SCHNAM16',
#  'CHARTER_TEXT16',
#  'SY_STATUS16',
#  'RECON_STATUS16',
#  'PVI2017',
#  'PVI2014',
#  'CONUM',
#  'CONAME',
#  'CD',
#  'CBSA',
#  'CSA',
#  'NECTA',
#  'METMIC',
#  'ALL_MTH00NUMVALID_1415',
#  'ALL_RLA00NUMVALID_1415',
#  'LSTREET116',
#  'LSTREET216',
#  'LSTREET316',
#  'LCITY16',
#  'LSTATE16',
#  'LZIP16',
#  'ADDRESS16',
#  'ALL_RLA00NUMVALID_1516',
#  'ALL_RLA00PCTPROF_1516',
#  'ALL_MTH00NUMVALID_1516',
#  'ALL_MTH00PCTPROF_1516',
#  'ess_strength',
#  'prog_strength',
#  'SD_lv_PVI_2014',
#  'SD_lv_PVI_2017',
#  'FIPS',
#  'Name of Area',
#  'Qualifying Name',
#  'State/U.S.-Abbreviation (USPS)',
#  'Summary Level',
#  'File Identification',
#  'Logical Record Number',
#  'State (FIPS)',
#  'School District (Elementary)',
#  'School District (Secondary)',
#  'School District (Unified)',
#  'Geographic Identifier',
#  'Area (Land)',
#  'Area (Water)',
#  'Total Population',
#  'Population Density (Per Sq. Mile)',
#  'Area (Land)',
#  '% Total Population: Under 18 Years',
#  '% Total Population: 18 to 34 Years',
#  '% Total Population: 35 to 64 Years',
#  '% Total Population: 65 and Over',
#  '% Total Population: White Alone',
#  '% Total Population: Black or African American Alone',
#  '% Total Population: American Indian and Alaska Native Alone',
#  '% Total Population: Asian Alone',
#  '% Total Population: Native Hawaiian and Other Pacific Islander Alone',
#  '% Total Population: Some Other Race Alone',
#  '% Total Population: Two or More Races',
#  'Occupied Housing Units',
#  '% Occupied Housing Units: Family Households',
#  '% Occupied Housing Units: Family Households: Married-Couple Family',
#  '% Occupied Housing Units: Nonfamily Households',
#  '% Occupied Housing Units: Nonfamily Households: Householder Living Alone',
#  '% Occupied Housing Units: With Related Children of the Householder Under 18',
#  '% Occupied Housing Units: No Related Children of the Householder Under 18',
#  'Population 15 Years and Over:',
#  '% Population 15 Years and Over: Never Married',
#  '% Population 15 Years and Over: Now Married (Not Including Separated)',
#  '% Population 15 Years and Over: Separated',
#  '% Population 15 Years and Over: Widowed',
#  '% Population 15 Years and Over: Divorced',
#  'Population 25 Years and Over:',
#  '% Population 25 Years and Over: Less than High School',
#  '% Population 25 Years and Over: High School Graduate (Includes Equivalency)',
#  '% Population 25 Years and Over: Some College',
#  "% Population 25 Years and Over: Bachelor's Degree",
#  "% Population 25 Years and Over: Master's Degree",
#  '% Population 25 Years and Over: Professional School Degree',
#  '% Population 25 Years and Over: Doctorate Degree',
#  'Population 3 Years and Over:',
#  '% Population 3 Years and Over: Enrolled in School',
#  '% Population 3 Years and Over: Not Enrolled in School',
#  '% Population 3 Years and Over Enrolled in School: Public School',
#  '% Population 3 Years and Over Enrolled in School: Public School: Pre-School',
#  '% Population 3 Years and Over Enrolled in School: Public School: K-8',
#  '% Population 3 Years and Over Enrolled in School: Public School: 9-12',
#  '% Population 3 Years and Over Enrolled in School: Public School: College',
#  '% Population 3 Years and Over Enrolled in School: Private School',
#  '% Population 3 Years and Over Enrolled in School: Private School: Pre-School',
#  '% Population 3 Years and Over Enrolled in School: Private School: K-8',
#  '% Population 3 Years and Over Enrolled in School: Private School: 9-12',
#  '% Population 3 Years and Over Enrolled in School: Private School: College',
#  'Civilian Population 16 to 19 Years:',
#  '% Civilian Population 16 to 19 Years: Not High School Graduate, Not Enrolled (Dropped Out)',
#  '% Civilian Population 16 to 19 Years: High School Graduate, or Enrolled (in School)',
#  '% Civilian Population in Labor Force 16 Years and Over: Employed',
#  '% Civilian Population in Labor Force 16 Years and Over: Unemployed',
#  '% White Alone, Not Hispanic or Latino 16 Years Old  in&nbsp; Civilian Labor Force: Employed',
#  '% White Alone, Not Hispanic or Latino 16 Years Old  in&nbsp; Civilian Labor Force: Unemployed',
#  '% Employed Civilian Population 16 Years and Over: Agriculture, Forestry, Fishing and Hunting, and Mining',
#  '% Employed Civilian Population 16 Years and Over: Construction',
#  '% Employed Civilian Population 16 Years and Over: Manufacturing',
#  '% Employed Civilian Population 16 Years and Over: Wholesale Trade',
#  '% Employed Civilian Population 16 Years and Over: Retail Trade',
#  '% Employed Civilian Population 16 Years and Over: Transportation and Warehousing, and Utilities',
#  '% Employed Civilian Population 16 Years and Over: Information',
#  '% Employed Civilian Population 16 Years and Over: Finance and Insurance, and Real Estate and Rental  and Leasing',
#  '% Employed Civilian Population 16 Years and Over: Professional, Scientific, and Management, and  Administrative and Waste Management Services',
#  '% Employed Civilian Population 16 Years and Over: Educational Services, and Health Care and Social  Assistance',
#  '% Employed Civilian Population 16 Years and Over: Arts, Entertainment, and Recreation, and  Accommodation and Food Services',
#  '% Employed Civilian Population 16 Years and Over: Other Services, Except Public Administration',
#  '% Employed Civilian Population 16 Years and Over: Public Administration',
#  '% Employed Civilian Population 16 Years and Over: Unpaid Family Workers',
#  'Median Household Income (In 2016 Inflation Adjusted Dollars)',
#  'Median Household Income (In 2016 Inflation Adjusted Dollars): White Alone Householder',
#  'Median Household Income (In 2016 Inflation Adjusted Dollars): Black or African American Alone Householder',
#  'Median Household Income (In 2016 Inflation Adjusted Dollars): American Indian and Alaska Native Alone  Householder',
#  'Median Household Income (In 2016 Inflation Adjusted Dollars): Asian Alone',
#  'Median Household Income (In 2016 Inflation Adjusted Dollars): Native Hawaiian and Other Pacific Islander Alone  Householder',
#  'Median Household Income (In 2016 Inflation Adjusted Dollars): Some Other Race Alone Householder',
#  'Median Household Income (In 2016 Inflation Adjusted Dollars): Two or More Races Householder',
#  'Median Household Income (In 2016 Inflation Adjusted Dollars): Hispanic or Latino Householder',
#  'Median Household Income (In 2016 Inflation Adjusted Dollars): White Alone Householder, Not Hispanic or Latino',
#  'Per Capita Income (In 2016 Inflation Adjusted Dollars)',
#  'Gini Index',
#  'Median Year Structure Built',
#  'Median Value',
#  '% Renter-Occupied Housing Units: Less than 10 Percent',
#  '% Renter-Occupied Housing Units: 10 to 29 Percent',
#  '% Renter-Occupied Housing Units: 30 to 49 Percent',
#  '% Renter-Occupied Housing Units: 50 Percent or More',
#  '% Renter-Occupied Housing Units: Not Computed',
#  '% Families: Income in Below Poverty Level',
#  '% Families: Income in at or Above Poverty Level',
#  'Population Under 18 Years of Age for Whom Poverty Status Is Determined:',
#  '% Population Under 18 Years of Age for Whom Poverty Status Is Determined: Living in Poverty',
#  '% Population Under 18 Years of Age for Whom Poverty Status Is Determined: at or Above Poverty Level',
#  '% Total: Same House 1 Year Ago',
#  '% Total: Moved Within Same County',
#  '% Total: Moved From Different County Within Same State',
#  '% Total: Moved From Different State',
#  '% Total: Moved From Abroad',
#  '% Total Population: Native Born',
#  '% Total Population: Foreign Born',
#  '% Total Population: Foreign Born: Naturalized Citizen',
#  '% Total Population: Foreign Born: Not a Citizen',
#  '% Foreign-Born Population: Europe',
#  '% Foreign-Born Population: Asia',
#  '% Foreign-Born Population: Africa',
#  '% Foreign-Born Population: Oceania',
#  '% Foreign-Born Population: Americas',
#  'Total:',
#  '% Total: No Health Insurance Coverage',
#  '% Total: with Health Insurance Coverage',
#  '% Total: with Health Insurance Coverage: Public Health Coverage',
#  '% Total: with Health Insurance Coverage: Private Health Insurance',
#  'close99',
#  'close00',
#  'close01',
#  'close02',
#  'close03',
#  'close04',
#  'close05',
#  'close06',
#  'close07',
#  'close08',
#  'close09',
#  'close10',
#  'close11',
#  'close12',
#  'close13',
#  'close14',
#  'close15',
#  'close16',
#  'close_rate99',
#  'close_rate00',
#  'close_rate01',
#  'close_rate02',
#  'close_rate03',
#  'close_rate04',
#  'close_rate05',
#  'close_rate06',
#  'close_rate07',
#  'close_rate08',
#  'close_rate09',
#  'close_rate10',
#  'close_rate11',
#  'close_rate12',
#  'close_rate13',
#  'close_rate14',
#  'close_rate15',
#  'close_rate16',
#  'POPTOT_S16',
#  'POP517_S16',
#  'CHILDPOV_S16',
#  'TRUE_CHARTER',
#  'WEBTEXT',
#  'MEMBER',
#  'TOTFRL',
#  'TITLEI',
#  'FTE',
#  'YEAR_OPENED',
#  'YEAR_CLOSED',
#  'SEARCH16',
#  'TOTETH',
#  'PCTETH',
#  'AGE',
#  'PCTFRL',
#  'PLACE',
#  'STR',
#  'WEBTEXT_METHOD',
#  'REPLACED',
#  'CMO_REPLACED',
#  'PROG_COUNT',
#  'RIT_COUNT',
#  'ESS_COUNT',
#  'ESS_STR',
#  'PROG_STR',
#  'RIT_STR',
#  'NUMWORDS',
#  'PROG_NORM',
#  'ESS_NORM',
#  'RIT_NORM']

# %%
df[['ESS_STR','PROG_STR','RIT_STR', 'NUMWORDS', 'PROG_COUNT']].describe()
# Out:
#            ESS_STR     PROG_STR      RIT_STR      NUMWORDS    PROG_COUNT
# count  7294.000000  7294.000000  7294.000000  1.140000e+04  11400.000000
# mean     -3.459361    -3.351078    -2.624867  2.096722e+04     51.623246
# std       1.325394     1.344113     1.288241  1.134103e+05    555.487858
# min      -6.000000    -6.000000    -6.000000  0.000000e+00      0.000000
# 25%      -3.526430    -3.359943    -2.501471  0.000000e+00      0.000000
# 50%      -2.929505    -2.827314    -2.174233  6.945000e+02      1.000000
# 75%      -2.609622    -2.496125    -1.964332  1.844700e+04     31.000000
# max      -1.448265    -1.162518    -1.112704  8.057623e+06  42362.000000

# %%
web_list = (df[df['NUMWORDS'] == df["NUMWORDS"].max()].iloc[0])['WEBTEXT'] # pages of school with max numwords

# %%
page_numwords = [len(re.split('\W+|_', p[3])) for p in web_list]

# %%
sum(page_numwords)/len(page_numwords) # avg num words per page
# Out:
# 48539.89759036145

# %%
high_pages = [p for p in web_list if len(re.split('\W+|_', p[3])) > 50000]

# %%
high_pages[0] # try going to https://www.methodschools.org/blog/topic/homeschooling-saves-money to see for yourself. Notice where all the words are!
# Out:
# ('https://www.methodschools.org/blog/topic/homeschooling-saves-money',
#  'False',
#  '2',
#  "About\nProgram\nBlog\nCareers\nBoard\nLocations\nStudents\nSmart Fox Login\nSchool Calendar\nStudent Showcase Center\nSummer\nEnroll\nLogin\nSearch\nMethod Blog:\nThe Smart Fox\nI want to read about\nhomeschooling\nSelect Option\nProject Based Learning\nCharter Schools\nOnline Learning\nSmall Class Sizes\nSchool Choice\nonline high school\nService Learning\nonline home school\nMethod Schools\nOnline Curriculum\nhome school\nhomeschooling\nClass Size\nquality schools\npersonalization\nBlended Learning\nChoosing the Right School\nIndependent Study\nInnovation\nClass Size Reduction\nData Driven Education\nonline middle school\nCharacter Education\nE-Learning\nMethod High School\nRobotics\nTraditional School\ncurriculum\nsmartfox\nBreakthrough Schools\nChange\nFocused Direct Instruction\nSummer School\nschool districts\nEdTech\nPBL\ncommon core\nindividualized learning\nmiddle school\nonline summer school\nCustomized Classroom\nDifferentiation\nField Trips\nGetting into college\nLMS\nLearning Disabilities\nNon-traditional schools\nRotational Model\nSIS\nSTEM Charter School\nSTEM School\nStation Rotation\nUC a-g\nadaptive curriculum\ncharter school funding\neducation budgets\neducation funding\nexperiental learning\nhands-on learning\nhomework help for parents\npersonalized learning\nschools and dyslexia\nADD\nADHD\nADHD holidays\nAccountability\nActivities for kids\nArcadia\nCalifornia LCFF\nDoctorate\nDyslexia\nDyslexia help\nEducation Dogma\nExercise\nFDI\nGoals\nGrants\nHelp for Learning Disabilities\nHomeschool misconceptions\nLeadership\nLearning help\nLos Angeles Charter Schools\nMethod Schools Arcadia\nNCAA approved\nNGLC\nOpening New Schools\nOutcomes\nParents and Dyslexia\nPhD\nSTEM Education\nSTEM Program\nSchoolism\nScience\nScience Fair\nSocialization\nStudent Marketing Projects\nTechnology in Education\nWASC\nWInter Vacation\nWhat is Dyslexia\nalternative education\nautomation\nautumn service learning project\nback to school\nbest school fit\nbullying\ncharter school gro\nchildren with developmental disorder\ncommunity service\ncustom online courses\ncustomer-centric schools\ndata\nenrollment\nenrollment growth\nextra-curricular activities\nflexibility\nfocus\nfree summer school\ngrowth in charter schools\nhaiti fundraiser\nhighly-qualified teachers\nholiday stress for kids\nhomeschool academics\nhomeschool and college\nhomeschool objections\nhomeschool research\nhomeschool socialization\nhomeschooling saves money\nhow to enroll at method\nhow to study\nmyths about charter schools\nno help for bullying problem\npersonalized instruction\nplan c\nproblems with school clicks and bullying\npsychological stress of school overcrowding\npublic charter school\npublic tax dollars\nred ocean\nsan diego charter schools\nschool funding\nschool overcrowding\nschool partnerships\nschool problems\nschool routine\nschool social hierarchy\nsmaller schools\nstem\nstudent blogs\nstudent conflicts\nstudent data\nstudents who are behind not getting help\nstudy tips\nsummer enrichment ideas\nteacher support\nteaching your child how to give back\nthe foundry\nvolunteering\nwhy do we have school problems\nwhy do we have school shootings\nwhy should I homeschool\nwinter break\nAll Topics\nProject Based Learning\nCharter Schools\nOnline Learning\nSmall Class Sizes\nSchool Choice\nonline high school\nService Learning\nonline home school\nMethod Schools\nOnline Curriculum\nhome school\nhomeschooling\nClass Size\nquality schools\npersonalization\nBlended Learning\nChoosing the Right School\nIndependent Study\nInnovation\nClass Size Reduction\nData Driven Education\nonline middle school\nCharacter Education\nE-Learning\nMethod High School\nRobotics\nTraditional School\ncurriculum\nsmartfox\nBreakthrough Schools\nChange\nFocused Direct Instruction\nSummer School\nschool districts\nEdTech\nPBL\ncommon core\nindividualized learning\nmiddle school\nonline summer school\nCustomized Classroom\nDifferentiation\nField Trips\nGetting into college\nLMS\nL ...

# %%
re.split('\W+|_', high_pages[0][3])
# Out:
# ['About',
#  'Program',
#  'Blog',
#  'Careers',
#  'Board',
#  'Locations',
#  'Students',
#  'Smart',
#  'Fox',
#  'Login',
#  'School',
#  'Calendar',
#  'Student',
#  'Showcase',
#  'Center',
#  'Summer',
#  'Enroll',
#  'Login',
#  'Search',
#  'Method',
#  'Blog',
#  'The',
#  'Smart',
#  'Fox',
#  'I',
#  'want',
#  'to',
#  'read',
#  'about',
#  'homeschooling',
#  'Select',
#  'Option',
#  'Project',
#  'Based',
#  'Learning',
#  'Charter',
#  'Schools',
#  'Online',
#  'Learning',
#  'Small',
#  'Class',
#  'Sizes',
#  'School',
#  'Choice',
#  'online',
#  'high',
#  'school',
#  'Service',
#  'Learning',
#  'online',
#  'home',
#  'school',
#  'Method',
#  'Schools',
#  'Online',
#  'Curriculum',
#  'home',
#  'school',
#  'homeschooling',
#  'Class',
#  'Size',
#  'quality',
#  'schools',
#  'personalization',
#  'Blended',
#  'Learning',
#  'Choosing',
#  'the',
#  'Right',
#  'School',
#  'Independent',
#  'Study',
#  'Innovation',
#  'Class',
#  'Size',
#  'Reduction',
#  'Data',
#  'Driven',
#  'Education',
#  'online',
#  'middle',
#  'school',
#  'Character',
#  'Education',
#  'E',
#  'Learning',
#  'Method',
#  'High',
#  'School',
#  'Robotics',
#  'Traditional',
#  'School',
#  'curriculum',
#  'smartfox',
#  'Breakthrough',
#  'Schools',
#  'Change',
#  'Focused',
#  'Direct',
#  'Instruction',
#  'Summer',
#  'School',
#  'school',
#  'districts',
#  'EdTech',
#  'PBL',
#  'common',
#  'core',
#  'individualized',
#  'learning',
#  'middle',
#  'school',
#  'online',
#  'summer',
#  'school',
#  'Customized',
#  'Classroom',
#  'Differentiation',
#  'Field',
#  'Trips',
#  'Getting',
#  'into',
#  'college',
#  'LMS',
#  'Learning',
#  'Disabilities',
#  'Non',
#  'traditional',
#  'schools',
#  'Rotational',
#  'Model',
#  'SIS',
#  'STEM',
#  'Charter',
#  'School',
#  'STEM',
#  'School',
#  'Station',
#  'Rotation',
#  'UC',
#  'a',
#  'g',
#  'adaptive',
#  'curriculum',
#  'charter',
#  'school',
#  'funding',
#  'education',
#  'budgets',
#  'education',
#  'funding',
#  'experiental',
#  'learning',
#  'hands',
#  'on',
#  'learning',
#  'homework',
#  'help',
#  'for',
#  'parents',
#  'personalized',
#  'learning',
#  'schools',
#  'and',
#  'dyslexia',
#  'ADD',
#  'ADHD',
#  'ADHD',
#  'holidays',
#  'Accountability',
#  'Activities',
#  'for',
#  'kids',
#  'Arcadia',
#  'California',
#  'LCFF',
#  'Doctorate',
#  'Dyslexia',
#  'Dyslexia',
#  'help',
#  'Education',
#  'Dogma',
#  'Exercise',
#  'FDI',
#  'Goals',
#  'Grants',
#  'Help',
#  'for',
#  'Learning',
#  'Disabilities',
#  'Homeschool',
#  'misconceptions',
#  'Leadership',
#  'Learning',
#  'help',
#  'Los',
#  'Angeles',
#  'Charter',
#  'Schools',
#  'Method',
#  'Schools',
#  'Arcadia',
#  'NCAA',
#  'approved',
#  'NGLC',
#  'Opening',
#  'New',
#  'Schools',
#  'Outcomes',
#  'Parents',
#  'and',
#  'Dyslexia',
#  'PhD',
#  'STEM',
#  'Education',
#  'STEM',
#  'Program',
#  'Schoolism',
#  'Science',
#  'Science',
#  'Fair',
#  'Socialization',
#  'Student',
#  'Marketing',
#  'Projects',
#  'Technology',
#  'in',
#  'Education',
#  'WASC',
#  'WInter',
#  'Vacation',
#  'What',
#  'is',
#  'Dyslexia',
#  'alternative',
#  'education',
#  'automation',
#  'autumn',
#  'service',
#  'learning',
#  'project',
#  'back',
#  'to',
#  'school',
#  'best',
#  'school',
#  'fit',
#  'bullying',
#  'charter',
#  'school',
#  'gro',
#  'children',
#  'with',
#  'developmental',
#  'disorder',
#  'community',
#  'service',
#  'custom',
#  'online',
#  'courses',
#  'customer',
#  'centric',
#  'schools',
#  'data',
#  'enrollment',
#  'enrollment',
#  'growth',
#  'extra',
#  'curricular',
#  'activities',
#  'flexibility',
#  'focus',
#  'free',
#  'summer',
#  'school',
#  'growth',
#  'in',
#  'charter',
#  'schools',
#  'haiti',
#  'fundraiser',
#  'highly',
#  'qualified',
#  'teachers',
#  'holiday',
#  'stress',
#  'for',
#  'kids',
#  'homeschool',
#  'academics',
#  'homeschool',
#  'and',
#  'college',
#  'homeschool',
#  'objections',
#  'homeschool',
#  'research',
#  'homeschool',
#  'socialization',
#  'homeschooling',
#  'saves',
#  'money',
#  'how',
#  'to',
#  'enroll',
#  'at',
#  'method',
#  'how',
#  'to',
#  'study',
#  'myths',
#  'about',
#  'charter',
#  'schools',
#  'no',
#  'help',
#  'for',
#  'bullying',
#  'problem',
#  'personalized',
#  'instruction',
#  'plan',
#  'c',
#  'problems',
#  'with',
#  'school',
#  'clicks',
#  'and',
#  'bullying',
#  'psychological',
#  'stress',
#  'of',
#  'school',
#  'overcrowding',
#  'public',
#  'charter',
#  'school',
#  'public',
#  'tax',
#  'dollars',
#  'red',
#  'ocean',
#  'san',
#  'diego',
#  'charter',
#  'schools',
#  'school',
#  'funding',
#  'school',
#  'overcrowding',
#  'school',
#  'partnerships',
#  'school',
#  'problems',
#  'school',
#  'routine',
#  'school',
#  'social',
#  'hierarchy',
#  'smaller',
#  'schools',
#  'stem',
#  'student',
#  'blogs',
#  'student',
#  'conflicts',
#  'student',
#  'data',
#  'students',
#  'who',
#  'are',
#  'behind',
#  'not',
#  'getting',
#  'help',
#  'study',
#  'tips',
#  'summer',
#  'enrichment',
#  'ideas',
#  'teacher',
#  'support',
#  'teaching',
#  'your',
#  'child',
#  'how',
#  'to',
#  'give',
#  'back',
#  'the',
#  'foundry',
#  'volunteering',
#  'why',
#  'do',
#  'we',
#  'have',
#  'school',
#  'problems',
#  'why',
#  'do',
#  'we',
#  'have',
#  'school',
#  'shootings',
#  'why',
#  'should',
#  'I',
#  'homeschool',
#  'winter',
#  'break',
#  'All',
#  'Topics',
#  'Project',
#  'Based',
#  'Learning',
#  'Charter',
#  'Schools',
#  'Online',
#  'Learning',
#  'Small',
#  'Class',
#  'Sizes',
#  'School',
#  'Choice',
#  'online',
#  'high',
#  'school',
#  'Service',
#  'Learning',
#  'online',
#  'home',
#  'school',
#  'Method',
#  'Schools',
#  'Online',
#  'Curriculum',
#  'home',
#  'school',
#  'homeschooling',
#  'Class',
#  'Size',
#  'quality',
#  'schools',
#  'personalization',
#  'Blended',
#  'Learning',
#  'Choosing',
#  'the',
#  'Right',
#  'School',
#  'Independent',
#  'Study',
#  'Innovation',
#  'Class',
#  'Size',
#  'Reduction',
#  'Data',
#  'Driven',
#  'Education',
#  'online',
#  'middle',
#  'school',
#  'Character',
#  'Education',
#  'E',
#  'Learning',
#  'Method',
#  'High',
#  'School',
#  'Robotics',
#  'Traditional',
#  'School',
#  'curriculum',
#  'smartfox',
#  'Breakthrough',
#  'Schools',
#  'Change',
#  'Focused',
#  'Direct',
#  'Instruction',
#  'Summer',
#  'School',
#  'school',
#  'districts',
#  'EdTech',
#  'PBL',
#  'common',
#  'core',
#  'individualized',
#  'learning',
#  'middle',
#  'school',
#  'online',
#  'summer',
#  'school',
#  'Customized',
#  'Classroom',
#  'Differentiation',
#  'Field',
#  'Trips',
#  'Getting',
#  'into',
#  'college',
#  'LMS',
#  'Learning',
#  'Disabilities',
#  'Non',
#  'traditional',
#  'schools',
#  'Rotational',
#  'Model',
#  'SIS',
#  'STEM',
#  'Charter',
#  'School',
#  'STEM',
#  'School',
#  'Station',
#  'Rotation',
#  'UC',
#  'a',
#  'g',
#  'adaptive',
#  'curriculum',
#  'charter',
#  'school',
#  'funding',
#  'education',
#  'budgets',
#  'education',
#  'funding',
#  'experiental',
#  'learning',
#  'hands',
#  'on',
#  'learning',
#  'homework',
#  'help',
#  'for',
#  'parents',
#  'personalized',
#  'learning',
#  'schools',
#  'and',
#  'dyslexia',
#  'ADD',
#  'ADHD',
#  'ADHD',
#  'holidays',
#  'Accountability',
#  'Activities',
#  'for',
#  'kids',
#  'Arcadia',
#  'California',
#  'LCFF',
#  'Doctorate',
#  'Dyslexia',
#  'Dyslexia',
#  'help',
#  'Education',
#  'Dogma',
#  'Exercise',
#  'FDI',
#  'Goals',
#  'Grants',
#  'Help',
#  'for',
#  'Learning',
#  'Disabilities',
#  'Homeschool',
#  'misconceptions',
#  'Leadership',
#  'Learning',
#  'help',
#  'Los',
#  'Angeles',
#  'Charter',
#  'Schools',
#  'Method',
#  'Schools',
#  'Arcadia',
#  'NCAA',
#  'approved',
#  'NGLC',
#  'Opening',
#  'New',
#  'Schools',
#  'Outcomes',
#  'Parents',
#  'and',
#  'Dyslexia',
#  'PhD',
#  'STEM',
#  'Education',
#  'STEM',
#  'Program',
#  'Schoolism',
#  'Science',
#  'Science',
#  'Fair',
#  'Socialization',
#  'Student',
#  'Marketing',
#  'Projects',
#  'Technology',
#  'in',
#  'Education',
#  'WASC',
#  'WInter',
#  'Vacation',
#  'What',
#  'is',
#  'Dyslexia',
#  'alternative',
#  'education',
#  'automation',
#  'autumn',
#  'service',
#  'learning',
#  'project',
#  'back',
#  'to',
#  'school',
#  'best',
#  'school',
#  'fit',
#  'bullying',
#  'charter',
#  'school',
#  'gro',
#  'children',
#  'with',
#  'developmental',
#  'disorder',
#  'community',
#  'service',
#  'custom',
#  'online',
#  'courses',
#  'customer',
#  'centric',
#  'schools',
#  'data',
#  'enrollment',
#  'enrollment',
#  'growth',
#  'extra',
#  'curricular',
#  'activities',
#  'flexibility',
#  'focus',
#  'free',
#  'summer',
#  'school',
#  'growth',
#  'in',
#  'charter',
#  'schools',
#  'haiti',
#  'fundraiser',
#  'highly',
#  'qualified',
#  'teachers',
#  'holiday',
#  'stress',
#  'for',
#  'kids',
#  'homeschool',
#  'academics',
#  'homeschool',
#  'and',
#  'college',
#  'homeschool',
#  'objections',
#  'homeschool',
#  'research',
#  'homeschool',
#  'socialization',
#  'homeschooling',
#  'saves',
#  'money',
#  'how',
#  'to',
#  'enroll',
#  'at',
#  'method',
#  'how',
#  'to',
#  'study',
#  'myths',
#  'about',
#  'charter',
#  'schools',
#  'no',
#  'help',
#  'for',
#  'bullying',
#  'problem',
#  'personalized',
#  'instruction',
#  'plan',
#  'c',
#  'problems',
#  'with',
#  'school',
#  'clicks',
#  'and',
#  'bullying',
#  'psychological',
#  'stress',
#  'of',
#  'school',
#  'overcrowding',
#  'public',
#  'charter',
#  'school',
#  'public',
#  'tax',
#  'dollars',
#  'red',
#  'ocean',
#  'san',
#  'diego',
#  'charter',
#  'schools',
#  'school',
#  'funding',
#  'school',
#  'overcrowding',
#  'school',
#  'partnerships',
#  'school',
#  'problems',
#  'school',
#  'routine',
#  'school',
#  'social',
#  'hierarchy',
#  'smaller',
#  'schools',
#  'stem',
#  'student',
#  'blogs',
#  'student',
#  'conflicts',
#  'student',
#  'data',
#  'students',
#  'who',
#  'are',
#  'behind',
#  'not',
#  'getting',
#  'help',
#  'study',
#  'tips',
#  'summer',
#  'enrichment',
#  'ideas',
#  'teacher',
#  'support',
#  'teaching',
#  'your',
#  'child',
#  'how',
#  'to',
#  'give',
#  'back',
#  'the',
#  'foundry',
#  'volunteering',
#  'why',
#  'do',
#  'we',
#  'have',
#  'school',
#  'problems',
#  'why',
#  'do',
#  'we',
#  'have',
#  'school',
#  'shootings',
#  'why',
#  'should',
#  'I',
#  'homeschool',
#  'winter',
#  'break',
#  'All',
#  'Topics',
#  'Project',
#  'Based',
#  'Learning',
#  'Charter',
#  'Schools',
#  'Online',
#  'Learning',
#  'Small',
#  'Class',
#  'Sizes',
#  'School',
#  'Choice',
#  'online',
#  'high',
#  'school',
#  'Service',
#  'Learning',
#  'online',
#  'home',
#  'school',
#  'Method',
#  'Schools',
#  'Online',
#  'Curriculum',
#  'home',
#  'school',
#  'homeschooling',
#  'Class',
#  'Size',
#  'quality',
#  'schools',
#  'personalization',
#  'Blended',
#  'Learning',
#  'Choosing',
#  'the',
#  'Right',
#  'School',
#  'Independent',
#  'Study',
#  'Innovation',
#  'Class',
#  'Size',
#  'Reduction',
#  'Data',
#  'Driven',
#  'Education',
#  'online',
#  'middle',
#  'school',
#  'Character',
#  'Education',
#  'E',
#  'Learning',
#  'Method',
#  'High',
#  'School',
#  'Robotics',
#  'Traditional',
#  'School',
#  'curriculum',
#  'smartfox',
#  'Breakthrough',
#  'Schools',
#  'Change',
#  'Focused',
#  'Direct',
#  'Instruction',
#  'Summer',
#  'School',
#  'school',
#  'districts',
#  'EdTech',
#  'PBL',
#  'common',
#  'core',
#  'individualized',
#  'learning',
#  'middle',
#  'school',
#  'online',
#  'summer',
#  'school',
#  'Customized',
#  'Classroom',
#  'Differentiation',
#  'Field',
#  'Trips',
#  'Getting',
#  'into',
#  'college',
#  'LMS',
#  'Learning',
#  'Disabilities',
#  'Non',
#  'traditional',
#  'schools',
#  'Rotational',
#  'Model',
#  'SIS',
#  'STEM',
#  'Charter',
#  'School',
#  'STEM',
#  'School',
#  'Station',
#  'Rotation',
#  'UC',
#  'a',
#  'g',
#  'adaptive',
#  'curriculum',
#  'charter',
#  'school',
#  'funding',
#  'education',
#  'budgets',
#  'education',
#  'funding',
#  'experiental',
#  'learning',
#  'hands',
#  'on',
#  'learning',
#  'homework',
#  'help',
#  'for',
#  'parents',
#  'personalized',
#  'learning',
#  'schools',
#  'and',
#  'dyslexia',
#  'ADD',
#  'ADHD',
#  'ADHD',
#  'holidays',
#  'Accountability',
#  'Activities',
#  'for',
#  'kids',
#  'Arcadia',
#  'California',
#  'LCFF',
#  'Doctorate',
#  'Dyslexia',
#  'Dyslexia',
#  'help',
#  'Education',
#  'Dogma',
#  'Exercise',
#  'FDI',
#  'Goals',
#  'Grants',
#  'Help',
#  'for',
#  'Learning',
#  'Disabilities',
#  'Homeschool',
#  'misconceptions',
#  'Leadership',
#  'Learning',
#  'help',
#  'Los',
#  'Angeles',
#  'Charter',
#  'Schools',
#  'Method',
#  'Schools',
#  'Arcadia',
#  'NCAA',
#  'approved',
#  'NGLC',
#  'Opening',
#  'New',
#  'Schools',
#  'Outcomes',
#  'Parents',
#  'and',
#  'Dyslexia',
#  'PhD',
#  'STEM',
#  'Education',
#  'STEM',
#  'Program',
#  'Schoolism',
#  'Science',
#  'Science',
#  'Fair',
#  'Socialization',
#  'Student',
#  'Marketing',
#  'Projects',
#  'Technology',
#  'in',
#  'Education',
#  'WASC',
#  'WInter',
#  'Vacation',
#  'What',
#  'is',
#  'Dyslexia',
#  'alternative',
#  'education',
#  'automation',
#  'autumn',
#  'service',
#  'learning',
#  ...]

# %%
#df["PROG_RATIO"] = df["PROG_COUNT"]/df["NUMWORDS"]
(df["PROG_COUNT"]/df["NUMWORDS"]).describe()
# Out:
# count    7294.000000
# mean        0.002320
# std         0.003076
# min         0.000000
# 25%         0.000436
# 50%         0.001487
# 75%         0.003184
# max         0.068783
# dtype: float64

# %%
df[df['PROG_COUNT'].isnull()]['NUMWORDS'].describe() # count is nan only when numwords is nan (nan webtext)
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: NUMWORDS, dtype: float64

# %%
# Find minima exclusive of artificial values (-6)
prog_min = df.loc[(df['PROG_STR']!=-6) & (df['NUMWORDS'] > 0), 'PROG_STR'].min()
ess_min = df.loc[(df['ESS_STR']!=-6) & (df['NUMWORDS'] > 0), 'ESS_STR'].min()
rit_min = df.loc[(df['RIT_STR']!=-6) & (df['NUMWORDS'] > 0), 'RIT_STR'].min()

# %%
# Set strength variables to be -6 when numwords was > 0, but strength was nan (can change this from -6 to actual min)
df.loc[(df['PROG_STR']==-6) & (df['NUMWORDS'] > 0), 'PROG_STR'] = -6 #prog_min
df.loc[(df['ESS_STR']==-6) & (df['NUMWORDS'] > 0), 'ESS_STR'] = -6 #ess_min
df.loc[(df['RIT_STR']==-6) & (df['NUMWORDS'] > 0), 'RIT_STR'] = -6 #rit_min

# %%
# Compare current minima of DF (probably -6) with minima excluding artificial values (-6)
print(df[['PROG_STR', 'ESS_STR', 'RIT_STR']].min())
print()
print(prog_min)
print(ess_min)
print(rit_min)
# Out:
# PROG_STR   -6.0
# ESS_STR    -6.0
# RIT_STR    -6.0
# dtype: float64
#
# -5.37196509277
# -4.7873471039
# -4.33057240761

# %%
df.loc[(df['PROG_STR']==-6) & (df['NUMWORDS'] > 0)]
# Out:
#                                    CMO_NAME  CMO_MEMSUM  \
# 4                                      AAEC      1320.0
# 5      Arizona Agribusiness & Equine Center      1320.0
# 19               ARLINGTON CLASSICS ACADEMY      1442.0
# 21               ARLINGTON CLASSICS ACADEMY      1442.0
# 22                             ASPIRA of PA      3966.0
# 23      OmniVest Properties Management, LLC      7075.0
# 28                             ASPIRA of PA      3966.0
# 29                                Academica     48541.0
# 30                         Somerset Academy     23411.0
# 31                                Academica     48541.0
# 32                         Somerset Academy     23411.0
# 33                                Academica     48541.0
# 34                         Somerset Academy     23411.0
# 35                                Academica     48541.0
# 36                         Somerset Academy     23411.0
# 39                                Academica     48541.0
# 40                         Somerset Academy     23411.0
# 44                                Academica     48541.0
# 45                         Somerset Academy     23411.0
# 46                                Academica     48541.0
# 47                         Somerset Academy     23411.0
# 48                         Somerset Academy     23411.0
# 49                                Academica     48541.0
# 50                         Somerset Academy     23411.0
# 51                                Academica     48541.0
# 52                         Somerset Academy     23411.0
# 53                                Academica     48541.0
# 54                         Somerset Academy     23411.0
# 55                                Academica     48541.0
# 56                         Somerset Academy     23411.0
# ...                                     ...         ...
# 11124                                   NaN         NaN
# 11125                                   NaN         NaN
# 11129                                   NaN         NaN
# 11136                                   NaN         NaN
# 11143                                   NaN         NaN
# 11144                                   NaN         NaN
# 11147                                   NaN         NaN
# 11149                                   NaN         NaN
# 11152                                   NaN         NaN
# 11169                                   NaN         NaN
# 11175                                   NaN         NaN
# 11176                                   NaN         NaN
# 11179                                   NaN         NaN
# 11180                                   NaN         NaN
# 11182                                   NaN         NaN
# 11188                                   NaN         NaN
# 11190                                   NaN         NaN
# 11192                                   NaN         NaN
# 11193                                   NaN         NaN
# 11206                                   NaN         NaN
# 11316                                   NaN         NaN
# 11327                                   NaN         NaN
# 11333                                   NaN         NaN
# 11335                                   NaN         NaN
# 11369                                   NaN         NaN
# 11370                                   NaN         NaN
# 11378                                   NaN         NaN
# 11379                                   NaN         NaN
# 11386                                   NaN         NaN
# 11396                                   NaN         NaN
#
#                                                 SCH_NAME CMO_STATE  \
# 4                                 AAEC - PARADISE VALLEY        AZ
# 5                                 AAEC - PARADISE VALLEY        AZ
# 19                   ARLINGTON CLASSICS ACADEMY - MIDDLE        TX
# 21              ARLINGTON CLASSICS ACADEMY -INTERMEDIATE        TX
# 22              ANTONIA PANTOJA COMMUNITY CHARTER SCHOOL        PA
# 23              ANTONIA PANTOJA COMMUNITY CHARTER SCHOOL        PA
# 28                            EUGENIO MARIA DE HOSTOS CS        PA
# 29              SOMERSET ACADEMY KEY CHARTER HIGH SCHOOL        FL
# 30              SOMERSET ACADEMY KEY CHARTER HIGH SCHOOL        NY
# 31                            KEY WEST COLLEGIATE SCHOOL        FL
# 32                            KEY WEST COLLEGIATE SCHOOL        NY
# 33                        SOMERSET ACADEMY DAVIE CHARTER        FL
# 34                        SOMERSET ACADEMY DAVIE CHARTER        NY
# 35              SOMERSET ACADEMY-ELEMENTARY EAGLE CAMPUS        FL
# 36              SOMERSET ACADEMY-ELEMENTARY EAGLE CAMPUS        NY
# 39          SOMERSET ACADEMY ELEMENTARY (MIRAMAR CAMPUS)        FL
# 40          SOMERSET ACADEMY ELEMENTARY (MIRAMAR CAMPUS)        NY
# 44                       SOMERSET ACADEMY (SILVER PALMS)        FL
# 45                       SOMERSET ACADEMY (SILVER PALMS)        NY
# 46     SOMERSET ACADEMY CHARTER MIDDLE SCHOOL SOUTH M...        FL
# 47     SOMERSET ACADEMY CHARTER MIDDLE SCHOOL SOUTH M...        NY
# 48     SOMERSET ACADEMY CHARTER MIDDLE SCHOOL SOUTH M...        NY
# 49                                  SOMERSET ACADEMY BAY        FL
# 50                                  SOMERSET ACADEMY BAY        NY
# 51                    SOMERSET ACADEMY BAY MIDDLE SCHOOL        FL
# 52                    SOMERSET ACADEMY BAY MIDDLE SCHOOL        NY
# 53                            SOMERSET ACADEMY BOCA EAST        FL
# 54                            SOMERSET ACADEMY BOCA EAST        NY
# 55                   SOMERSET ACADEMY BOCA MIDDLE SCHOOL        FL
# 56                   SOMERSET ACADEMY BOCA MIDDLE SCHOOL        NY
# ...                                                  ...       ...
# 11124                                                NaN       NaN
# 11125                                                NaN       NaN
# 11129                                                NaN       NaN
# 11136                                                NaN       NaN
# 11143                                                NaN       NaN
# 11144                                                NaN       NaN
# 11147                                                NaN       NaN
# 11149                                                NaN       NaN
# 11152                                                NaN       NaN
# 11169                                                NaN       NaN
# 11175                                                NaN       NaN
# 11176                                                NaN       NaN
# 11179                                                NaN       NaN
# 11180                                                NaN       NaN
# 11182                                                NaN       NaN
# 11188                                                NaN       NaN
# 11190                                                NaN       NaN
# 11192                                                NaN       NaN
# 11193                                                NaN       NaN
# 11206                                                NaN       NaN
# 11316                                                NaN       NaN
# 11327                                                NaN       NaN
# 11333                                                NaN       NaN
# 11335                                                NaN       NaN
# 11369                                                NaN       NaN
# 11370                                                NaN       NaN
# 11378                                                NaN       NaN
# 11379                                                NaN       NaN
# 11386                                                NaN       NaN
# 11396                                                NaN       NaN
#
#        CMO_SCHNUM                                          CMO_URL  \
# 4             6.0                 https://www.aaechighschools.com/
# 5             6.0                 https://www.aaechighschools.com/
# 19            3.0                           http://www.acaedu.net/
# 21            3.0                           http://www.acaedu.net/
# 22            5.0                         http://www.aspirapa.org/
# 23           19.0  http://www.omnivestllc.com/omnivest_properties/
# 28            5.0                         http://www.aspirapa.org/
# 29          108.0                        http://www.academica.org/
# 30           67.0           http://www.somersetacademyschools.com/
# 31          108.0                        http://www.academica.org/
# 32           67.0           http://www.somersetacademyschools.com/
# 33          108.0                        http://www.academica.org/
# 34           67.0           http://www.somersetacademyschools.com/
# 35          108.0                        http://www.academica.org/
# 36           67.0           http://www.somersetacademyschools.com/
# 39          108.0                        http://www.academica.org/
# 40           67.0           http://www.somersetacademyschools.com/
# 44          108.0                        http://www.academica.org/
# 45           67.0           http://www.somersetacademyschools.com/
# 46          108.0                        http://www.academica.org/
# 47           67.0           http://www.somersetacademyschools.com/
# 48           67.0           http://www.somersetacademyschools.com/
# 49          108.0                        http://www.academica.org/
# 50           67.0           http://www.somersetacademyschools.com/
# 51          108.0                        http://www.academica.org/
# 52           67.0           http://www.somersetacademyschools.com/
# 53          108.0                        http://www.academica.org/
# 54           67.0           http://www.somersetacademyschools.com/
# 55          108.0                        http://www.academica.org/
# 56           67.0           http://www.somersetacademyschools.com/
# ...           ...                                              ...
# 11124         NaN                                              NaN
# 11125         NaN                                              NaN
# 11129         NaN                                              NaN
# 11136         NaN                                              NaN
# 11143         NaN                                              NaN
# 11144         NaN                                              NaN
# 11147         NaN                                              NaN
# 11149         NaN                                              NaN
# 11152         NaN                                              NaN
# 11169         NaN                                              NaN
# 11175         NaN                                              NaN
# 11176         NaN                                              NaN
# 11179         NaN                                              NaN
# 11180         NaN                                              NaN
# 11182         NaN                                              NaN
# 11188         NaN                                              NaN
# 11190         NaN                                              NaN
# 11192         NaN                                              NaN
# 11193         NaN                                              NaN
# 11206         NaN                                              NaN
# 11316         NaN                                              NaN
# 11327         NaN                                              NaN
# 11333         NaN                                              NaN
# 11335         NaN                                              NaN
# 11369         NaN                                              NaN
# 11370         NaN                                              NaN
# 11378         NaN                                              NaN
# 11379         NaN                                              NaN
# 11386         NaN                                              NaN
# 11396         NaN                                              NaN
#
#        CMO_NUMSTATES      CMO_ALLSTATES CMO_SECTOR  CMO_NUMSTUDENTS_CREDO17  \
# 4                1.0                 AZ        NaN                      NaN
# 5                1.0                 AZ        CMO                   1220.0
# 19               1.0                 TX        NaN                      NaN
# 21               1.0                 TX        NaN                      NaN
# 22               1.0                 PA        CMO                   3494.0
# 23               1.0                 PA        VOS                   5313.0
# 28               1.0                 PA        CMO                   3494.0
# 29               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 30               1.0                 NY     Hybrid                  14951.0
# 31               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 32               1.0                 NY     Hybrid                  14951.0
# 33               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 34               1.0                 NY     Hybrid                  14951.0
# 35               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 36               1.0                 NY     Hybrid                  14951.0
# 39               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 40               1.0                 NY     Hybrid                  14951.0
# 44               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 45               1.0                 NY     Hybrid                  14951.0
# 46               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 47               1.0                 NY     Hybrid                  14951.0
# 48               1.0                 NY     Hybrid                  14951.0
# 49               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 50               1.0                 NY     Hybrid                  14951.0
# 51               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 52               1.0                 NY     Hybrid                  14951.0
# 53               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 54               1.0                 NY     Hybrid                  14951.0
# 55               6.0  FL,UT,CA,NV,TX,DC        VOS                  23788.0
# 56               1.0                 NY     Hybrid                  14951.0
# ...              ...                ...        ...                      ...
# 11124            NaN                NaN        NaN                      NaN
# 11125            NaN                NaN        NaN                      NaN
# 11129            NaN                NaN        NaN                      NaN
# 11136            NaN                NaN        NaN                      NaN
# 11143            NaN                NaN        NaN                      NaN
# 11144            NaN                NaN        NaN                      NaN
# 11147            NaN                NaN        NaN                      NaN
# 11149            NaN                NaN        NaN                      NaN
# 11152            NaN                NaN        NaN                      NaN
# 11169            NaN                NaN        NaN                      NaN
# 11175            NaN                NaN        NaN                      NaN
# 11176            NaN                NaN        NaN                      NaN
# 11179            NaN                NaN        NaN                      NaN
# 11180            NaN                NaN        NaN                      NaN
# 11182            NaN                NaN        NaN                      NaN
# 11188            NaN                NaN        NaN                      NaN
# 11190            NaN                NaN        NaN                      NaN
# 11192            NaN                NaN        NaN                      NaN
# 11193            NaN                NaN        NaN                      NaN
# 11206            NaN                NaN        NaN                      NaN
# 11316            NaN                NaN        NaN                      NaN
# 11327            NaN                NaN        NaN                      NaN
# 11333            NaN                NaN        NaN                      NaN
# 11335            NaN                NaN        NaN                      NaN
# 11369            NaN                NaN        NaN                      NaN
# 11370            NaN                NaN        NaN                      NaN
# 11378            NaN                NaN        NaN                      NaN
# 11379            NaN                NaN        NaN                      NaN
# 11386            NaN                NaN        NaN                      NaN
# 11396            NaN                NaN        NaN                      NaN
#
#          ...    PROG_COUNT RIT_COUNT ESS_COUNT   ESS_STR PROG_STR   RIT_STR  \
# 4        ...             0         1         0 -6.000000     -6.0 -2.664642
# 5        ...             0         1         0 -6.000000     -6.0 -2.664642
# 19       ...             0         2         0 -6.000000     -6.0 -2.586587
# 21       ...             0         2         0 -6.000000     -6.0 -2.416641
# 22       ...             0         5         2 -2.226600     -6.0 -1.831230
# 23       ...             0         5         2 -2.226600     -6.0 -1.831230
# 28       ...             0        42        19 -2.188410     -6.0 -1.846278
# 29       ...             0         0         0 -6.000000     -6.0 -6.000000
# 30       ...             0         0         0 -6.000000     -6.0 -6.000000
# 31       ...             0         0         0 -6.000000     -6.0 -6.000000
# 32       ...             0         0         0 -6.000000     -6.0 -6.000000
# 33       ...             0         0         0 -6.000000     -6.0 -6.000000
# 34       ...             0         0         0 -6.000000     -6.0 -6.000000
# 35       ...             0         0         0 -6.000000     -6.0 -6.000000
# 36       ...             0         0         0 -6.000000     -6.0 -6.000000
# 39       ...             0         0         0 -6.000000     -6.0 -6.000000
# 40       ...             0         0         0 -6.000000     -6.0 -6.000000
# 44       ...             0         0         0 -6.000000     -6.0 -6.000000
# 45       ...             0         0         0 -6.000000     -6.0 -6.000000
# 46       ...             0         0         0 -6.000000     -6.0 -6.000000
# 47       ...             0         0         0 -6.000000     -6.0 -6.000000
# 48       ...             0         0         0 -6.000000     -6.0 -6.000000
# 49       ...             0         0         0 -6.000000     -6.0 -6.000000
# 50       ...             0         0         0 -6.000000     -6.0 -6.000000
# 51       ...             0         0         0 -6.000000     -6.0 -6.000000
# 52       ...             0         0         0 -6.000000     -6.0 -6.000000
# 53       ...             0         0         0 -6.000000     -6.0 -6.000000
# 54       ...             0         0         0 -6.000000     -6.0 -6.000000
# 55       ...             0         0         0 -6.000000     -6.0 -6.000000
# 56       ...             0         0         0 -6.000000     -6.0 -6.000000
# ...      ...           ...       ...       ...       ...      ...       ...
# 11124    ...             0         2         0 -6.000000     -6.0 -2.358886
# 11125    ...             0         2         0 -6.000000     -6.0 -2.344392
# 11129    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11136    ...             0        10         0 -6.000000     -6.0 -1.858537
# 11143    ...             0         1         1 -2.757396     -6.0 -2.757396
# 11144    ...             0         2         0 -6.000000     -6.0 -2.171726
# 11147    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11149    ...             0         1         1 -2.878522     -6.0 -2.878522
# 11152    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11169    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11175    ...             0        49        67 -2.469426     -6.0 -2.604292
# 11176    ...             0         1         0 -6.000000     -6.0 -2.829947
# 11179    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11180    ...             0        27         5 -2.894205     -6.0 -2.161146
# 11182    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11188    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11190    ...             0         6         0 -6.000000     -6.0 -1.847161
# 11192    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11193    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11206    ...             0        58         0 -6.000000     -6.0 -2.234701
# 11316    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11327    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11333    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11335    ...             0         1         0 -6.000000     -6.0 -3.665862
# 11369    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11370    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11378    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11379    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11386    ...             0         0         0 -6.000000     -6.0 -6.000000
# 11396    ...             0         2         1 -2.656098     -6.0 -2.354108
#
#        NUMWORDS PROG_NORM  ESS_NORM  RIT_NORM
# 4           462       0.0  0.000000  0.682455
# 5           462       0.0  0.000000  0.682455
# 19          772       0.0  0.000000  0.698426
# 21          522       0.0  0.000000  0.733199
# 22          339       0.0  0.829002  0.852981
# 23          339       0.0  0.829002  0.852981
# 28         2948       0.0  0.837393  0.849902
# 29            1       0.0  0.000000  0.000000
# 30            1       0.0  0.000000  0.000000
# 31            1       0.0  0.000000  0.000000
# 32            1       0.0  0.000000  0.000000
# 33            1       0.0  0.000000  0.000000
# 34            1       0.0  0.000000  0.000000
# 35            1       0.0  0.000000  0.000000
# 36            1       0.0  0.000000  0.000000
# 39            1       0.0  0.000000  0.000000
# 40            1       0.0  0.000000  0.000000
# 44            1       0.0  0.000000  0.000000
# 45            1       0.0  0.000000  0.000000
# 46            1       0.0  0.000000  0.000000
# 47            1       0.0  0.000000  0.000000
# 48            1       0.0  0.000000  0.000000
# 49            1       0.0  0.000000  0.000000
# 50            1       0.0  0.000000  0.000000
# 51            1       0.0  0.000000  0.000000
# 52            1       0.0  0.000000  0.000000
# 53            1       0.0  0.000000  0.000000
# 54            1       0.0  0.000000  0.000000
# 55            1       0.0  0.000000  0.000000
# 56            1       0.0  0.000000  0.000000
# ...         ...       ...       ...       ...
# 11124       458       0.0  0.000000  0.745016
# 11125       443       0.0  0.000000  0.747982
# 11129       120       0.0  0.000000  0.000000
# 11136       724       0.0  0.000000  0.847394
# 11143       572       0.0  0.712388  0.663476
# 11144       298       0.0  0.000000  0.783311
# 11147        13       0.0  0.000000  0.000000
# 11149       756       0.0  0.685778  0.638692
# 11152        13       0.0  0.000000  0.000000
# 11169        33       0.0  0.000000  0.000000
# 11175     19747       0.0  0.775654  0.694803
# 11176       676       0.0  0.000000  0.648631
# 11179        56       0.0  0.000000  0.000000
# 11180      3919       0.0  0.682332  0.785476
# 11182         5       0.0  0.000000  0.000000
# 11188        69       0.0  0.000000  0.000000
# 11190       423       0.0  0.000000  0.849721
# 11192        72       0.0  0.000000  0.000000
# 11193         8       0.0  0.000000  0.000000
# 11206      9986       0.0  0.000000  0.770426
# 11316       261       0.0  0.000000  0.000000
# 11327       157       0.0  0.000000  0.000000
# 11333         1       0.0  0.000000  0.000000
# 11335      4634       0.0  0.000000  0.477593
# 11369         1       0.0  0.000000  0.000000
# 11370         1       0.0  0.000000  0.000000
# 11378         1       0.0  0.000000  0.000000
# 11379         1       0.0  0.000000  0.000000
# 11386         1       0.0  0.000000  0.000000
# 11396       453       0.0  0.734643  0.745994
#
# [1398 rows x 404 columns]

# %%
# Normalize strength variables to 0-1 distribution:
df["PROG_NORM"] = (df["PROG_STR"] - df["PROG_STR"].min()) / (df["PROG_STR"].max() - df["PROG_STR"].min())
df["ESS_NORM"] = (df["ESS_STR"] - df["ESS_STR"].min()) / (df["ESS_STR"].max() - df["ESS_STR"].min())
df["RIT_NORM"] = (df["RIT_STR"] - df["RIT_STR"].min()) / (df["RIT_STR"].max() - df["RIT_STR"].min())

# %%
df[['PROG_NORM','RIT_NORM','ESS_NORM', 'PROG_STR', 'ESS_STR', 'RIT_STR']].describe()
# Out:
#          PROG_NORM     RIT_NORM     ESS_NORM     PROG_STR      ESS_STR  \
# count  7294.000000  7294.000000  7294.000000  7294.000000  7294.000000
# mean      0.547583     0.690593     0.558169    -3.351078    -3.459361
# std       0.277854     0.263590     0.291184     1.344113     1.325394
# min       0.000000     0.000000     0.000000    -6.000000    -6.000000
# 25%       0.545750     0.715841     0.543434    -3.359943    -3.526430
# 50%       0.655855     0.782798     0.674577    -2.827314    -2.929505
# 75%       0.724318     0.825747     0.744854    -2.496125    -2.609622
# max       1.000000     1.000000     1.000000    -1.162518    -1.448265
#
#            RIT_STR
# count  7294.000000
# mean     -2.624867
# std       1.288241
# min      -6.000000
# 25%      -2.501471
# 50%      -2.174233
# 75%      -1.964332
# max      -1.112704

# %%
df[['PROG_NORM', 'ESS_NORM', 'RIT_NORM']].hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff1728ce7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff169af5978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff169a8ac18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff169a9d198>]], dtype=object)

# %%
df[['ESS_STR','PROG_STR','RIT_STR']].hist(bins=20)
plt.show()

# %%
df.to_pickle(filepath)

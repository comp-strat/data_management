# %% [markdown]
# # For cleaner/updated version, see count_dict

# %%
import multiprocessing as mp
import pandas as pd
import re
import numpy as np
import time
from nltk.stem.porter import PorterStemmer


stemmer = PorterStemmer()
stem = stemmer.stem # stemmer function

charter_path = '../../charters_full_2015_15_250.pkl'
df_charter = pd.read_pickle(charter_path)

dict_path = '/home/jovyan/work/Charter-school-identities/dicts/'
dict_names = ['discipline', 'inquiry'] # names of txt file holding dictionary
dicts = [] # loaded list of dicts
for dname in dict_names:  
    with open(dict_path+dname) as f: 
        dicts.append(f.read().splitlines())

# %%
df_charter['WEBTEXT_METHOD'].value_counts()
# Out:
# 3    11182
# 0      339
# Name: WEBTEXT_METHOD, dtype: int64

# %%
class Page:
    def __init__(self,p):
        self.url = p[0]
        self.boo = p[1]
        self.depth = p[2]
        self.text = p[3]
    def __repr__(self):
        return self.text
    def __eq__(self, other):
        if isinstance(other, Page):
            return self.text == other.text
        else:
            return False
    def __ne__(self, other):
        return (not self.__eq__(other))
    def __hash__(self):
        return hash(self.__repr__())
    
def dict_precalc(keywords):
    for entry in keywords:
        small_keywords.append(entry) if len(re.split('\W+|_', entry)) < 3 else large_keywords.append(entry)

    large_words = [[stem(x) for x in re.split('\W+|_', entry)] for entry in large_keywords] # list words for each large dict entry
    large_lengths = [len(x) for x in large_words]
    large_first_words = [x[0] for x in large_words] # first words of each large entry in dict
    key_words = [[stem(x) for x in re.split('\W+|_', entry)] for entry in keywords]
    return [large_words, large_lengths, large_first_words, key_words]


def dict_count2(key_words, large_words, large_lengths, large_first_words, pages):

    """Returns the hit count with given dictionary on page set.

    pages: set of preprocessed page lists corresponding to an entry of the 'webtext' column
    """
    counts = 0 # Number of matches between text_list and keywords
    res_length = 0
    for splitted_phrase in pages:
        for length in range(1, 3):
            if len(splitted_phrase) < length:
                continue # If text chunk is shorter than length of dict entries being matched, there are no matches.
            for i in range(len(splitted_phrase) - length + 1):
                entry = splitted_phrase[i:i+length]
                if entry in key_words:
                    counts += 1
                    res_length += length - 1
        indices = np.transpose(np.nonzero([[word == entry for word in splitted_phrase] for entry in large_first_words]))
        for ind in indices:
            if ind[1] <= (len(splitted_phrase) - large_lengths[ind[0]]) and large_words[ind[0]] == splitted_phrase[ind[1] : ind[1] + large_lengths[ind[0]]]:
                counts += 1
                res_length += large_lengths[ind[0]] - 1
    return counts, res_length

# %%
disc_pre = dict_precalc(dict_ess)
inq_pre = dict_precalc(dict_prog)
rit_pre = dict_precalc(dict_rit)

# %%
def parallel_count(df):
    precalc_list = [dict_precalc(d) for d in dicts]
    res_list = []
#     e_res = [] # sum of matched keyword length - 1 used to correct for number of (key)words in pages of a school for a more accurate hit ratio
#     p_res = [] # same except for keywords in progressive dict
#     r_res = [] # ritualistic
    count_list = []
#     ess_count = []
#     prog_count = []
#     rit_count = []
    num_words = []
    start = time.time()
    for i, row in enumerate(df['WEBTEXT'].values):
        pages = set([Page(p) for p in row])
        pages = [[stem(x) for x in re.split('\W+|_', p.text)] for p in pages] # preprocess pages in same way as dictionaries should have been in above precalc function
        num_words.append(sum([len(p) for p in pages]))
        disc_c, disc_res = dict_count2(disc_pre[3], ess_pre[0], ess_pre[1], ess_pre[2], pages)
        inq_c, inq_res = dict_count2(prog_pre[3], prog_pre[0], prog_pre[1], prog_pre[2], pages)
        rit_c, rit_res = dict_count2(rit_pre[3], rit_pre[0], rit_pre[1], rit_pre[2], pages)
        ess_count.append(ess_c)
        prog_count.append(prog_c)
        rit_count.append(rit_c)
        e_res.append(ess_res)
        p_res.append(prog_res)
        r_res.append(rit_res)
        if i%100 == 0:
            end = time.time()
            print('Time Elapsed:{:f}, Percent Complete:{:f}'.format(end - start,i*100/len(df)))
    df.loc[:,'PROG_COUNT'] = np.array(prog_count)
    df.loc[:,'RIT_COUNT'] = np.array(rit_count)
    df.loc[:,'ESS_COUNT'] = np.array(ess_count)
    df.loc[:,'ESS_STR'] = np.log10(np.array(ess_count)/(np.array(num_words) - np.array(e_res)))
    df.loc[:,'PROG_STR'] = np.log10(np.array(prog_count)/(np.array(num_words) - np.array(p_res)))
    df.loc[:,'RIT_STR'] = np.log10(np.array(rit_count)/(np.array(num_words) - np.array(r_res)))
    df.replace([np.inf, -np.inf], np.nan, inplace = True)
    return df

# %%
[range(11000)[300*i:i*300+300] for i in range(round(11000/300)+1)] # checking for below
# Out:
# [range(0, 300),
#  range(300, 600),
#  range(600, 900),
#  range(900, 1200),
#  range(1200, 1500),
#  range(1500, 1800),
#  range(1800, 2100),
#  range(2100, 2400),
#  range(2400, 2700),
#  range(2700, 3000),
#  range(3000, 3300),
#  range(3300, 3600),
#  range(3600, 3900),
#  range(3900, 4200),
#  range(4200, 4500),
#  range(4500, 4800),
#  range(4800, 5100),
#  range(5100, 5400),
#  range(5400, 5700),
#  range(5700, 6000),
#  range(6000, 6300),
#  range(6300, 6600),
#  range(6600, 6900),
#  range(6900, 7200),
#  range(7200, 7500),
#  range(7500, 7800),
#  range(7800, 8100),
#  range(8100, 8400),
#  range(8400, 8700),
#  range(8700, 9000),
#  range(9000, 9300),
#  range(9300, 9600),
#  range(9600, 9900),
#  range(9900, 10200),
#  range(10200, 10500),
#  range(10500, 10800),
#  range(10800, 11000)]

# %%
with mp.Pool(processes = mp.cpu_count() - 1) as pool:
    results = pool.map(parallel_count, [df_charter[300*i:i*300+300] for i in range(round(len(df_charter)/300)+1)]) # execute on chunks of 300(arbitrary)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-5e914cec8545> in <module>()
# ----> 1 with mp.Pool(processes = mp.cpu_count() - 1) as pool:
#       2     results = pool.map(parallel_count, [df_charter[300*i:i*300+300] for i in range(round(len(df_charter)/300))]) # 300 chunks arbitrary
#
# /opt/conda/lib/python3.6/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     117         from .pool import Pool
#     118         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 119                     context=self.get_context())
#     120
#     121     def RawValue(self, typecode_or_type, *args):
#
# /opt/conda/lib/python3.6/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# /opt/conda/lib/python3.6/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# /opt/conda/lib/python3.6/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# /opt/conda/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     275         def _Popen(process_obj):
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#     279     class SpawnProcess(process.BaseProcess):
#
# /opt/conda/lib/python3.6/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      24             pass
#      25         self.returncode = None
# ---> 26         self._launch(process_obj)
#      27
#      28     def duplicate_for_child(self, fd):
#
# /opt/conda/lib/python3.6/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      71         code = 1
#      72         parent_r, child_w = os.pipe()
# ---> 73         self.pid = os.fork()
#      74         if self.pid == 0:
#      75             try:
#
# OSError: [Errno 12] Cannot allocate memory

# %%
(pd.concat(results)).to_pickle('../../charters_full_2015_250.pkl')
# Out:
# 3    954
# 0     46
# Name: WEBTEXT_METHOD, dtype: int64

# %%
# df1[['SCHNAM15','WEBTEXT_METHOD','PROG_COUNT','RIT_COUNT','ESS_COUNT','ESS_STR','PROG_STR','ESS_STR']]
# Out:
#                                              SCHNAM15  WEBTEXT_METHOD  \
# 0     Arizona Agribusiness & Equine Center - Estrella               3
# 1     Arizona Agribusiness & Equine Center - Estrella               3
# 2                                  AAEC - SMCC Campus               3
# 3                                  AAEC - SMCC Campus               3
# 4                              AAEC - Paradise Valley               3
# 5                              AAEC - Paradise Valley               3
# 6                           CUMBERLAND ACADEMY MIDDLE               3
# 7                                      CUMBERLAND H S               3
# 8                                  CUMBERLAND ACADEMY               3
# 9                  ACCELERATED INTERDISCIPLINARY ACAD               3
# 10                     ACCELERATED INT CHARTER SCHOOL               3
# 11                                   AIA LANCASTER EL               3
# 12                               AIA LANCASTER MIDDLE               3
# 13                                   ACE Charter High               3
# 14                                ACE Empower Academy               3
# 15                                ACE Inspire Academy               3
# 16                              ACE Franklin McKinley               3
# 17                          ARISTOI CLASSICAL ACADEMY               3
# 18                     ARISTOI CLASSICAL UPPER SCHOOL               3
# 19                ARLINGTON CLASSICS ACADEMY - MIDDLE               3
# 20                   ARLINGTON CLASSICS ACADEMY - PRI               3
# 21           ARLINGTON CLASSICS ACADEMY -INTERMEDIATE               3
# 22           Antonia Pantoja Community Charter School               3
# 23           Antonia Pantoja Community Charter School               3
# 24              ASPIRA Bilingual Cyber Charter School               3
# 25              ASPIRA Bilingual Cyber Charter School               3
# 26                          Olney Charter High School               3
# 27                     John B. Stetson Charter School               3
# 28                         Eugenio Maria DE Hostos CS               3
# 29                                                NaN               3
# ..                                                ...             ...
# 70  SOMERSET ACADEMY CHARTER MIDDLE SCHOOL (SOUTH ...               3
# 71             SOMERSET ACADEMY CHARTER MIDDLE SCHOOL               3
# 72             SOMERSET ACADEMY CHARTER MIDDLE SCHOOL               3
# 73             SOMERSET ACADEMY CHARTER MIDDLE SCHOOL               3
# 74                         SOMERSET ARTS CONSERVATORY               3
# 75                         SOMERSET ARTS CONSERVATORY               3
# 76                            SOMERSET GABLES ACADEMY               3
# 77                            SOMERSET GABLES ACADEMY               3
# 78                              SOMERSET OAKS ACADEMY               3
# 79                              SOMERSET OAKS ACADEMY               3
# 80                              SOMERSET OAKS ACADEMY               3
# 81                             SOMERSET PINES ACADEMY               3
# 82                             SOMERSET PINES ACADEMY               3
# 83                             SOMERSET PINES ACADEMY               3
# 84                   SOMERSET ACADEMY AT SILVER PALMS               3
# 85                   SOMERSET ACADEMY AT SILVER PALMS               3
# 86                   SOMERSET ACADEMY AT SILVER PALMS               3
# 87         SOMERSET PREPARATORY CHARTER MIDDLE SCHOOL               3
# 88         SOMERSET PREPARATORY CHARTER MIDDLE SCHOOL               3
# 89         SOMERSET PREPARATORY CHARTER MIDDLE SCHOOL               3
# 90  SOMERSET PREPARATORY ACADEMY CHARTER HIGH AT N...               3
# 91  SOMERSET PREPARATORY ACADEMY CHARTER HIGH AT N...               3
# 92  SOMERSET PREPARATORY ACADEMY CHARTER HIGH AT N...               3
# 93                                      DORAL ACADEMY               3
# 94                                      DORAL ACADEMY               3
# 95                                      DORAL ACADEMY               3
# 96                                      DORAL ACADEMY               3
# 97                                      Doral Academy               3
# 98                                      Doral Academy               3
# 99                                      Doral Academy               3
#
#     PROG_COUNT  RIT_COUNT  ESS_COUNT   ESS_STR  PROG_STR   ESS_STR
# 0            1          7          0       NaN -2.977266       NaN
# 1            1          7          0       NaN -2.977266       NaN
# 2            1          8          0       NaN -2.941014       NaN
# 3            1          8          0       NaN -2.941014       NaN
# 4            0          1          0       NaN       NaN       NaN
# 5            0          1          0       NaN       NaN       NaN
# 6          488        706        192 -2.547275 -2.141070 -2.547275
# 7           37        140         28 -3.420362 -3.299189 -3.420362
# 8          582        826         13 -3.669989 -2.017585 -3.669989
# 9           10         55          6 -2.871767 -2.649335 -2.871767
# 10          10         55          6 -2.871767 -2.649335 -2.871767
# 11          10         55          6 -2.871767 -2.649335 -2.871767
# 12          10         55          6 -2.871767 -2.649335 -2.871767
# 13         116        200         20 -2.913125 -2.149086 -2.913125
# 14         116        200         20 -2.913125 -2.149086 -2.913125
# 15         116        200         20 -2.913125 -2.149086 -2.913125
# 16         116        200         20 -2.913125 -2.149086 -2.913125
# 17         251        294         24 -3.638830 -2.619293 -3.638830
# 18           1          1          0       NaN -2.556303       NaN
# 19           0          2          0       NaN       NaN       NaN
# 20          83        575         42 -3.259497 -2.963492 -3.259497
# 21           0          2          0       NaN       NaN       NaN
# 22           0          5          2 -2.226600       NaN -2.226600
# 23           0          5          2 -2.226600       NaN -2.226600
# 24          32        441        156 -2.278636 -2.968074 -2.278636
# 25          32        441        156 -2.278636 -2.968074 -2.278636
# 26           3         10          2 -2.444045 -2.267954 -2.444045
# 27           0          0          0       NaN       NaN       NaN
# 28           0         42         19 -2.188410       NaN -2.188410
# 29           0          0          0       NaN       NaN       NaN
# ..         ...        ...        ...       ...       ...       ...
# 70          12         53         27 -2.706149 -3.058046 -2.706149
# 71           0          0          0       NaN       NaN       NaN
# 72           0          0          0       NaN       NaN       NaN
# 73           0          0          0       NaN       NaN       NaN
# 74           0          0          0       NaN       NaN       NaN
# 75           0          0          0       NaN       NaN       NaN
# 76           0          0          0       NaN       NaN       NaN
# 77           0          0          0       NaN       NaN       NaN
# 78           0          0          0       NaN       NaN       NaN
# 79           0          0          0       NaN       NaN       NaN
# 80           0          0          0       NaN       NaN       NaN
# 81           0          0          0       NaN       NaN       NaN
# 82           0          0          0       NaN       NaN       NaN
# 83           0          0          0       NaN       NaN       NaN
# 84           0          0          0       NaN       NaN       NaN
# 85           0          0          0       NaN       NaN       NaN
# 86           0          0          0       NaN       NaN       NaN
# 87           0          0          0       NaN       NaN       NaN
# 88           0          0          0       NaN       NaN       NaN
# 89           0          0          0       NaN       NaN       NaN
# 90           0          0          0       NaN       NaN       NaN
# 91           0          0          0       NaN       NaN       NaN
# 92           0          0          0       NaN       NaN       NaN
# 93           0          0          0       NaN       NaN       NaN
# 94           0          0          0       NaN       NaN       NaN
# 95           0          0          0       NaN       NaN       NaN
# 96           0          0          0       NaN       NaN       NaN
# 97           0          0          0       NaN       NaN       NaN
# 98           0          0          0       NaN       NaN       NaN
# 99           0          0          0       NaN       NaN       NaN
#
# [100 rows x 8 columns]

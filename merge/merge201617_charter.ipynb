# %% [markdown]
# # 0. Set Up

# %%
# import libraries
import pandas as pd 
import pickle as pk
import numpy as np

# %%
# Reads each csv file and coverts it into a 2-D data structure (Dataframe).
# Directory
f0 = pd.read_csv("ccd_201617/ccd_sch_029_1617_w_1a_11212017.csv", encoding = "latin1", low_memory = False)
# Lunch Program
f1 = pd.read_csv("ccd_201617/ccd_sch_033_1617_l_2a_11212017.csv", encoding = 'latin1', low_memory = False)
# Membership
f2 = pd.read_csv("ccd_201617/ccd_sch_052_1617_l_2a_11212017.csv", encoding = 'latin1', low_memory = False)
# Staff
f3 = pd.read_csv("ccd_201617/ccd_sch_059_1617_l_2a_11212017.csv", encoding = 'latin1', low_memory = False)
# School Characteristics
f4 = pd.read_csv("ccd_201617/ccd_sch_129_1617_w_1a_11212017.csv", encoding = 'latin1', low_memory = False)
# School Geography
fgeo = pd.read_excel("ccd_201617/EDGE_GEOCODE_PUBLICSCH_1617/EDGE_GEOCODE_PUBLICSCH_1617.xlsx", encoding = 'latin1')

# %%
# pd.set_option is to display all columns when calling dataframe
pd.set_option('display.max_columns', None)
# display the number of columns and rows of each data table
display(np.shape(f0))
display(np.shape(f1))
display(np.shape(f2))
display(np.shape(f3))
display(np.shape(f4))
display(np.shape(fgeo))
# Out:
# (102181, 65)
# (495095, 17)
# (12279594, 18)
# (100062, 15)
# (100062, 20)
# (102173, 24)

# %% [markdown]
# # 1. Select All Charters

# %%
# Select all the charter schools from the directory table (There should at least 7,000 columns.)
charterSchools = f0.loc[f0['CHARTER_TEXT'] == 'Yes' , : ]
charterSchools
# Out:
#        SCHOOL_YEAR  FIPST STATENAME  ST  \
# 152      2016-2017      1   ALABAMA  AL
# 1559     2016-2017      2    ALASKA  AK
# 1658     2016-2017      2    ALASKA  AK
# 1661     2016-2017      2    ALASKA  AK
# 1727     2016-2017      2    ALASKA  AK
# ...            ...    ...       ...  ..
# 100049   2016-2017     56   WYOMING  WY
# 100052   2016-2017     56   WYOMING  WY
# 100055   2016-2017     56   WYOMING  WY
# 100141   2016-2017     56   WYOMING  WY
# 100144   2016-2017     56   WYOMING  WY
#
#                                                  SCH_NAME  \
# 152                     Acceleration Day and Evening Acad
# 1559                                  Ayaprun Elitnaurvik
# 1658                             Ketchikan Charter School
# 1661    Tongass School of Arts and Sciences Charter Sc...
# 1727                              Aquarian Charter School
# ...                                                   ...
# 100049                                Snowy Range Academy
# 100052                  Laramie Montessori Charter School
# 100055                       Arapahoe Charter High School
# 100141                                      PODER Academy
# 100144                     PODER Academy Secondary School
#
#                                          LEA_NAME  STATE_AGENCY_NO  UNION  \
# 152             Acceleration Day and Evening Acad                1    NaN
# 1559              Lower Kuskokwim School District                1    NaN
# 1658    Ketchikan Gateway Borough School District                1    NaN
# 1661    Ketchikan Gateway Borough School District                1    NaN
# 1727                    Anchorage School District                1    NaN
# ...                                           ...              ...    ...
# 100049           Albany County School District #1                1    NaN
# 100052           Albany County School District #1                1    NaN
# 100055         Fremont County School District #38                1    NaN
# 100141          Laramie County School District #1                1    NaN
# 100144          Laramie County School District #1                1    NaN
#
#           ST_LEAID    LEAID  ... G_10_OFFERED  G_11_OFFERED  G_12_OFFERED  \
# 152         AL-800   100197  ...          Yes           Yes           Yes
# 1559         AK-31   200001  ...           No            No            No
# 1658         AK-25   200150  ...           No            No            No
# 1661         AK-25   200150  ...           No            No            No
# 1727         AK-05   200180  ...           No            No            No
# ...            ...      ...  ...          ...           ...           ...
# 100049  WY-0101000  5600730  ...           No            No            No
# 100052  WY-0101000  5600730  ...           No            No            No
# 100055  WY-0738000  5600960  ...          Yes           Yes           Yes
# 100141  WY-1101000  5601980  ...           No            No            No
# 100144  WY-1101000  5601980  ...           No            No            No
#
#        G_13_OFFERED G_UG_OFFERED G_AE_OFFERED GSLO GSHI       LEVEL  \
# 152              No           No           No   09   12        High
# 1559             No           No           No   PK   06  Elementary
# 1658             No           No           No   KG   08  Elementary
# 1661             No           No           No   PK   06  Elementary
# 1727             No           No           No   KG   06  Elementary
# ...             ...          ...          ...  ...  ...         ...
# 100049           No           No           No   KG   09       Other
# 100052           No           No           No   KG   06  Elementary
# 100055           No           No           No   09   12        High
# 100141           No           No           No   KG   05  Elementary
# 100144           No           No           No   06   08      Middle
#
#           IGOFFERED
# 152     As reported
# 1559    As reported
# 1658    As reported
# 1661    As reported
# 1727    As reported
# ...             ...
# 100049  As reported
# 100052  As reported
# 100055  As reported
# 100141  As reported
# 100144  As reported
#
# [7356 rows x 65 columns]

# %%
# Check to see if there is around 7,000 charter schools
display(np.shape(charterSchools))
# Out:
# (7356, 65)

# %%
# Select the NCESSCH column for the charter schools. This will serve as a primary key to merge and extract
# charter schoold from other tables
charter_id = np.array(charterSchools["NCESSCH"])
len(charter_id)
# Out:
# 7356

# %% [markdown]
# # 2. Select Free and Reduced Lunch from f1 table

# %%
# Display the different types of Lunch Program : looking at the output, we want the 
# 'Free lunch qualified' and 'Reduced-price lunch qualified' labels
f1["LUNCH_PROGRAM"].unique()
# Out:
# array(['Free lunch qualified', 'Reduced-price lunch qualified', 'Missing',
#        'Not Applicable', 'No Category Codes', nan], dtype=object)

# %%
# filter the selected labels
lunch_labels = ['Free lunch qualified', 'Reduced-price lunch qualified']
f1_filtered = f1.loc[f1['LUNCH_PROGRAM'].isin(lunch_labels) , : ]

# %%
# Add up the sum of the two lunch program
f1_wide = f1_filtered.groupby("NCESSCH").agg({"STUDENT_COUNT": ['sum']})

# %%
# Rename the new table column
f1_wide.columns = ['Free and Reduced Lunch']

# %%
#Select only charter schools Lunch Programs
charter_lunch = f1_wide.loc[f1_wide.index.isin(charter_id)]
charter_lunch
# Out:
#               Free and Reduced Lunch
# NCESSCH
# 1.001970e+10                     0.0
# 2.000010e+10                   141.0
# 2.001500e+10                    88.0
# 2.001500e+10                    77.0
# 2.001800e+10                     0.0
# ...                              ...
# 4.000796e+11                   598.0
# 4.000796e+11                   145.0
# 4.000796e+11                   116.0
# 4.000796e+11                   552.0
# 4.000796e+11                   684.0
#
# [5369 rows x 1 columns]

# %% [markdown]
# # 3. Explore Membership Table - f2

# %%
# Display the different types of Total Indicators Labels: From the Documentation: 'Education Unit Total' gives the  
# total students enrolled in the school, 'Category Set A - By Race/Ethnicity; Sex; Grade' gives the grade/race/gender count
f2["TOTAL_INDICATOR"].unique()
# Out:
# array(['Category Set A - By Race/Ethnicity; Sex; Grade',
#        'Derived - Education Unit Total minus Adult Education Count',
#        'Derived - Subtotal by Race/Ethnicity and Sex minus Adult Education Count',
#        'Education Unit Total', 'Subtotal 4 - By Grade'], dtype=object)

# %%
# Filter out the null values
f2notNan = f2.loc[pd.notnull(f2['STUDENT_COUNT']), ]

# %%
# Doing a check on 'Education Unit Total'
totals_id = ["Category Set A - By Race/Ethnicity; Sex; Grade"]
f2one = f2.loc[f2["NCESSCH"] == 780003000034, ]
f2onefilter = f2one.loc[f2['TOTAL_INDICATOR'].isin(totals_id) , : ]
f2onesum = f2onefilter.agg({"STUDENT_COUNT": ['sum']})
f2onesum
# Out:
#      STUDENT_COUNT
# sum          537.0

# %%
f2one.loc[f2['TOTAL_INDICATOR'] == "Education Unit Total"]
# Out:
#          SCHOOL_YEAR  FIPST            STATENAME  ST  \
# 12279589   2016-2017     78  U.S. VIRGIN ISLANDS  VI
#
#                               SCH_NAME  STATE_AGENCY_NO  UNION ST_LEAID  \
# 12279589  BERTHA BOSCHULTE JUNIOR HIGH                1    NaN   VI-001
#
#             LEAID  ST_SCHID       NCESSCH    SCHID              GRADE  \
# 12279589  7800030  VI-001-9  780003000034  7800034  No Category Codes
#
#              RACE_ETHNICITY                SEX  STUDENT_COUNT  \
# 12279589  No Category Codes  No Category Codes          537.0
#
#                TOTAL_INDICATOR  DMS_FLAG
# 12279589  Education Unit Total  Reported

# %%
#all_CatA = f2notNan.loc[f2notNan['TOTAL_INDICATOR'].isin(totals_id) , : ]
#agg_total = all_CatA.groupby('NCESSCH').agg({"STUDENT_COUNT": ['sum']})
agg_total.columns = ["calculated_total"]
total_only = f2notNan.loc[f2notNan['TOTAL_INDICATOR'] == 'Education Unit Total', ['NCESSCH', 'STUDENT_COUNT']]
check_total = agg_total.merge(total_only, how="outer", left_index = True, right_on = 'NCESSCH')

# %%
check_total.loc[check_total['NCESSCH'].isin(charter_id)]
# Out:
#           calculated_total       NCESSCH  STUDENT_COUNT
# 345613               163.0   20000100329          163.0
# 364595               186.0   20015000306          186.0
# 364970               174.0   20015000523          174.0
# 374081               378.0   20018000172          378.0
# 374302               622.0   20018000178          622.0
# ...                    ...           ...            ...
# 12037192              38.0  560198000574           38.0
# 434430                 NaN   40003700712          218.0
# 459922                 NaN   40025502075          699.0
# 482554                 NaN   40042901994          444.0
# 1944490                NaN   69100602957          146.0
#
# [7005 rows x 3 columns]

# %%
# perform checks
# Check to make sure Education Total Units match up with the caluclated Totals
calc = np.array(check_total["calculated_total"])
total = np.array(check_total["STUDENT_COUNT"])

not_match = []
for i in range(0, len(calc)):
    if calc[i] != total[i]:
        not_match.append(i)
        print((calc[i], total[i]))
# Out:
# (95.0, 94.0)
# (396.0, 395.0)
# (400.0, 398.0)
# (357.0, 356.0)
# (472.0, 471.0)
# (1807.0, 1806.0)
# (320.0, 319.0)
# (35.0, 34.0)
# (470.0, 468.0)
# (1306.0, 1303.0)
# (579.0, 578.0)
# (822.0, 821.0)
# (953.0, 951.0)
# (1277.0, 1276.0)
# (1053.0, 1051.0)
# (691.0, 690.0)
# (792.0, 790.0)
# (777.0, 776.0)
# (250.0, 249.0)
# (583.0, 582.0)
# (1432.0, 1429.0)
# (733.0, 732.0)
# (780.0, 779.0)
# (1169.0, 1168.0)
# (1505.0, 1503.0)
# (520.0, 519.0)
# (1795.0, 1792.0)
# (2504.0, 2502.0)
# (1024.0, 1023.0)
# (472.0, 471.0)
# (412.0, 411.0)
# (443.0, 442.0)
# (411.0, 410.0)
# (1334.0, 1333.0)
# (83.0, 82.0)
# (187.0, 186.0)
# (34.0, 33.0)
# (7.0, 6.0)
# (116.0, 115.0)
# (305.0, 301.0)
# (168.0, 167.0)
# (155.0, 154.0)
# (466.0, 465.0)
# (594.0, 584.0)
# (600.0, 599.0)
# (201.0, 200.0)
# (392.0, 377.0)
# (222.0, 221.0)
# (438.0, 437.0)
# (785.0, 783.0)
# (640.0, 639.0)
# (795.0, 793.0)
# (1192.0, 1191.0)
# (1444.0, 1442.0)
# (1365.0, 1363.0)
# (597.0, 593.0)
# (697.0, 379.0)
# (484.0, 478.0)
# (105.0, 103.0)
# (159.0, 155.0)
# (187.0, 186.0)
# (369.0, 366.0)
# (360.0, 358.0)
# (98.0, 96.0)
# (234.0, 233.0)
# (737.0, 733.0)
# (nan, 218.0)
# (nan, 699.0)
# (nan, 444.0)
# (nan, 1740.0)
# (nan, 864.0)
# (nan, 852.0)
# (nan, 211.0)
# (nan, 146.0)
# (nan, 823.0)
# (nan, 611.0)
# (nan, 185.0)
# (nan, 307.0)
# (nan, 320.0)
# (nan, 317.0)
# (nan, 439.0)
# (nan, 623.0)
# (nan, 250.0)
# (nan, 497.0)
# (nan, 583.0)
# (nan, 93.0)
# (nan, 275.0)

# %% [markdown]
# ## 4. Extract total enrollment of student of each school

# %%
# Select the total number students
total_member = f2.loc[f2["TOTAL_INDICATOR"] == "Education Unit Total"]
total_member
# Out:
#          SCHOOL_YEAR  FIPST            STATENAME  ST  \
# 107        2016-2017      1              ALABAMA  AL
# 222        2016-2017      1              ALABAMA  AL
# 337        2016-2017      1              ALABAMA  AL
# 452        2016-2017      1              ALABAMA  AL
# 567        2016-2017      1              ALABAMA  AL
# ...              ...    ...                  ...  ..
# 12279205   2016-2017     78  U.S. VIRGIN ISLANDS  VI
# 12279336   2016-2017     78  U.S. VIRGIN ISLANDS  VI
# 12279467   2016-2017     78  U.S. VIRGIN ISLANDS  VI
# 12279523   2016-2017     78  U.S. VIRGIN ISLANDS  VI
# 12279589   2016-2017     78  U.S. VIRGIN ISLANDS  VI
#
#                                       SCH_NAME  STATE_AGENCY_NO  UNION  \
# 107           Sequoyah Sch - Chalkville Campus                1    NaN
# 222                                      Camps                1    NaN
# 337                                    Det Ctr                1    NaN
# 452              Wallace Sch - Mt Meigs Campus                1    NaN
# 567                  McNeel Sch - Vacca Campus                1    NaN
# ...                                        ...              ...    ...
# 12279205  GLADYS A. ABRAHAM  ELEMENTARY SCHOOL                1    NaN
# 12279336       ULLA F MULLER ELEMENTARY SCHOOL                1    NaN
# 12279467       YVONNE BOWSKY ELEMENTARY SCHOOL                1    NaN
# 12279523            CANCRYN JUNIOR HIGH SCHOOL                1    NaN
# 12279589          BERTHA BOSCHULTE JUNIOR HIGH                1    NaN
#
#          ST_LEAID    LEAID     ST_SCHID       NCESSCH    SCHID  \
# 107        AL-210   100002  AL-210-0020   10000200277   100277
# 222        AL-210   100002  AL-210-0050   10000201667   101667
# 337        AL-210   100002  AL-210-0060   10000201670   101670
# 452        AL-210   100002  AL-210-0030   10000201705   101705
# 567        AL-210   100002  AL-210-0040   10000201706   101706
# ...           ...      ...          ...           ...      ...
# 12279205   VI-001  7800030    VI-001-21  780003000025  7800025
# 12279336   VI-001  7800030    VI-001-17  780003000026  7800026
# 12279467   VI-001  7800030    VI-001-23  780003000027  7800027
# 12279523   VI-001  7800030    VI-001-25  780003000033  7800033
# 12279589   VI-001  7800030     VI-001-9  780003000034  7800034
#
#                       GRADE     RACE_ETHNICITY                SEX  \
# 107       No Category Codes  No Category Codes  No Category Codes
# 222       No Category Codes  No Category Codes  No Category Codes
# 337       No Category Codes  No Category Codes  No Category Codes
# 452       No Category Codes  No Category Codes  No Category Codes
# 567       No Category Codes  No Category Codes  No Category Codes
# ...                     ...                ...                ...
# 12279205  No Category Codes  No Category Codes  No Category Codes
# 12279336  No Category Codes  No Category Codes  No Category Codes
# 12279467  No Category Codes  No Category Codes  No Category Codes
# 12279523  No Category Codes  No Category Codes  No Category Codes
# 12279589  No Category Codes  No Category Codes  No Category Codes
#
#           STUDENT_COUNT       TOTAL_INDICATOR      DMS_FLAG
# 107                 NaN  Education Unit Total  Not reported
# 222                 NaN  Education Unit Total  Not reported
# 337                 NaN  Education Unit Total  Not reported
# 452                 NaN  Education Unit Total  Not reported
# 567                 NaN  Education Unit Total  Not reported
# ...                 ...                   ...           ...
# 12279205          345.0  Education Unit Total      Reported
# 12279336          449.0  Education Unit Total      Reported
# 12279467          397.0  Education Unit Total      Reported
# 12279523          526.0  Education Unit Total      Reported
# 12279589          537.0  Education Unit Total      Reported
#
# [99070 rows x 18 columns]

# %%
# Select only charter schools only in membership data
charter_membership = f2.loc[f2["NCESSCH"].isin(charter_id)]

# %%
len(charter_membership["NCESSCH"].unique())
# Out:
# 7011

# %%
# Select only the charterschools
total_ch_mem = charter_membership.loc[charter_membership["TOTAL_INDICATOR"] == "Education Unit Total",['NCESSCH','STUDENT_COUNT']]
total_ch_mem
# Out:
#                NCESSCH  STUDENT_COUNT
# 28992      10019702432            NaN
# 345613     20000100329          163.0
# 364595     20015000306          186.0
# 364970     20015000523          174.0
# 374081     20018000172          378.0
# ...                ...            ...
# 12026260  560073000216          198.0
# 12026704  560073000542           76.0
# 12027132  560096000367           22.0
# 12036956  560198000547          169.0
# 12037192  560198000574           38.0
#
# [7011 rows x 2 columns]

# %% [markdown]
# ## 5. Calculate student total by race

# %%
# Total up all students by race for each school
charter_memfilter = charter_membership.loc[charter_membership['TOTAL_INDICATOR'].isin(totals_id) , : ]
charter_memgroup = charter_memfilter.groupby(["NCESSCH", 'RACE_ETHNICITY']).agg({"STUDENT_COUNT": ['sum']})
charter_memgroup
# Out:
#                                                        STUDENT_COUNT
#                                                                  sum
# NCESSCH      RACE_ETHNICITY
# 10019702432  American Indian or Alaska Native                    0.0
#              Asian                                               0.0
#              Black or African American                           0.0
#              Hispanic/Latino                                     0.0
#              Native Hawaiian or Other Pacific Islander           0.0
# ...                                                              ...
# 560198000574 Hispanic/Latino                                    10.0
#              Native Hawaiian or Other Pacific Islander           0.0
#              Not Specified                                       0.0
#              Two or more races                                   1.0
#              White                                              24.0
#
# [56088 rows x 1 columns]

# %%
# Unstack rowa to become columns for a wide format table
charter_memwide = charter_memgroup.unstack()

# %%
charter_memwide.index
# Out:
# Int64Index([ 10019702432,  20000100329,  20015000306,  20015000523,
#              20018000172,  20018000178,  20018000459,  20018000460,
#              20018000530,  20018000555,
#             ...
#             551629002953, 551632002752, 551650002523, 551668002901,
#             551707002781, 560073000216, 560073000542, 560096000367,
#             560198000547, 560198000574],
#            dtype='int64', name='NCESSCH', length=7011)

# %%
# Merge with charter lunch data and total students data; use outer merge to keep all charter schools
chMemLun = charter_memwide.merge(charter_lunch, how="outer", left_index = True, right_index = True)
chMemLunTot = chMemLun.merge(total_ch_mem, how="outer", left_index = True, right_on = "NCESSCH")
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/merge.py:617: UserWarning: merging between different levels can give an unintended result (3 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)

# %%
# Set index of merged table to be NCESSCH to make later merges easier
ch_merged = chMemLunTot.set_index('NCESSCH')
ch_merged
# Out:
#               (STUDENT_COUNT, sum, American Indian or Alaska Native)  \
# NCESSCH
# 10019702432                                                 0.0
# 20000100329                                               160.0
# 20015000306                                                77.0
# 20015000523                                                58.0
# 20018000172                                                10.0
# ...                                                         ...
# 560073000216                                                4.0
# 560073000542                                                2.0
# 560096000367                                               22.0
# 560198000547                                                0.0
# 560198000574                                                0.0
#
#               (STUDENT_COUNT, sum, Asian)  \
# NCESSCH
# 10019702432                           0.0
# 20000100329                           0.0
# 20015000306                          33.0
# 20015000523                          14.0
# 20018000172                          10.0
# ...                                   ...
# 560073000216                         25.0
# 560073000542                          0.0
# 560096000367                          0.0
# 560198000547                          1.0
# 560198000574                          0.0
#
#               (STUDENT_COUNT, sum, Black or African American)  \
# NCESSCH
# 10019702432                                               0.0
# 20000100329                                               0.0
# 20015000306                                               1.0
# 20015000523                                               2.0
# 20018000172                                               4.0
# ...                                                       ...
# 560073000216                                              3.0
# 560073000542                                              0.0
# 560096000367                                              0.0
# 560198000547                                              4.0
# 560198000574                                              3.0
#
#               (STUDENT_COUNT, sum, Hispanic/Latino)  \
# NCESSCH
# 10019702432                                     0.0
# 20000100329                                     0.0
# 20015000306                                    13.0
# 20015000523                                     5.0
# 20018000172                                    23.0
# ...                                             ...
# 560073000216                                    9.0
# 560073000542                                   12.0
# 560096000367                                    0.0
# 560198000547                                   55.0
# 560198000574                                   10.0
#
#               (STUDENT_COUNT, sum, Native Hawaiian or Other Pacific Islander)  \
# NCESSCH
# 10019702432                                                 0.0
# 20000100329                                                 0.0
# 20015000306                                                 5.0
# 20015000523                                                 2.0
# 20018000172                                                 1.0
# ...                                                         ...
# 560073000216                                                0.0
# 560073000542                                                0.0
# 560096000367                                                0.0
# 560198000547                                                0.0
# 560198000574                                                0.0
#
#               (STUDENT_COUNT, sum, Not Specified)  \
# NCESSCH
# 10019702432                                   0.0
# 20000100329                                   0.0
# 20015000306                                   0.0
# 20015000523                                   0.0
# 20018000172                                   0.0
# ...                                           ...
# 560073000216                                  0.0
# 560073000542                                  0.0
# 560096000367                                  0.0
# 560198000547                                  0.0
# 560198000574                                  0.0
#
#               (STUDENT_COUNT, sum, Two or more races)  \
# NCESSCH
# 10019702432                                       0.0
# 20000100329                                       0.0
# 20015000306                                       6.0
# 20015000523                                      13.0
# 20018000172                                      55.0
# ...                                               ...
# 560073000216                                      0.0
# 560073000542                                      6.0
# 560096000367                                      0.0
# 560198000547                                      4.0
# 560198000574                                      1.0
#
#               (STUDENT_COUNT, sum, White)  Free and Reduced Lunch  \
# NCESSCH
# 10019702432                           0.0                     0.0
# 20000100329                           3.0                   141.0
# 20015000306                          51.0                    88.0
# 20015000523                          80.0                    77.0
# 20018000172                         275.0                     0.0
# ...                                   ...                     ...
# 560073000216                        157.0                     NaN
# 560073000542                         56.0                     NaN
# 560096000367                          0.0                     NaN
# 560198000547                        105.0                     NaN
# 560198000574                         24.0                     NaN
#
#               STUDENT_COUNT
# NCESSCH
# 10019702432             NaN
# 20000100329           163.0
# 20015000306           186.0
# 20015000523           174.0
# 20018000172           378.0
# ...                     ...
# 560073000216          198.0
# 560073000542           76.0
# 560096000367           22.0
# 560198000547          169.0
# 560198000574           38.0
#
# [7011 rows x 10 columns]

# %%
# Create proportion for each race by divideing each column by total numbre of students
proportions = ch_merged.copy()
columns = proportions.columns
for i, row in proportions.iterrows():
    for x in range(len(columns)):
        col = columns[x]
        if col != 'STUDENT_COUNT':
            value = row[x]
            if value == 0:
                proportions.at[i, col] = 0
            else:
                proportions.at[i, col] = str((row[x] / row[len(row) - 1]) * 100)

proportions.columns = ['American Indian/Alaska Native (% total)', 'Asian (% total)', 'Black/African American (% total)', 'Hispanic/Latino (% total)', 'Hawaiian/Pacific Islander (% total)', 'Not Specified (% total)', 'Two+ races (% total)', 'White (% total)', 'Free or Reduced Lunch (% total)', 'Total Student Count']              
proportions
# Out:
#               American Indian/Alaska Native (% total)  Asian (% total)  \
# NCESSCH
# 10019702432                                  0.000000         0.000000
# 20000100329                                 98.159509         0.000000
# 20015000306                                 41.397849        17.741935
# 20015000523                                 33.333333         8.045977
# 20018000172                                  2.645503         2.645503
# ...                                               ...              ...
# 560073000216                                 2.020202        12.626263
# 560073000542                                 2.631579         0.000000
# 560096000367                               100.000000         0.000000
# 560198000547                                 0.000000         0.591716
# 560198000574                                 0.000000         0.000000
#
#               Black/African American (% total)  Hispanic/Latino (% total)  \
# NCESSCH
# 10019702432                           0.000000                   0.000000
# 20000100329                           0.000000                   0.000000
# 20015000306                           0.537634                   6.989247
# 20015000523                           1.149425                   2.873563
# 20018000172                           1.058201                   6.084656
# ...                                        ...                        ...
# 560073000216                          1.515152                   4.545455
# 560073000542                          0.000000                  15.789474
# 560096000367                          0.000000                   0.000000
# 560198000547                          2.366864                  32.544379
# 560198000574                          7.894737                  26.315789
#
#               Hawaiian/Pacific Islander (% total)  Not Specified (% total)  \
# NCESSCH
# 10019702432                              0.000000                      0.0
# 20000100329                              0.000000                      0.0
# 20015000306                              2.688172                      0.0
# 20015000523                              1.149425                      0.0
# 20018000172                              0.264550                      0.0
# ...                                           ...                      ...
# 560073000216                             0.000000                      0.0
# 560073000542                             0.000000                      0.0
# 560096000367                             0.000000                      0.0
# 560198000547                             0.000000                      0.0
# 560198000574                             0.000000                      0.0
#
#               Two+ races (% total)  White (% total)  \
# NCESSCH
# 10019702432               0.000000         0.000000
# 20000100329               0.000000         1.840491
# 20015000306               3.225806        27.419355
# 20015000523               7.471264        45.977011
# 20018000172              14.550265        72.751323
# ...                            ...              ...
# 560073000216              0.000000        79.292929
# 560073000542              7.894737        73.684211
# 560096000367              0.000000         0.000000
# 560198000547              2.366864        62.130178
# 560198000574              2.631579        63.157895
#
#               Free or Reduced Lunch (% total)  Total Student Count
# NCESSCH
# 10019702432                          0.000000                  NaN
# 20000100329                         86.503067                163.0
# 20015000306                         47.311828                186.0
# 20015000523                         44.252874                174.0
# 20018000172                          0.000000                378.0
# ...                                       ...                  ...
# 560073000216                              NaN                198.0
# 560073000542                              NaN                 76.0
# 560096000367                              NaN                 22.0
# 560198000547                              NaN                169.0
# 560198000574                              NaN                 38.0
#
# [7011 rows x 10 columns]

# %%
#Save progress into a csv in work folder
proportions.to_csv('mergedMemLun.csv', header=True)

# %% [markdown]
# # 6. Select charter schools only for f3, f4, and fgeo

# %%
# select all charter schools in f3 table
charter_f3 = f3.loc[f3["NCESSCH"].isin(charter_id)]

# %%
# Select all charters in f4 table
charter_f4 = f4.loc[f4["NCESSCH"].isin(charter_id)]

# %%
# Select all charters in fgro table
charter_geo = fgeo.loc[fgeo["NCESSCH"].isin(charter_id)]

# %%
len(charter_geo)
# Out:
# 7351

# %% [markdown]
# # 7. Merge all Tables

# %%
# merge All tables
# merge directory and proportions table
mergef02016_17 = charterSchools.merge(proportions, how="outer", left_on = "NCESSCH", right_index = True)

# %%
# merge with f3 staff table
mergef32016_17 = mergef02016_17.merge(charter_f3, how="outer", left_on = "NCESSCH", right_on = "NCESSCH")

# %%
# merge with f4 school characteristics table
mergef42016_17 = mergef32016_17.merge(charter_f4, how="outer", left_on = "NCESSCH", right_on = "NCESSCH")

# %%
# merge with fgeo table
mergeAll2016_17 = mergef42016_17.merge(charter_geo, how="outer", left_on = "NCESSCH", right_on = "NCESSCH")

# %%
#Save progress of the merge table into working folder
mergeAll2016_17.to_csv('AllCharters1617.csv', header=True)

# %% [markdown]
# # 8. Perform Check on full merged table

# %%
#Perform Check 1
mergeAll2016_17.loc[mergeAll2016_17["SCH_NAME_x"] == "Inspire Charter School", ]
#Passes Check 1
# Should create more checks
# Out:
#     SCHOOL_YEAR_x  FIPST_x STATENAME_x ST_x              SCH_NAME_x  \
# 671     2016-2017        6  CALIFORNIA   CA  Inspire Charter School
#
#                      LEA_NAME  STATE_AGENCY_NO_x  UNION_x  ST_LEAID_x  \
# 671  Acton-Agua Dulce Unified                  1      NaN  CA-1975309
#
#      LEAID_x          ST_SCHID_x      NCESSCH  SCHID_x            MSTREET1  \
# 671   600001  CA-1975309-0129742  60000113764   613764  33323 Santiago Rd.
#
#     MSTREET2 MSTREET3  MCITY MSTATE   MZIP   MZIP4            LSTREET1  \
# 671      NaN      NaN  Acton     CA  93510  1416.0  33323 Santiago Rd.
#
#     LSTREET2 LSTREET3  LCITY LSTATE   LZIP   LZIP4          PHONE  \
# 671      NaN      NaN  Acton     CA  93510  1416.0  (661)269-2214
#
#                            WEBSITE  SY_STATUS SY_STATUS_TEXT  UPDATED_STATUS  \
# 671  http://www.inspireschools.org          1           Open               1
#
#     UPDATED_STATUS_TEXT EFFECTIVE_DATE   SCH_TYPE_TEXT  SCH_TYPE RECON_STATUS  \
# 671                Open     01/27/2017  Regular School         1           No
#
#     OUT_OF_STATE_FLAG CHARTER_TEXT CHARTAUTH1               CHARTAUTHN1  \
# 671                No          Yes    0600001  Acton-Agua Dulce Unified
#
#     CHARTAUTH2 CHARTAUTHN2 NOGRADES G_PK_OFFERED G_KG_OFFERED G_1_OFFERED  \
# 671        NaN         NaN       No           No          Yes         Yes
#
#     G_2_OFFERED G_3_OFFERED G_4_OFFERED G_5_OFFERED G_6_OFFERED G_7_OFFERED  \
# 671         Yes         Yes         Yes         Yes         Yes         Yes
#
#     G_8_OFFERED G_9_OFFERED G_10_OFFERED G_11_OFFERED G_12_OFFERED  \
# 671         Yes         Yes          Yes          Yes          Yes
#
#     G_13_OFFERED G_UG_OFFERED G_AE_OFFERED GSLO GSHI  LEVEL    IGOFFERED  \
# 671           No           No           No   KG   12  Other  As reported
#
#      American Indian/Alaska Native (% total)  Asian (% total)  \
# 671                                 0.303337         5.510617
#
#      Black/African American (% total)  Hispanic/Latino (% total)  \
# 671                          6.825076                  31.698686
#
#      Hawaiian/Pacific Islander (% total)  Not Specified (% total)  \
# 671                             0.303337                      0.0
#
#      Two+ races (% total)  White (% total)  Free or Reduced Lunch (% total)  \
# 671             11.577351        43.781598                        31.850354
#
#      Total Student Count SCHOOL_YEAR_y  FIPST_y STATENAME_y ST_y  \
# 671               1978.0     2016-2017      6.0  CALIFORNIA   CA
#
#                  SCH_NAME_y  STATE_AGENCY_NO_y  UNION_y  ST_LEAID_y   LEAID_y  \
# 671  Inspire Charter School                1.0      NaN  CA-1975309  600001.0
#
#              ST_SCHID_y   SCHID_y  TEACHERS       TOTAL_INDICATOR  DMS_FLAG  \
# 671  CA-1975309-0129742  613764.0    144.37  Education Unit Total  Reported
#
#     SCHOOL_YEAR  FIPST   STATENAME  ST                SCH_NAME  \
# 671   2016-2017    6.0  CALIFORNIA  CA  Inspire Charter School
#
#      STATE_AGENCY_NO  UNION    ST_LEAID     LEAID            ST_SCHID  \
# 671              1.0    NaN  CA-1975309  600001.0  CA-1975309-0129742
#
#         SCHID SHARED_TIME TITLEI_STATUS TITLEI_STATUS_TEXT MAGNET_TEXT  \
# 671  613764.0     Missing       MISSING            Missing          No
#
#     NSLP_STATUS NSLP_STATUS_TEXT      VIRTUAL  VIRTUAL_TEXT  \
# 671      NSLPNO               No  FULLVIRTUAL  Full Virtual
#
#                        NAME  OPSTFIPS              STREET   CITY STATE  \
# 671  Inspire Charter School       6.0  33323 Santiago Rd.  Acton    CA
#
#          ZIP STFIP   CNTY              NMCNTY LOCALE        LAT         LON  \
# 671  93510.0    06  06037  Los Angeles County     41  34.490786 -118.162386
#
#       CBSA                              NMCBSA  CBSATYPE  CSA  \
# 671  31080  Los Angeles-Long Beach-Anaheim, CA       1.0  348
#
#                           NMCSA NECTA NMNECTA    CD   SLDL   SLDU  SURVYEAR
# 671  Los Angeles-Long Beach, CA     N       N  0625  06036  06021    2016.0

# %% [markdown]
# # 9. Find new Charters

# %%
#Find New Charters 
charter_recorded = pd.read_csv("Checking charter URLs 2016 - full list.csv")
charter1617 = mergeAll2016_17.copy()

# %%
# Select the primary keys to identify new schools; new schools will have a new NCESSCH number
ncessch_recorded = charter_recorded["NCESSCH"]
ncessch_1617 = charter1617["NCESSCH"]

# %%
# Function to filter the new NCESSCH values
# Input: two arrays; series - array to check if values in check_to array, 
#        check_to - array with values to check with for series
# Output: array of indices to series (input) array for new NCESSCH values

def filarray(series, check_to):
    indexes = []
    for i in range(0, len(series)):
        if series[i] not in check_to:
            indexes.append(i)
    return indexes

# %%
# Turn series into np arrays
ncessch_1617 = np.array(ncessch_1617)
ncessch_recorded = np.array(ncessch_recorded)

# %%
# filter the ncessch from the 2016-17 data to the spreadsheet and select the new values
new_indexes = filarray(ncessch_1617, ncessch_recorded)

# %%
# Display new schools
pd.set_option('display.max_columns', None)
new_charters = charter1617.iloc[new_indexes, :]
new_charters
# Out:
#      SCHOOL_YEAR_x  FIPST_x           STATENAME_x ST_x  \
# 102      2016-2017        4               ARIZONA   AZ
# 107      2016-2017        4               ARIZONA   AZ
# 108      2016-2017        4               ARIZONA   AZ
# 2245     2016-2017       10              DELAWARE   DE
# 2314     2016-2017       11  DISTRICT OF COLUMBIA   DC
# ...            ...      ...                   ...  ...
# 7084     2016-2017       49                  UTAH   UT
# 7127     2016-2017       55             WISCONSIN   WI
# 7132     2016-2017       55             WISCONSIN   WI
# 7230     2016-2017       55             WISCONSIN   WI
# 7350     2016-2017       55             WISCONSIN   WI
#
#                                          SCH_NAME_x  \
# 102                        Ombudsman - Charter East
# 107                     Ombudsman - Charter East II
# 108                    Ombudsman - Charter Valencia
# 2245           Mapleton Charter School at Whitehall
# 2314            William E Doar PCS NW Soldiers Home
# ...                                             ...
# 7084                     CAPSTONE CLASSICAL ACADEMY
# 7127                           Pathways High School
# 7132  Tomorrow River Virtual Charter School (TRVCS)
# 7230        Insight School of Wisconsin High School
# 7350                 Wonewoc-Center Virtual Academy
#
#                                                LEA_NAME  STATE_AGENCY_NO_x  \
# 102   Ombudsman Educational Services Ltd. a subsidia...                  1
# 107   Ombudsman Educational Services Ltd. a subsidia...                  1
# 108   Ombudsman Educational Services Ltd. a subsidia...                  1
# 2245               Mapleton Charter School at Whitehall                  1
# 2314                               City Arts & Prep PCS                  1
# ...                                                 ...                ...
# 7084                         CAPSTONE CLASSICAL ACADEMY                  1
# 7127                        Pathways High School Agency                  1
# 7132                     Tomorrow River School District                  1
# 7230                          McFarland School District                  1
# 7350               Wonewoc-Union Center School District                  1
#
#       UNION_x ST_LEAID_x  LEAID_x     ST_SCHID_x       NCESSCH  SCHID_x  \
# 102       NaN    AZ-4323   400103   AZ-4323-5493   40010301583   401583
# 107       NaN    AZ-4323   400103  AZ-4323-89440   40010302855   402855
# 108       NaN    AZ-4323   400103  AZ-4323-89827   40010302950   402950
# 2245      NaN    DE-9613  1000060   DE-9613-4085  100006000375  1000375
# 2314      NaN     DC-153  1100053    DC-153-1033  110005300428  1100428
# ...       ...        ...      ...            ...           ...      ...
# 7084      NaN      UT-9L  4900199    UT-9L-9L300  490019901527  4901527
# 7127      NaN    WI-8139  5500079   WI-8139-8139  550007903064  5503064
# 7132      NaN    WI-0126  5500330   WI-0126-0140  550033003063  5503063
# 7230      NaN    WI-3381  5508910   WI-3381-0470  550891003067  5503067
# 7350      NaN    WI-6713  5517130   WI-6713-0850  551713003059  5503059
#
#                            MSTREET1 MSTREET2 MSTREET3             MCITY  \
# 102   13832 N. 32nd St. Ste 218 Bld      NaN      NaN           Phoenix
# 107          1585 N. Milwaukee Ave.      NaN      NaN      Libertyville
# 108           1686 W. Valencia Road      NaN      NaN            Tucson
# 2245    401 Federal Street- Suite 2      NaN      NaN             Dover
# 2314       3700 North Capitol St NW      NaN      NaN        Washington
# ...                             ...      ...      ...               ...
# 7084                2307 N. 2850 W.      NaN      NaN        PLAIN CITY
# 7127                336 W Walnut St      NaN      NaN         Milwaukee
# 7132           10186 County Road MM      NaN      NaN  Amherst Junction
# 7230            4709 Dale-Curtin Dr      NaN      NaN         McFarland
# 7350                  101 School Rd      NaN      NaN           Wonewoc
#
#      MSTATE   MZIP   MZIP4                     LSTREET1 LSTREET2 LSTREET3  \
# 102      AZ  85032     NaN               3943 E. Thomas      NaN      NaN
# 107      IL  60048     NaN        4041 East Thomas Road      NaN      NaN
# 108      AZ  85746     NaN        1686 W. Valencia Road      NaN      NaN
# 2245     DE  19901     NaN  401 Federal Street- Suite 2      NaN      NaN
# 2314     DC  20011     NaN     3700 North Capitol St NW      NaN      NaN
# ...     ...    ...     ...                          ...      ...      ...
# 7084     UT  84404     NaN              2307 N. 2850 W.      NaN      NaN
# 7127     WI  53232  3847.0              336 W Walnut St      NaN      NaN
# 7132     WI  54407  9053.0         10186 County Road MM      NaN      NaN
# 7230     WI  53558     NaN          4709 Dale-Curtin Dr      NaN      NaN
# 7350     WI  53968     NaN                101 School Rd      NaN      NaN
#
#                  LCITY LSTATE   LZIP   LZIP4          PHONE  \
# 102            Phoenix     AZ  85018     NaN  (602)840-2997
# 107            Phoenix     AZ  85018     NaN  (602)840-2997
# 108             Tucson     AZ  85746     NaN  (520)573-5858
# 2245             Dover     DE  19901     NaN  (302)735-4000
# 2314        Washington     DC  20011     NaN  (202)882-1930
# ...                ...    ...    ...     ...            ...
# 7084        PLAIN CITY     UT  84404     NaN  (801)415-9973
# 7127         Milwaukee     WI  53232  3847.0  (414)943-2891
# 7132  Amherst Junction     WI  54407  9053.0  (715)346-2730
# 7230         McFarland     WI  53558     NaN  (608)838-9482
# 7350           Wonewoc     WI  53968     NaN  (608)464-3165
#
#                                          WEBSITE  SY_STATUS    SY_STATUS_TEXT  \
# 102                     http://www.ombudsman.com          5  Changed Boundary
# 107                                          NaN          5  Changed Boundary
# 108                                          NaN          5  Changed Boundary
# 2245                                         NaN          2            Closed
# 2314                   http://www.wedjschool.us/          2            Closed
# ...                                          ...        ...               ...
# 7084                                         NaN          7            Future
# 7127         http://mhecimovich@pathwayshigh.org          7            Future
# 7132                            http://trccs.org          7            Future
# 7230                     http://www.wiva.k12.com          7            Future
# 7350  http://www.wc.k12.wi.us/virtualacademy.cfm          7            Future
#
#       UPDATED_STATUS UPDATED_STATUS_TEXT EFFECTIVE_DATE       SCH_TYPE_TEXT  \
# 102                5    Changed Boundary     08/15/2017      Regular School
# 107                5    Changed Boundary     08/15/2017      Regular School
# 108                5    Changed Boundary     08/15/2017      Regular School
# 2245               2              Closed     07/01/2017      Regular School
# 2314               2              Closed     01/27/2017      Regular School
# ...              ...                 ...            ...                 ...
# 7084               7              Future     09/13/2017      Regular School
# 7127               7              Future     07/17/2017      Regular School
# 7132               7              Future     07/17/2017      Regular School
# 7230               7              Future     07/17/2017  Alternative School
# 7350               7              Future     07/17/2017      Regular School
#
#       SCH_TYPE RECON_STATUS OUT_OF_STATE_FLAG CHARTER_TEXT CHARTAUTH1  \
# 102          1           No                No          Yes      10500
# 107          1           No               Yes          Yes      10500
# 108          1           No                No          Yes      10500
# 2245         1           No                No          Yes      DOE01
# 2314         1           No                No          Yes        002
# ...        ...          ...               ...          ...        ...
# 7084         1           No                No          Yes         99
# 7127         1           No                No          Yes        NaN
# 7132         1           No                No          Yes       0126
# 7230         4           No                No          Yes       3381
# 7350         1           No                No          Yes       6713
#
#                                   CHARTAUTHN1 CHARTAUTH2 CHARTAUTHN2  \
# 102   Arizona State Board for Charter Schools        NaN         NaN
# 107   Arizona State Board for Charter Schools        NaN         NaN
# 108   Arizona State Board for Charter Schools        NaN         NaN
# 2245         Delaware Department of Education        NaN         NaN
# 2314           DC Public Charter School Board        NaN         NaN
# ...                                       ...        ...         ...
# 7084                                     USBE        NaN         NaN
# 7127                                      NaN        NaN         NaN
# 7132           Tomorrow River School District        NaN         NaN
# 7230                McFarland School District        NaN         NaN
# 7350     Wonewoc-Union Center School District        NaN         NaN
#
#           NOGRADES  G_PK_OFFERED  G_KG_OFFERED   G_1_OFFERED   G_2_OFFERED  \
# 102             No            No            No            No            No
# 107             No            No            No            No            No
# 108             No            No            No            No            No
# 2245  Not reported  Not reported  Not reported  Not reported  Not reported
# 2314  Not reported  Not reported  Not reported  Not reported  Not reported
# ...            ...           ...           ...           ...           ...
# 7084  Not reported  Not reported  Not reported  Not reported  Not reported
# 7127  Not reported  Not reported  Not reported  Not reported  Not reported
# 7132  Not reported  Not reported  Not reported  Not reported  Not reported
# 7230  Not reported  Not reported  Not reported  Not reported  Not reported
# 7350  Not reported  Not reported  Not reported  Not reported  Not reported
#
#        G_3_OFFERED   G_4_OFFERED   G_5_OFFERED   G_6_OFFERED   G_7_OFFERED  \
# 102             No            No            No            No            No
# 107             No            No            No            No            No
# 108             No            No            No           Yes           Yes
# 2245  Not reported  Not reported  Not reported  Not reported  Not reported
# 2314  Not reported  Not reported  Not reported  Not reported  Not reported
# ...            ...           ...           ...           ...           ...
# 7084  Not reported  Not reported  Not reported  Not reported  Not reported
# 7127  Not reported  Not reported  Not reported  Not reported  Not reported
# 7132  Not reported  Not reported  Not reported  Not reported  Not reported
# 7230  Not reported  Not reported  Not reported  Not reported  Not reported
# 7350  Not reported  Not reported  Not reported  Not reported  Not reported
#
#        G_8_OFFERED   G_9_OFFERED  G_10_OFFERED  G_11_OFFERED  G_12_OFFERED  \
# 102             No           Yes           Yes           Yes           Yes
# 107             No           Yes           Yes           Yes           Yes
# 108            Yes           Yes           Yes           Yes           Yes
# 2245  Not reported  Not reported  Not reported  Not reported  Not reported
# 2314  Not reported  Not reported  Not reported  Not reported  Not reported
# ...            ...           ...           ...           ...           ...
# 7084  Not reported  Not reported  Not reported  Not reported  Not reported
# 7127  Not reported  Not reported  Not reported  Not reported  Not reported
# 7132  Not reported  Not reported  Not reported  Not reported  Not reported
# 7230  Not reported  Not reported  Not reported  Not reported  Not reported
# 7350  Not reported  Not reported  Not reported  Not reported  Not reported
#
#       G_13_OFFERED  G_UG_OFFERED  G_AE_OFFERED GSLO GSHI         LEVEL  \
# 102             No            No            No   09   12          High
# 107             No            No            No   09   12          High
# 108             No            No            No   06   12         Other
# 2245  Not reported  Not reported  Not reported    M    M  Not reported
# 2314  Not reported  Not reported  Not reported    M    M  Not reported
# ...            ...           ...           ...  ...  ...           ...
# 7084  Not reported  Not reported  Not reported    M    M  Not reported
# 7127  Not reported  Not reported  Not reported    M    M  Not reported
# 7132  Not reported  Not reported  Not reported    M    M  Not reported
# 7230  Not reported  Not reported  Not reported    M    M  Not reported
# 7350  Not reported  Not reported  Not reported    M    M  Not reported
#
#         IGOFFERED  American Indian/Alaska Native (% total)  Asian (% total)  \
# 102   As reported                                 9.876543         1.234568
# 107   As reported                                 8.383234         0.000000
# 108   As reported                                11.270983         0.479616
# 2245  As reported                                      NaN              NaN
# 2314  As reported                                      NaN              NaN
# ...           ...                                      ...              ...
# 7084  As reported                                      NaN              NaN
# 7127  As reported                                      NaN              NaN
# 7132  As reported                                      NaN              NaN
# 7230  As reported                                      NaN              NaN
# 7350  As reported                                      NaN              NaN
#
#       Black/African American (% total)  Hispanic/Latino (% total)  \
# 102                           7.407407                  67.901235
# 107                           4.191617                  79.640719
# 108                           2.637890                  81.055156
# 2245                               NaN                        NaN
# 2314                               NaN                        NaN
# ...                                ...                        ...
# 7084                               NaN                        NaN
# 7127                               NaN                        NaN
# 7132                               NaN                        NaN
# 7230                               NaN                        NaN
# 7350                               NaN                        NaN
#
#       Hawaiian/Pacific Islander (% total)  Not Specified (% total)  \
# 102                                   0.0                      0.0
# 107                                   0.0                      0.0
# 108                                   0.0                      0.0
# 2245                                  NaN                      NaN
# 2314                                  NaN                      NaN
# ...                                   ...                      ...
# 7084                                  NaN                      NaN
# 7127                                  NaN                      NaN
# 7132                                  NaN                      NaN
# 7230                                  NaN                      NaN
# 7350                                  NaN                      NaN
#
#       Two+ races (% total)  White (% total)  Free or Reduced Lunch (% total)  \
# 102               1.234568        12.345679                              0.0
# 107               0.000000         7.784431                              0.0
# 108               0.000000         4.556355                              0.0
# 2245                   NaN              NaN                              NaN
# 2314                   NaN              NaN                              NaN
# ...                    ...              ...                              ...
# 7084                   NaN              NaN                              NaN
# 7127                   NaN              NaN                              NaN
# 7132                   NaN              NaN                              NaN
# 7230                   NaN              NaN                              NaN
# 7350                   NaN              NaN                              NaN
#
#       Total Student Count SCHOOL_YEAR_y  FIPST_y STATENAME_y ST_y  \
# 102                  81.0     2016-2017      4.0     ARIZONA   AZ
# 107                 167.0     2016-2017      4.0     ARIZONA   AZ
# 108                 417.0     2016-2017      4.0     ARIZONA   AZ
# 2245                  NaN           NaN      NaN         NaN  NaN
# 2314                  NaN           NaN      NaN         NaN  NaN
# ...                   ...           ...      ...         ...  ...
# 7084                  NaN           NaN      NaN         NaN  NaN
# 7127                  NaN           NaN      NaN         NaN  NaN
# 7132                  NaN           NaN      NaN         NaN  NaN
# 7230                  NaN           NaN      NaN         NaN  NaN
# 7350                  NaN           NaN      NaN         NaN  NaN
#
#                         SCH_NAME_y  STATE_AGENCY_NO_y  UNION_y ST_LEAID_y  \
# 102       Ombudsman - Charter East                1.0      NaN    AZ-4323
# 107    Ombudsman - Charter East II                1.0      NaN    AZ-4323
# 108   Ombudsman - Charter Valencia                1.0      NaN    AZ-4323
# 2245                           NaN                NaN      NaN        NaN
# 2314                           NaN                NaN      NaN        NaN
# ...                            ...                ...      ...        ...
# 7084                           NaN                NaN      NaN        NaN
# 7127                           NaN                NaN      NaN        NaN
# 7132                           NaN                NaN      NaN        NaN
# 7230                           NaN                NaN      NaN        NaN
# 7350                           NaN                NaN      NaN        NaN
#
#        LEAID_y     ST_SCHID_y   SCHID_y  TEACHERS       TOTAL_INDICATOR  \
# 102   400103.0   AZ-4323-5493  401583.0       NaN  Education Unit Total
# 107   400103.0  AZ-4323-89440  402855.0       NaN  Education Unit Total
# 108   400103.0  AZ-4323-89827  402950.0       NaN  Education Unit Total
# 2245       NaN            NaN       NaN       NaN                   NaN
# 2314       NaN            NaN       NaN       NaN                   NaN
# ...        ...            ...       ...       ...                   ...
# 7084       NaN            NaN       NaN       NaN                   NaN
# 7127       NaN            NaN       NaN       NaN                   NaN
# 7132       NaN            NaN       NaN       NaN                   NaN
# 7230       NaN            NaN       NaN       NaN                   NaN
# 7350       NaN            NaN       NaN       NaN                   NaN
#
#           DMS_FLAG SCHOOL_YEAR  FIPST STATENAME   ST  \
# 102   Not reported   2016-2017    4.0   ARIZONA   AZ
# 107   Not reported   2016-2017    4.0   ARIZONA   AZ
# 108   Not reported   2016-2017    4.0   ARIZONA   AZ
# 2245           NaN         NaN    NaN       NaN  NaN
# 2314           NaN         NaN    NaN       NaN  NaN
# ...            ...         ...    ...       ...  ...
# 7084           NaN         NaN    NaN       NaN  NaN
# 7127           NaN         NaN    NaN       NaN  NaN
# 7132           NaN         NaN    NaN       NaN  NaN
# 7230           NaN         NaN    NaN       NaN  NaN
# 7350           NaN         NaN    NaN       NaN  NaN
#
#                           SCH_NAME  STATE_AGENCY_NO  UNION ST_LEAID     LEAID  \
# 102       Ombudsman - Charter East              1.0    NaN  AZ-4323  400103.0
# 107    Ombudsman - Charter East II              1.0    NaN  AZ-4323  400103.0
# 108   Ombudsman - Charter Valencia              1.0    NaN  AZ-4323  400103.0
# 2245                           NaN              NaN    NaN      NaN       NaN
# 2314                           NaN              NaN    NaN      NaN       NaN
# ...                            ...              ...    ...      ...       ...
# 7084                           NaN              NaN    NaN      NaN       NaN
# 7127                           NaN              NaN    NaN      NaN       NaN
# 7132                           NaN              NaN    NaN      NaN       NaN
# 7230                           NaN              NaN    NaN      NaN       NaN
# 7350                           NaN              NaN    NaN      NaN       NaN
#
#            ST_SCHID     SCHID SHARED_TIME  TITLEI_STATUS  \
# 102    AZ-4323-5493  401583.0          No  NOTTITLE1ELIG
# 107   AZ-4323-89440  402855.0          No  NOTTITLE1ELIG
# 108   AZ-4323-89827  402950.0          No  NOTTITLE1ELIG
# 2245            NaN       NaN         NaN            NaN
# 2314            NaN       NaN         NaN            NaN
# ...             ...       ...         ...            ...
# 7084            NaN       NaN         NaN            NaN
# 7127            NaN       NaN         NaN            NaN
# 7132            NaN       NaN         NaN            NaN
# 7230            NaN       NaN         NaN            NaN
# 7350            NaN       NaN         NaN            NaN
#
#         TITLEI_STATUS_TEXT MAGNET_TEXT NSLP_STATUS NSLP_STATUS_TEXT  \
# 102   Not a Title I school     Missing      NSLPNO               No
# 107   Not a Title I school     Missing      NSLPNO               No
# 108   Not a Title I school     Missing      NSLPNO               No
# 2245                   NaN         NaN         NaN              NaN
# 2314                   NaN         NaN         NaN              NaN
# ...                    ...         ...         ...              ...
# 7084                   NaN         NaN         NaN              NaN
# 7127                   NaN         NaN         NaN              NaN
# 7132                   NaN         NaN         NaN              NaN
# 7230                   NaN         NaN         NaN              NaN
# 7350                   NaN         NaN         NaN              NaN
#
#          VIRTUAL VIRTUAL_TEXT                                           NAME  \
# 102   NOTVIRTUAL  Not Virtual                       Ombudsman - Charter East
# 107   NOTVIRTUAL  Not Virtual                    Ombudsman - Charter East II
# 108   NOTVIRTUAL  Not Virtual                   Ombudsman - Charter Valencia
# 2245         NaN          NaN           Mapleton Charter School at Whitehall
# 2314         NaN          NaN            William E Doar PCS NW Soldiers Home
# ...          ...          ...                                            ...
# 7084         NaN          NaN                     CAPSTONE CLASSICAL ACADEMY
# 7127         NaN          NaN                           Pathways High School
# 7132         NaN          NaN  Tomorrow River Virtual Charter School (TRVCS)
# 7230         NaN          NaN        Insight School of Wisconsin High School
# 7350         NaN          NaN                 Wonewoc-Center Virtual Academy
#
#       OPSTFIPS                       STREET              CITY STATE      ZIP  \
# 102        4.0               3943 E. Thomas           Phoenix    AZ  85018.0
# 107        4.0        4041 East Thomas Road           Phoenix    AZ  85018.0
# 108        4.0        1686 W. Valencia Road            Tucson    AZ  85746.0
# 2245      10.0  401 Federal Street- Suite 2             Dover    DE  19901.0
# 2314      11.0     3700 North Capitol St NW        Washington    DC  20011.0
# ...        ...                          ...               ...   ...      ...
# 7084      49.0              2307 N. 2850 W.        PLAIN CITY    UT  84404.0
# 7127      55.0              336 W Walnut St         Milwaukee    WI  53232.0
# 7132      55.0         10186 County Road MM  Amherst Junction    WI  54407.0
# 7230      55.0          4709 Dale-Curtin Dr         McFarland    WI  53558.0
# 7350      55.0                101 School Rd           Wonewoc    WI  53968.0
#
#      STFIP   CNTY                NMCNTY LOCALE        LAT         LON   CBSA  \
# 102     04  04013       Maricopa County     11  33.479939 -111.996269  38060
# 107     04  04013       Maricopa County     11  33.479926 -111.993746  38060
# 108     04  04019           Pima County     11  32.136471 -111.002207  46060
# 2245    10  10001           Kent County     13  39.158003  -75.522055  20100
# 2314    11  11001  District of Columbia     11  38.923611  -76.995785  47900
# ...    ...    ...                   ...    ...        ...         ...    ...
# 7084    49  49057          Weber County     21  41.299250 -112.049140  36260
# 7127    55  55079      Milwaukee County     11  43.052995  -87.915249  33340
# 7132    55  55097        Portage County     42  44.542612  -89.275643  44620
# 7230    55  55025           Dane County     21  43.014807  -89.300307  31540
# 7350    55  55057         Juneau County     43  43.662531  -90.222950      N
#
#                                             NMCBSA  CBSATYPE  CSA  \
# 102                    Phoenix-Mesa-Scottsdale, AZ       1.0    N
# 107                    Phoenix-Mesa-Scottsdale, AZ       1.0    N
# 108                                     Tucson, AZ       1.0  536
# 2245                                     Dover, DE       1.0  428
# 2314  Washington-Arlington-Alexandria, DC-VA-MD-WV       1.0  548
# ...                                            ...       ...  ...
# 7084                          Ogden-Clearfield, UT       1.0  482
# 7127             Milwaukee-Waukesha-West Allis, WI       1.0  376
# 7132                             Stevens Point, WI       2.0  554
# 7230                                   Madison, WI       1.0  357
# 7350                                             N       0.0    N
#
#                                                NMCSA NECTA NMNECTA    CD  \
# 102                                                N     N       N  0407
# 107                                                N     N       N  0407
# 108                               Tucson-Nogales, AZ     N       N  0403
# 2245        Philadelphia-Reading-Camden, PA-NJ-DE-MD     N       N  1000
# 2314  Washington-Baltimore-Arlington, DC-MD-VA-WV-PA     N       N  1198
# ...                                              ...   ...     ...   ...
# 7084                   Salt Lake City-Provo-Orem, UT     N       N  4901
# 7127                   Milwaukee-Racine-Waukesha, WI     N       N  5504
# 7132       Wausau-Stevens Point-Wisconsin Rapids, WI     N       N  5503
# 7230                   Madison-Janesville-Beloit, WI     N       N  5502
# 7350                                               N     N       N  5503
#
#        SLDL   SLDU  SURVYEAR
# 102   04024  04024    2016.0
# 107   04024  04024    2016.0
# 108   04004  04004    2016.0
# 2245  10032  10017    2016.0
# 2314      N  11005    2016.0
# ...     ...    ...       ...
# 7084  49029  49020    2016.0
# 7127  55016  55006    2016.0
# 7132  55071  55024    2016.0
# 7230  55047  55016    2016.0
# 7350  55050  55017    2016.0
#
# [63 rows x 131 columns]

# %%
# length of new charters
len(new_charters['NCESSCH'])
# Out:
# 63

# %%
#Save new charters in working folder
new_charters.to_csv('new_charters1617.csv', header=True)

# %% [markdown]
# # 10. Drop Repetitive Columns and clean full merged table

# %%
# Drop Repetitive Columns
charter_drop = charter1617.drop(['SCHOOL_YEAR_y', 'FIPST_y', 'STATENAME_y', 'ST_y', 'SCH_NAME_y', 'STATE_AGENCY_NO_y', 'UNION_y', 'ST_LEAID_y','LEAID_y', 'ST_SCHID_y','SCHID_y'
                 ,'SCHOOL_YEAR', 'FIPST', 'STATENAME', 'ST', 'SCH_NAME', 'STATE_AGENCY_NO', 'UNION', 'ST_LEAID','LEAID', 'ST_SCHID','SCHID', ], axis=1)

# %%
# Rename columns
cleaned_charter = charter_drop.rename(columns={'SCHOOL_YEAR_x':'SCHOOL_YEAR',
                                               'FIPST_x' : 'FIPST',
                                               'STATENAME_x' : 'STATENAME', 
                                               'ST_x' : 'ST',
                                               'SCH_NAME_x' : 'SCH_NAME',
                                               'STATE_AGENCY_NO_x' : 'STATE_AGENCY_NO',
                                               'UNION_x' : 'UNION',
                                               'ST_LEAID_x' : 'ST_LEAID',
                                               'LEAID_x': 'LEAID',
                                               'ST_SCHID_x' : 'ST_SCHID' ,
                                               'SCHID_x' : 'SCHID'})

# %%
# Save Progress 
cleaned_charter.to_csv("cleaned_AllCharters1617.csv", header = True)

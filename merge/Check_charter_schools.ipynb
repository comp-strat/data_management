# %%
# import libraries
import pandas as pd 
import pickle as pk
import numpy as np

# %%
charter1617 = pd.read_csv("mergedTable.csv")

# %%
charter1617

# %%
charter_curr = pd.read_csv("Checking charter URLs 2016 - full list.csv")

# %%
charter_curr

# %%
charters_in_curr = charter_curr["NCESSCH"]

# %%
charters_in_new = charter1617["NCESSCH"]

# %%
charters_in_new = charters_in_new.apply(lambda x: '{:.2f}'.format(x))

# %%
check_charter = charters_in_curr.eq(charters_in_new)

# %%
charters_in_new[1]

# %%
sum(check_charter)

# %%
def filarray(series, check_to):
    indexes = []
    for i in range(0, len(series)):
        if series[i] not in check_to:
            indexes.append(i)
    return indexes

# %%
filseries(charters_in_new, charters_in_curr)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# array([], dtype=float64)

# %%
charters_in_new = np.array(charters_in_new)

# %%
charters_in_curr = np.array(charters_in_curr)

# %%
charters_in_curr
# Out:
# array([480002508343,  64071013696, 370036503328, ...,  40012501619,
#         40008301021,  40006500821])

# %%
charters_in_new
# Out:
# array(['10019702432.00', '20000100329.00', '20015000306.00', ...,
#        '90021901782.00', '90022001807.00', '90022101803.00'], dtype=object)

# %%
charters_in_new = charters_in_new.astype(dtype= float)

# %%
new_indexes = filarray(charters_in_new, charters_in_curr)

# %%
new_charters = charter1617.iloc[new_indexes, :]

# %%
pd.set_option('display.max_columns', None)
new_charters
# Out:
#       Unnamed: 0 SCHOOL_YEAR  FIPST   STATENAME  ST  \
# 102          102   2016-2017      4     ARIZONA  AZ
# 107          107   2016-2017      4     ARIZONA  AZ
# 108          108   2016-2017      4     ARIZONA  AZ
# 213          213   2016-2017      4     ARIZONA  AZ
# 214          214   2016-2017      4     ARIZONA  AZ
# 581          581   2016-2017      4     ARIZONA  AZ
# 686          686   2016-2017      6  CALIFORNIA  CA
# 760          760   2016-2017      6  CALIFORNIA  CA
# 783          783   2016-2017      6  CALIFORNIA  CA
# 1347        1347   2016-2017      6  CALIFORNIA  CA
# 1411        1411   2016-2017      6  CALIFORNIA  CA
#
#                                              SCH_NAME  \
# 102                          Ombudsman - Charter East
# 107                       Ombudsman - Charter East II
# 108                      Ombudsman - Charter Valencia
# 213                       Sequoia Village High School
# 214                         George Washington Academy
# ...

# %%
new_charters['NCESSCH'].apply(lambda x: '{:.2f}'.format(x))
# Out:
# 102     40010301583.00
# 107     40010302855.00
# 108     40010302950.00
# 213     40024603028.00
# 214     40024603494.00
# 581     40094603375.00
# 686     60000114062.00
# 760     60141913136.00
# 783     60144414064.00
# 1347    62271014063.00
# 1411    62703013921.00
# Name: NCESSCH, dtype: object

# %%
len(new_indexes)
# Out:
# 11

# %%
new_charters.to_csv('new_charters16-17.csv', header=True)

# %%
new_charters["STREET"] + " " + new_charters["CITY"] + " " + new_charters["STATE"] + " " + new_charters["ZIP"].astype(dtype= str)
# Out:
# 102                       3943 E. Thomas Phoenix AZ 85018
# 107                4041 East Thomas Road Phoenix AZ 85018
# 108                 1686 W. Valencia Road Tucson AZ 85746
# 213                 982 Full House Lane Show Low AZ 85901
# 214                    1945 S. 1st St. Snowflake AZ 85937
# 581                  4445 S. 12th Street Phoenix AZ 85040
# 686     1782 La Costa Meadows Dr. Ste. 102 San Marcos ...
# 760                  355 E. Leland Rd. Pittsburg CA 94565
# 783                         101 Glen Dr. Fairfax CA 94930
# 1347             1800 Colorado Blvd. Los Angeles CA 90041
# 1411                   722 W. March Ln. Stockton CA 95207
# dtype: object

# %%
new_charters["SCH_NAME"]
# Out:
# 102                            Ombudsman - Charter East
# 107                         Ombudsman - Charter East II
# 108                        Ombudsman - Charter Valencia
# 213                         Sequoia Village High School
# 214                           George Washington Academy
# 581              Phoenix Collegiate Academy High School
# 686     Pathways Academy Charter School Adult Education
# 760                           Synergy Education Project
# 783                                 Ross Valley Charter
# 1347              PUC International Preparatory Academy
# 1411                                        The Academy
# Name: SCH_NAME, dtype: object
